# %% [markdown]
# <a href="https://colab.research.google.com/github/123ranika/jsfinal/blob/main/FacebookAI_xlm_roberta_base_run_6000.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Performing checks for the resources available

# %%
import torch

# If there's a GPU available...
if torch.cuda.is_available():

    # Tell PyTorch to use the GPU.
    device = torch.device("cuda")

    print('There are %d GPU(s) available.' % torch.cuda.device_count())

    print('We will use the GPU:', torch.cuda.get_device_name(0))

# If not...
else:
    print('No GPU available, using the CPU instead.')
    device = torch.device("cpu")
# Out:
# There are 1 GPU(s) available.
# We will use the GPU: Tesla T4

# %% [markdown]
# ### Installing huggingface transformers library

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.46.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.26.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.6)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)

# %% [markdown]
# ## Importing necessary packages

# %%
import pandas as pd
import numpy as np
import random
from sklearn.preprocessing import LabelEncoder
from sklearn.utils.class_weight import compute_class_weight
import time
import datetime
from sklearn.metrics import classification_report,confusion_matrix
import random
import time
import torch.nn as nn
from transformers import AutoModel , AutoModelForSequenceClassification, AutoConfig , AutoTokenizer , AdamW ,get_linear_schedule_with_warmup
import torch
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rc
from matplotlib.ticker import MaxNLocator

# %% [markdown]
# ## Setting some configuration values

# %%
# Use plot styling from seaborn.
sns.set(style='darkgrid')

# Increase the plot size and font size.
sns.set(font_scale=1.5)
plt.rcParams["figure.figsize"] = (16,12)

# Set the seed value all over the place to make this reproducible.
seed_val = 42

random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)
torch.cuda.manual_seed_all(seed_val)

# %% [markdown]
# ## Importing drive into the colaboratory

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ## Loading training data

# %%
import pandas as pd

# Attempt to read the file with ISO-8859-1 encoding
data = pd.read_excel('/content/Dataset (3).xlsx')

# %%
data=data[:6000]

# %%
data.count()
# Out:
# texts     6000
# labels    6000
# dtype: int64

# %%
data.head()
# Out:
#                                                texts            labels
# 0  মেধাবী শিক্ষার্থীরাই মা বাবাকে বিদ্যাস্রমে পাটাবে     Cyberbullying
# 1  চিরিয়া খানার এই অদ্ভুত প্রাণী গুলারে রাস্তায়...     Cyberbullying
# 2        শরীর বিক্রি করে পয়সা কামাই করে৷ আবার ভাব কি     Cyberbullying
# 3                              এটা কি আমাদের ধর্মজাল  Religious_Hatred
# 4           বেডি আসার আগে দাঁত মাজতে ভুলে গেছে বুঝি।     Cyberbullying

# %%
# Add an ID column starting from 1
data['PID'] = range(1, len(data) + 1)

# %%
data.head()
# Out:
#                                                texts            labels  PID
# 0  মেধাবী শিক্ষার্থীরাই মা বাবাকে বিদ্যাস্রমে পাটাবে     Cyberbullying    1
# 1  চিরিয়া খানার এই অদ্ভুত প্রাণী গুলারে রাস্তায়...     Cyberbullying    2
# 2        শরীর বিক্রি করে পয়সা কামাই করে৷ আবার ভাব কি     Cyberbullying    3
# 3                              এটা কি আমাদের ধর্মজাল  Religious_Hatred    4
# 4           বেডি আসার আগে দাঁত মাজতে ভুলে গেছে বুঝি।     Cyberbullying    5

# %%
import pandas as pd

# Function to rename a single column
def change_column_name(df, old_name, new_name):
    df = df.rename(columns={old_name: new_name})
    return df

# Assuming df is your DataFrame
data = change_column_name(data, old_name="label", new_name="labels")
data = change_column_name(data, old_name="Comments", new_name="text")
data.head() # Display the first few rows of the DataFrame
#text


# Move the ID column to the first position
cols = ['PID'] + [col for col in data.columns if col != 'PID']
data = data[cols]

data.head()
# Out:
#    PID                                              texts            labels
# 0    1  মেধাবী শিক্ষার্থীরাই মা বাবাকে বিদ্যাস্রমে পাটাবে     Cyberbullying
# 1    2  চিরিয়া খানার এই অদ্ভুত প্রাণী গুলারে রাস্তায়...     Cyberbullying
# 2    3        শরীর বিক্রি করে পয়সা কামাই করে৷ আবার ভাব কি     Cyberbullying
# 3    4                              এটা কি আমাদের ধর্মজাল  Religious_Hatred
# 4    5           বেডি আসার আগে দাঁত মাজতে ভুলে গেছে বুঝি।     Cyberbullying

# %%
# Keep only the specified three columns
# Replace 'column1', 'column2', 'column3' with your actual column names
data = data[['PID', 'texts', 'labels']]

# Report the number of sentences
print('Number of training sentences: {:,}\n'.format(data.shape[0]))

# Display 10 random rows from the data
print(data.sample(10))
# Out:
# Number of training sentences: 6,000
#
#        PID                                              texts  \
# 1782  1783                                   হালি ঘুমায় কেমনে
# 3917  3918                                        হাউন আঙ্কেল
# 221    222               মমতাজের জন্য পার্লামেন্ট সর্গে উঠেছে
# 2135  2136                             পাইপটা নিচে লাগিয়ে চুষ
# 5224  5225  যদি দাড়ি টুপি আলাদের গালগাল খেতে চান তাহলে মু...
# 1168  1169                           সস্তা মেয়েদের এভাবেই খায়
# 879    880                 আর কইদিন পরে ওই ২টা বিচি হয়ে জাবে।
# 156    157      কোনো কিছুতে লাগলে টেলেন্ট পুটকি দিয়া গেল অইলে
# 1657  1658                         লিজেন্ড রা অন্য কিছু দেকবে
# 323    324                               হালা টোকাইয়ের বংস ধর
#
#                 labels
# 1782     Cyberbullying
# 3917           Sarcasm
# 221            Sarcasm
# 2135     Cyberbullying
# 5224  Religious_Hatred
# 1168     Cyberbullying
# 879      Cyberbullying
# 156      Cyberbullying
# 1657           Sarcasm
# 323      Cyberbullying

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# # Read the file with ISO-8859-1 encoding
# train_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Nazir Sir/spam - spam.csv', encoding='ISO-8859-1')

# First, split the data into training and temp (test + validation)
train_df, temp_df = train_test_split(data, test_size=0.2, random_state=42)

# Then split temp_data into test and validation sets (50% each of temp_data, so 15% of the total for each)
test_df, val_df = train_test_split(temp_df, test_size=0.5, random_state=42)

# %%
train_df
# Out:
#        PID                                              texts         labels
# 3897  3898               মা কিভাবে পারেন তাকে নিয়ে ট্রল করতে  Cyberbullying
# 5628  5629                                নায়িকা এত মোটা কেন         Racism
# 1756  1757                             ধাক্কা ধাক্কি করবেন না  Cyberbullying
# 2346  2347  গরুর ভূড়ি ঠিকি তো পছন্দ করো তাহলে আমার এই ভূড়ি...  Cyberbullying
# 2996  2997                                        ভারতের কসাই  Cyberbullying
# ...    ...                                                ...            ...
# 3772  3773  হাসিনাকে অতি শিগগিরী দেশে ফিরিয়ে এনে ২০০৯ এর ...      Political
# 5191  5192          এখন নাচতে শুরু করেছে পরে বাঁচতে শুরু করবে        Sarcasm
# 5226  5227  ইন্ডিয়ান লক্ষ লক্ষ পর্নো ভিডিও ইন্টারনেটে আপল...  Cyberbullying
# 5390  5391            পাগোল যদি মাঠে থাকে তাহলে বিবাহ হবেনানে        Sarcasm
# 860    861                                       অতি টিপার ফল  Cyberbullying
#
# [4800 rows x 3 columns]

# %%
test_df
# Out:
#        PID                                              texts  \
# 5000  5001                   নাচের সাথে ধর্মের কোনো কারণ নেই।
# 5492  5493           নিজের গায়ে লাগলে হারাম অন্যের সময় হালাল
# 439    440            পানি লে আগে নাহলি মাতা ঘুইরি পইরি জাবিন
# 4834  4835                            ভাস্কর খানকির ছেলে পাঠা
# 1225  1226                       ড্রাইভার আবেদ আলী কাকু নাকি?
# ...    ...                                                ...
# 1086  1087               হানিবানি ম্যাডাম ঠিক এই ভাবে কথা বলে
# 5488  5489  নামধারী আলেম শুধু লেগে থাকেন একজন আরেকজনের দোষ...
# 776    777  পাগলা গারদে মোবাইল ইন্টারনেট ব্যাবহার করা যায় ...
# 4190  4191                          মাতারির বাড়ির লোকেশন দেন
# 4280  4281                   কুকুর মালিকের সাথেই থাকে সবসময়।
#
#                 labels
# 5000  Religious_Hatred
# 5492  Religious_Hatred
# 439            Sarcasm
# 4834     Cyberbullying
# 1225           Sarcasm
# ...                ...
# 1086     Cyberbullying
# 5488  Religious_Hatred
# 776            Sarcasm
# 4190     Cyberbullying
# 4280           Sarcasm
#
# [600 rows x 3 columns]

# %%
val_df
# Out:
#        PID                                    texts            labels
# 5160  5161                 কভু আশীবিষে দংশেনি যারে।           Sarcasm
# 2845  2846                 মাথায় কি এতো ঝামেলা সয়-?           Sarcasm
# 1870  1871                       খালি কলস বেশি বাজে           Sarcasm
# 3606  3607                       বউ ও নাই নেট ও নাই           Sarcasm
# 1074  1075                           মিয়া মিয়া লাগে     Cyberbullying
# ...    ...                                      ...               ...
# 426    427                       তানিশা বারো বাতারি     Cyberbullying
# 2864  2865              এবার কাকুর ফলক উন্মোচন হবে!           Sarcasm
# 1501  1502     পুটকি মারতে মারতে মাইরা লাইবার মনে ক     Cyberbullying
# 4915  4916                সৌদি দের পা ধুয়া পানি খা  Religious_Hatred
# 5746  5747  কে কার সাথে রেষ্ট নিচ্ছে জাতি জানতে চায়           Sarcasm
#
# [600 rows x 3 columns]

# %%
train_df['labels'].value_counts()
# Out:
# labels
# Cyberbullying            1695
# Sarcasm                  1606
# Political                 788
# Religious_Hatred          469
# Racism                    194
# Gender_Discrimination      48
# Name: count, dtype: int64

# %%
le = LabelEncoder()
train_df['labels'] = le.fit_transform(train_df['labels'])

# %%
train_df['labels'].value_counts()
# Out:
# labels
# 0    1695
# 5    1606
# 2     788
# 4     469
# 3     194
# 1      48
# Name: count, dtype: int64

# %% [markdown]
# ### Loading `train_sentences` and `train_labels`

# %%
# Get the lists of sentences and their labels.
train_sentences = train_df['texts'].values
train_labels = train_df['labels'].values

# %% [markdown]
# ## Saving Class Names

# %%
data.labels.unique()
# Out:
# array(['Cyberbullying', 'Religious_Hatred', 'Gender_Discrimination',
#        'Sarcasm', 'Political', 'Racism'], dtype=object)

# %%
class_names = [
            'Cyberbullying', 'Religious_Hatred', 'Gender_Discrimination',
       'Sarcasm', 'Political', 'Racism'
]

# %% [markdown]
# ## Loading the validation data

# %%
val_df['labels'] = le.transform(val_df['labels'])

# %%
val_df['labels'].value_counts()
# Out:
# labels
# 0    216
# 5    191
# 2    104
# 4     54
# 3     30
# 1      5
# Name: count, dtype: int64

# %% [markdown]
# ### Loading `val_sentences` and `val_labels`

# %%
# Get the lists of sentences and their labels.
val_sentences = val_df['texts'].values
val_labels = val_df['labels'].values

# %%
val_labels
# Out:
# array([5, 5, 5, 5, 0, 0, 3, 0, 5, 3, 2, 4, 0, 0, 0, 5, 0, 0, 0, 0, 4, 4,
#        0, 4, 0, 0, 0, 5, 5, 5, 3, 5, 0, 0, 0, 5, 0, 2, 3, 5, 4, 2, 4, 5,
#        5, 5, 0, 5, 2, 2, 0, 5, 3, 2, 0, 5, 5, 0, 4, 2, 2, 2, 4, 0, 2, 4,
#        0, 0, 5, 3, 0, 0, 2, 0, 5, 3, 4, 5, 4, 4, 3, 5, 0, 5, 0, 0, 3, 2,
#        2, 5, 3, 5, 4, 2, 0, 0, 0, 2, 4, 5, 0, 5, 5, 0, 0, 5, 5, 4, 2, 0,
#        5, 2, 5, 0, 3, 2, 5, 0, 5, 5, 5, 4, 2, 5, 0, 0, 5, 5, 0, 5, 2, 0,
#        3, 5, 2, 0, 0, 0, 2, 0, 5, 0, 3, 2, 0, 0, 2, 2, 0, 2, 0, 4, 0, 0,
#        2, 0, 1, 5, 0, 2, 4, 3, 0, 5, 4, 4, 0, 0, 5, 4, 5, 4, 5, 5, 5, 2,
#        5, 2, 3, 5, 0, 0, 5, 2, 4, 0, 0, 5, 5, 2, 4, 0, 0, 0, 0, 5, 0, 4,
#        5, 5, 0, 0, 0, 0, 5, 2, 5, 0, 0, 0, 0, 5, 4, 2, 5, 5, 5, 0, 5, 5,
#        0, 4, 0, 0, 5, 4, 5, 4, 0, 0, 5, 0, 0, 5, 5, 5, 0, 2, 5, 0, 0, 0,
#        5, 4, 0, 0, 5, 0, 5, 5, 5, 0, 5, 0, 1, 4, 0, 2, 3, 0, 5, 5, 5, 5,
#        0, 0, 4, 2, 5, 3, 0, 5, 0, 2, 0, 0, 3, 2, 4, 5, 5, 0, 0, 0, 2, 0,
#        5, 5, 2, 5, 5, 2, 5, 5, 2, 0, 0, 0, 0, 5, 5, 0, 5, 2, 0, 0, 0, 5,
#        0, 5, 4, 0, 5, 5, 2, 5, 5, 4, 5, 0, 5, 0, 5, 0, 5, 2, 0, 5, 0, 0,
#        2, 5, 0, 0, 3, 3, 0, 5, 0, 5, 5, 5, 0, 2, 0, 0, 5, 0, 5, 4, 5, 2,
#        2, 5, 2, 2, 0, 5, 0, 5, 0, 0, 2, 2, 5, 0, 5, 2, 4, 2, 5, 0, 0, 0,
#        5, 5, 0, 3, 5, 0, 2, 0, 2, 0, 0, 0, 0, 0, 5, 2, 5, 5, 0, 2, 0, 5,
#        4, 5, 5, 2, 0, 5, 5, 5, 0, 0, 0, 3, 0, 0, 0, 2, 0, 0, 2, 4, 5, 5,
#        2, 0, 2, 0, 0, 4, 0, 0, 2, 2, 0, 2, 5, 2, 5, 0, 5, 5, 0, 0, 5, 5,
#        0, 2, 0, 5, 2, 5, 2, 5, 5, 0, 5, 2, 0, 4, 5, 3, 0, 5, 0, 0, 2, 2,
#        2, 2, 4, 4, 2, 0, 0, 2, 5, 0, 5, 0, 5, 5, 5, 4, 5, 2, 0, 5, 5, 0,
#        2, 2, 5, 0, 5, 3, 1, 0, 0, 0, 5, 4, 0, 0, 0, 0, 2, 0, 5, 2, 5, 4,
#        2, 0, 5, 0, 5, 4, 5, 0, 2, 5, 5, 0, 5, 0, 2, 5, 5, 2, 5, 0, 4, 0,
#        0, 5, 1, 0, 2, 2, 0, 5, 0, 0, 0, 0, 0, 5, 3, 0, 5, 4, 3, 0, 5, 5,
#        4, 5, 0, 5, 5, 5, 0, 0, 3, 5, 2, 5, 4, 5, 5, 2, 2, 0, 0, 4, 4, 5,
#        2, 0, 5, 2, 5, 2, 2, 2, 2, 3, 2, 2, 0, 0, 5, 3, 3, 0, 2, 5, 2, 1,
#        2, 0, 5, 0, 4, 5])

# %% [markdown]
# ## Helper Functions

# %% [markdown]
# #### 1) Update Interval Function

# %%
def good_update_interval(total_iters, num_desired_updates):
    '''
    This function will try to pick an intelligent progress update interval
    based on the magnitude of the total iterations.

    Parameters:
      `total_iters` - The number of iterations in the for-loop.
      `num_desired_updates` - How many times we want to see an update over the
                              course of the for-loop.
    '''
    # Divide the total iterations by the desired number of updates. Most likely
    # this will be some ugly number.
    exact_interval = total_iters / num_desired_updates

    # The `round` function has the ability to round down a number to, e.g., the
    # nearest thousandth: round(exact_interval, -3)
    #
    # To determine the magnitude to round to, find the magnitude of the total,
    # and then go one magnitude below that.

    # Get the order of magnitude of the total.
    order_of_mag = len(str(total_iters)) - 1

    # Our update interval should be rounded to an order of magnitude smaller.
    round_mag = order_of_mag - 1

    # Round down and cast to an int.
    update_interval = int(round(exact_interval, -round_mag))

    # Don't allow the interval to be zero!
    if update_interval == 0:
        update_interval = 1

    return update_interval

# %% [markdown]
# #### 2) Format time function

# %%
def format_time(elapsed):
    '''
    Takes a time in seconds and returns a string hh:mm:ss
    '''
    # Round to the nearest second.
    elapsed_rounded = int(round((elapsed)))

    # Format as hh:mm:ss
    return str(datetime.timedelta(seconds=elapsed_rounded))

# %% [markdown]
# #### 3) Make Smart Batches function

# %%
def make_smart_batches(text_samples, labels, batch_size,tokenizer,max_input_length):
    '''
    This function combines all of the required steps to prepare batches.
    '''

    print('Creating Smart Batches from {:,} examples with batch size {:,}...\n'.format(len(text_samples), batch_size))

    # =========================
    #   Tokenize & Truncate
    # =========================

    full_input_ids = []

    # Tokenize all training examples
    print('Tokenizing {:,} samples...'.format(len(labels)))

    # Choose an interval on which to print progress updates.
    update_interval = good_update_interval(total_iters=len(labels), num_desired_updates=10)

    # For each training example...
    for text in text_samples:

        # Report progress.
        if ((len(full_input_ids) % update_interval) == 0):
            print('  Tokenized {:,} samples.'.format(len(full_input_ids)))

        # Tokenize the sample.
        input_ids = tokenizer.encode(text=text,              # Text to encode.
                                    add_special_tokens=True, # Do add specials.
                                    max_length=max_input_length,
                                    truncation=True,         # Do Truncate!
                                    padding=False)           # DO NOT pad.

        # Add the tokenized result to our list.
        full_input_ids.append(input_ids)

    print('DONE.')
    print('{:>10,} samples\n'.format(len(full_input_ids)))

    # =========================
    #      Select Batches
    # =========================

    # Sort the two lists together by the length of the input sequence.
    samples = sorted(zip(full_input_ids, labels), key=lambda x: len(x[0]))

    print('{:>10,} samples after sorting\n'.format(len(samples)))

    import random

    # List of batches that we'll construct.
    batch_ordered_sentences = []
    batch_ordered_labels = []

    print('Creating batches of size {:}...'.format(batch_size))

    # Choose an interval on which to print progress updates.
    update_interval = good_update_interval(total_iters=len(samples), num_desired_updates=10)

    # Loop over all of the input samples...
    while len(samples) > 0:

        # Report progress.
        if ((len(batch_ordered_sentences) % update_interval) == 0 \
            and not len(batch_ordered_sentences) == 0):
            print('  Selected {:,} batches.'.format(len(batch_ordered_sentences)))

        # `to_take` is our actual batch size. It will be `batch_size` until
        # we get to the last batch, which may be smaller.
        to_take = min(batch_size, len(samples))

        # Pick a random index in the list of remaining samples to start
        # our batch at.
        select = random.randint(0, len(samples) - to_take)

        # Select a contiguous batch of samples starting at `select`.
        #print("Selecting batch from {:} to {:}".format(select, select+to_take))
        batch = samples[select:(select + to_take)]

        #print("Batch length:", len(batch))

        # Each sample is a tuple--split them apart to create a separate list of
        # sequences and a list of labels for this batch.
        batch_ordered_sentences.append([s[0] for s in batch])
        batch_ordered_labels.append([s[1] for s in batch])

        # Remove these samples from the list.
        del samples[select:select + to_take]

    print('\n  DONE - Selected {:,} batches.\n'.format(len(batch_ordered_sentences)))

    # =========================
    #        Add Padding
    # =========================

    print('Padding out sequences within each batch...')

    py_inputs = []
    py_attn_masks = []
    py_labels = []

    # For each batch...
    for (batch_inputs, batch_labels) in zip(batch_ordered_sentences, batch_ordered_labels):

        # New version of the batch, this time with padded sequences and now with
        # attention masks defined.
        batch_padded_inputs = []
        batch_attn_masks = []

        # First, find the longest sample in the batch.
        # Note that the sequences do currently include the special tokens!
        max_size = max([len(sen) for sen in batch_inputs])

        # For each input in this batch...
        for sen in batch_inputs:

            # How many pad tokens do we need to add?
            num_pads = max_size - len(sen)

            # Add `num_pads` padding tokens to the end of the sequence.
            padded_input = sen + [tokenizer.pad_token_id]*num_pads

            # Define the attention mask--it's just a `1` for every real token
            # and a `0` for every padding token.
            attn_mask = [1] * len(sen) + [0] * num_pads

            # Add the padded results to the batch.
            batch_padded_inputs.append(padded_input)
            batch_attn_masks.append(attn_mask)

        # Our batch has been padded, so we need to save this updated batch.
        # We also need the inputs to be PyTorch tensors, so we'll do that here.
        # Todo - Michael's code specified "dtype=torch.long"
        py_inputs.append(torch.tensor(batch_padded_inputs))
        py_attn_masks.append(torch.tensor(batch_attn_masks))
        py_labels.append(torch.tensor(batch_labels))

    print('  DONE.')

    # Return the smart-batched dataset!
    return (py_inputs, py_attn_masks, py_labels)

# %%
def make_smart_batches_on_test(text_samples, text_ids, batch_size,tokenizer,max_input_length):
    '''
    This function combines all of the required steps to prepare batches.
    '''

    print('Creating Smart Batches from {:,} examples with batch size {:,}...\n'.format(len(text_samples), batch_size))

    # =========================
    #   Tokenize & Truncate
    # =========================

    full_input_ids = []

    # Tokenize all training examples
    print('Tokenizing {:,} samples...'.format(len(text_samples)))

    # Choose an interval on which to print progress updates.
    update_interval = good_update_interval(total_iters=len(text_samples), num_desired_updates=10)

    # For each training example...
    for text in text_samples:

        # Report progress.
        if ((len(full_input_ids) % update_interval) == 0):
            print('  Tokenized {:,} samples.'.format(len(full_input_ids)))

        # Tokenize the sample.
        input_ids = tokenizer.encode(text=text,              # Text to encode.
                                    add_special_tokens=True, # Do add specials.
                                    max_length=max_input_length,
                                    truncation=True,         # Do Truncate!
                                    padding=False)           # DO NOT pad.

        # Add the tokenized result to our list.
        full_input_ids.append(input_ids)

    print('DONE.')
    print('{:>10,} samples\n'.format(len(full_input_ids)))

    # =========================
    #      Select Batches
    # =========================

    # Sort the two lists together by the length of the input sequence.
    samples = sorted(zip(full_input_ids, text_ids), key=lambda x: len(x[0]))

    print('{:>10,} samples after sorting\n'.format(len(samples)))

    import random

    # List of batches that we'll construct.
    batch_ordered_sentences = []
    batch_ordered_ids = []

    print('Creating batches of size {:}...'.format(batch_size))

    # Choose an interval on which to print progress updates.
    update_interval = good_update_interval(total_iters=len(samples), num_desired_updates=10)

    # Loop over all of the input samples...
    while len(samples) > 0:

        # Report progress.
        if ((len(batch_ordered_sentences) % update_interval) == 0 \
            and not len(batch_ordered_sentences) == 0):
            print('  Selected {:,} batches.'.format(len(batch_ordered_sentences)))

        # `to_take` is our actual batch size. It will be `batch_size` until
        # we get to the last batch, which may be smaller.
        to_take = min(batch_size, len(samples))

        # Pick a random index in the list of remaining samples to start
        # our batch at.
        select = random.randint(0, len(samples) - to_take)

        # Select a contiguous batch of samples starting at `select`.
        #print("Selecting batch from {:} to {:}".format(select, select+to_take))
        batch = samples[select:(select + to_take)]

        #print("Batch length:", len(batch))

        # Each sample is a tuple--split them apart to create a separate list of
        # sequences and a list of labels for this batch.
        batch_ordered_sentences.append([s[0] for s in batch])
        batch_ordered_ids.append([s[1] for s in batch])

        # Remove these samples from the list.
        del samples[select:select + to_take]

    print('\n  DONE - Selected {:,} batches.\n'.format(len(batch_ordered_sentences)))

    # =========================
    #        Add Padding
    # =========================

    print('Padding out sequences within each batch...')

    py_inputs = []
    py_attn_masks = []
    py_ids = []

    # For each batch...
    for (batch_inputs, batch_ids) in zip(batch_ordered_sentences, batch_ordered_ids):

        # New version of the batch, this time with padded sequences and now with
        # attention masks defined.
        batch_padded_inputs = []
        batch_attn_masks = []

        # First, find the longest sample in the batch.
        # Note that the sequences do currently include the special tokens!
        max_size = max([len(sen) for sen in batch_inputs])

        # For each input in this batch...
        for sen in batch_inputs:

            # How many pad tokens do we need to add?
            num_pads = max_size - len(sen)

            # Add `num_pads` padding tokens to the end of the sequence.
            padded_input = sen + [tokenizer.pad_token_id]*num_pads

            # Define the attention mask--it's just a `1` for every real token
            # and a `0` for every padding token.
            attn_mask = [1] * len(sen) + [0] * num_pads

            # Add the padded results to the batch.
            batch_padded_inputs.append(padded_input)
            batch_attn_masks.append(attn_mask)

        # Our batch has been padded, so we need to save this updated batch.
        # We also need the inputs to be PyTorch tensors, so we'll do that here.
        # Todo - Michael's code specified "dtype=torch.long"
        py_inputs.append(torch.tensor(batch_padded_inputs))
        py_attn_masks.append(torch.tensor(batch_attn_masks))
        py_ids.append(torch.tensor(batch_ids))

    print('  DONE.')

    # Return the smart-batched dataset!
    return (py_inputs, py_attn_masks, py_ids)

# %% [markdown]
# #### 4) Function for calculating accuracy per class

# %%
def accuracy_per_class(preds, labels , label_dict):

    preds_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()

    for label in np.unique(labels_flat):
        y_preds = preds_flat[labels_flat==label]
        y_true = labels_flat[labels_flat==label]
        print(f'Class: {label_dict[label]}')
        print(f'Accuracy: {round(100*len(y_preds[y_preds==label])/len(y_true) , 2)}\n')

# %% [markdown]
# ### 5) Function for plotting training history

# %%
def plot_training_history(history):
  fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 6))

  ax1.plot(history['train_loss'], label='train loss')
  ax1.plot(history['val_loss'], label='validation loss')

  ax1.xaxis.set_major_locator(MaxNLocator(integer=True))
  ax1.set_ylim([-0.05, 1.05])
  ax1.legend()
  ax1.set_ylabel('Loss')
  ax1.set_xlabel('Epoch')

  ax2.plot(history['train_acc'], label='train accuracy')
  ax2.plot(history['val_acc'], label='validation accuracy')

  ax2.xaxis.set_major_locator(MaxNLocator(integer=True))
  ax2.set_ylim([-0.05, 1.05])
  ax2.legend()

  ax2.set_ylabel('Accuracy')
  ax2.set_xlabel('Epoch')

  fig.suptitle('Training history')

# %% [markdown]
# ### 6) Function to check accuracy

# %%
def check_accuracy(predictions,true_labels):
  # Combine the results across the batches.
  predictions = np.concatenate(predictions, axis=0)
  true_labels = np.concatenate(true_labels, axis=0)

  # Choose the label with the highest score as our prediction.
  preds = np.argmax(predictions, axis=1).flatten()

  # Calculate simple flat accuracy -- number correct over total number.
  accuracy = (preds == true_labels).mean()

  return accuracy

# %% [markdown]
# ### 7) Function to evaluate model

# %%
def eval_model(model,py_inputs, py_attn_masks, py_labels):
# Prediction on test set
  t0 = time.time()

  print('Doing validation on {:,} sentences...'.format(len(py_labels)))

  # Put model in evaluation mode
  model.eval()

  # Tracking variables
  predictions , true_labels = [], []

  # Choose an interval on which to print progress updates.
  update_interval = good_update_interval(total_iters=len(py_inputs), num_desired_updates=10)

  # Measure elapsed time.
  t0 = time.time()
  total_val_loss = 0

  # Put model in evaluation mode
  model.eval()

  # For each batch of training data...
  for step in range(0, len(py_inputs)):

      # Progress update every 100 batches.
      if step % update_interval == 0 and not step == 0:
          # Calculate elapsed time in minutes.
          elapsed = format_time(time.time() - t0)

          # Calculate the time remaining based on our progress.
          steps_per_sec = (time.time() - t0) / step
          remaining_sec = steps_per_sec * (len(py_inputs) - step)
          remaining = format_time(remaining_sec)

          # Report progress.
          print('  Batch {:>7,}  of  {:>7,}.    Elapsed: {:}.  Remaining: {:}'.format(step, len(py_inputs), elapsed, remaining))

      # Copy the batch to the GPU.
      b_input_ids = py_inputs[step].to(device)
      b_input_mask = py_attn_masks[step].to(device)
      b_labels = py_labels[step].to(device)

      # Telling the model not to compute or store gradients, saving memory and
      # speeding up prediction
      with torch.no_grad():
        output = model(b_input_ids,
                           #  token_type_ids=None,
                             attention_mask=b_input_mask,
                             labels=b_labels)


      logits = output.logits
      loss = output.loss
      # Move logits and labels to CPU
      logits = logits.detach().cpu().numpy()
      label_ids = b_labels.to('cpu').numpy()

      # Store predictions and true labels
      predictions.append(logits)
      true_labels.append(label_ids)

      total_val_loss += loss.item()

  val_accuracy = check_accuracy(predictions,true_labels)

  validation_time = format_time(time.time() - t0)

  # Calculate the average loss over all of the batches.
  avg_val_loss = total_val_loss / len(py_inputs)


  # print('Accuracy: {:.3f}'.format(val_accuracy))
  return (avg_val_loss,val_accuracy,validation_time)

# %% [markdown]
# ### 8) Function for making predictions on our test dataset

# %%
def get_predictions(py_inputs, py_attn_masks, py_labels):

  print('Predicting labels for {:,} test batches...'.format(len(py_labels)))

  # Put model in evaluation mode
  model.eval()

  # Tracking variables
  predictions , true_labels = [], []

  # Choose an interval on which to print progress updates.
  update_interval = good_update_interval(total_iters=len(py_inputs), num_desired_updates=10)

  # Measure elapsed time.
  t0 = time.time()

  # Put model in evaluation mode
  model.eval()

  # For each batch of training data...
  for step in range(0, len(py_inputs)):

      # Progress update every 100 batches.
      if step % update_interval == 0 and not step == 0:
          # Calculate elapsed time in minutes.
          elapsed = format_time(time.time() - t0)

          # Calculate the time remaining based on our progress.
          steps_per_sec = (time.time() - t0) / step
          remaining_sec = steps_per_sec * (len(py_inputs) - step)
          remaining = format_time(remaining_sec)

          # Report progress.
          print('  Batch {:>7,}  of  {:>7,}.    Elapsed: {:}.  Remaining: {:}'.format(step, len(py_inputs), elapsed, remaining))

      # Copy the batch to the GPU.
      b_input_ids = py_inputs[step].to(device)
      b_input_mask = py_attn_masks[step].to(device)
      b_labels = py_labels[step].to(device)

      # Telling the model not to compute or store gradients, saving memory and
      # speeding up prediction
      with torch.no_grad():
          # Forward pass, calculate logit predictions
          outputs = model(b_input_ids, b_input_mask)

      logits = outputs.logits

      # Move logits and labels to CPU
      logits = logits.detach().cpu().numpy()
      label_ids = b_labels.to('cpu').numpy()

      # Store predictions and true labels
      predictions.append(logits)
      true_labels.append(label_ids)
      # Combine the results across the batches.
  predictions = np.concatenate(predictions, axis=0)
  true_labels = np.concatenate(true_labels, axis=0)

      # Choose the label with the highest score as our prediction.
  preds = np.argmax(predictions, axis=1).flatten()

  return (preds,true_labels)

# %% [markdown]
# ### 9) Function for making predictions on test dataset(without labels)

# %%
def get_predictions_test(py_inputs, py_attn_masks,py_ids):

  print('Predicting labels for {:,} test batches...'.format(len(py_inputs)))

  # Put model in evaluation mode
  model.eval()

  # Tracking variables
  predictions , true_labels ,ids = [], [] , []

  # Choose an interval on which to print progress updates.
  update_interval = good_update_interval(total_iters=len(py_inputs), num_desired_updates=10)

  # Measure elapsed time.
  t0 = time.time()

  # Put model in evaluation mode
  model.eval()

  # For each batch of training data...
  for step in range(0, len(py_inputs)):

      # Progress update every 100 batches.
      if step % update_interval == 0 and not step == 0:
          # Calculate elapsed time in minutes.
          elapsed = format_time(time.time() - t0)

          # Calculate the time remaining based on our progress.
          steps_per_sec = (time.time() - t0) / step
          remaining_sec = steps_per_sec * (len(py_inputs) - step)
          remaining = format_time(remaining_sec)

          # Report progress.
          print('  Batch {:>7,}  of  {:>7,}.    Elapsed: {:}.  Remaining: {:}'.format(step, len(py_inputs), elapsed, remaining))

      # Copy the batch to the GPU.
      b_input_ids = py_inputs[step].to(device)
      b_input_mask = py_attn_masks[step].to(device)
      b_ids = py_ids[step].to(device)

      # Telling the model not to compute or store gradients, saving memory and
      # speeding up prediction
      with torch.no_grad():
          # Forward pass, calculate logit predictions
          outputs = model(b_input_ids, b_input_mask)

      logits = outputs.logits

      # Move logits and labels to CPU
      logits = logits.detach().cpu().numpy()
      b_ids = b_ids.detach().cpu().numpy()
      # Store predictions
      predictions.append(logits)
      ids.append(b_ids)
      # Combine the results across the batches.
  predictions = np.concatenate(predictions, axis=0)
  ids = np.concatenate(ids,axis=0)
  # Choose the label with the highest score as our prediction.
  preds = np.argmax(predictions, axis=1).flatten()

  return ids,preds

# %% [markdown]
# ### 10) Confusion Matrix Helper Function

# %%
def show_confusion_matrix(confusion_matrix, class_names):

  cm = confusion_matrix.copy()

  cell_counts = cm.flatten()

  cm_row_norm = cm / cm.sum(axis=1)[:, np.newaxis]

  row_percentages = ["{0:.2f}".format(value) for value in cm_row_norm.flatten()]

  cell_labels = [f"{cnt}\n{per}" for cnt, per in zip(cell_counts, row_percentages)]
  cell_labels = np.asarray(cell_labels).reshape(cm.shape[0], cm.shape[1])

  df_cm = pd.DataFrame(cm_row_norm, index=class_names, columns=class_names)

  hmap = sns.heatmap(df_cm, annot=cell_labels, fmt="", cmap="Blues")
  hmap.yaxis.set_ticklabels(hmap.yaxis.get_ticklabels(), rotation=0, ha='right')
  hmap.xaxis.set_ticklabels(hmap.xaxis.get_ticklabels(), rotation=30, ha='right')
  plt.ylabel('True Sign')
  plt.xlabel('Predicted Sign');

# %% [markdown]
# ## Smart Batching of the training data

# %%
#model_name = 'sagorsarker/bangla-bert-base'

#model_name = 'google-bert/bert-base-multilingual-cased'

#model_name = 'distilbert/distilbert-base-uncased'

model_name = 'FacebookAI/xlm-roberta-base'

#
# Load the BERT tokenizer.
print(f'Loading {model_name} tokenizer...')
tokenizer = AutoTokenizer.from_pretrained(model_name, do_lower_case=False)
# Out:
# Loading FacebookAI/xlm-roberta-base tokenizer...

# %%
lengths = []
for text in train_sentences:
  lengths.append(len(text))

# %%
# Use plot styling from seaborn.
sns.set(style='darkgrid')

# Increase the plot size and font size.
sns.set(font_scale=1.5)
plt.rcParams["figure.figsize"] = (12,6)

plt.scatter(range(0, len(lengths)), lengths, marker="|")

plt.xlabel('Sample Number')
plt.ylabel('Sequence Length')
plt.title('Samples BEFORE Tokenizing')

plt.show()

# %% [markdown]
# ### Tokenizing the sequences

# %%
max_input_length = 300

# %%
full_input_ids = []
labels = []

# Tokenize all training examples
print('Tokenizing {:,} training samples...'.format(len(train_sentences)))

# Choose an interval on which to print progress updates.
update_interval = good_update_interval(total_iters=len(train_sentences), num_desired_updates=10)

# For each training example...
for text in train_sentences:

    # Report progress.
    if ((len(full_input_ids) % update_interval) == 0):
        print('  Tokenized {:,} samples.'.format(len(full_input_ids)))

    # Tokenize the sentence.
    input_ids = tokenizer.encode(text=text,
                                 add_special_tokens=True,
                                 max_length=max_input_length,
                                 truncation=True,
                                 padding=False)

    # Add the tokenized result to our list.
    full_input_ids.append(input_ids)

print('DONE.')
print('{:>10,} samples'.format(len(full_input_ids)))
# Out:
# Tokenizing 4,800 training samples...
#   Tokenized 0 samples.
#   Tokenized 500 samples.
#   Tokenized 1,000 samples.
#   Tokenized 1,500 samples.
#   Tokenized 2,000 samples.
#   Tokenized 2,500 samples.
#   Tokenized 3,000 samples.
#   Tokenized 3,500 samples.
#   Tokenized 4,000 samples.
#   Tokenized 4,500 samples.
# DONE.
#      4,800 samples

# %%
# Get all of the lengths.
unsorted_lengths = [len(x) for x in full_input_ids]

# %%
# Use plot styling from seaborn.
sns.set(style='darkgrid')

# Increase the plot size and font size.
sns.set(font_scale=1.5)
plt.rcParams["figure.figsize"] = (12,6)

plt.scatter(range(0, len(unsorted_lengths)), unsorted_lengths, marker="|")

plt.xlabel('Sample Number')
plt.ylabel('Sequence Length')
plt.title('Samples BEFORE Sorting')

plt.show()

# %%
# Sort the two lists together by the length of the input sequence.
train_samples = sorted(zip(full_input_ids, train_labels), key=lambda x: len(x[0]))

# %%
train_samples[0:5]
# Out:
# [([0, 240897, 223551, 2], 0),
#  ([0, 127205, 9591, 2], 5),
#  ([0, 127205, 47193, 2], 5),
#  ([0, 190186, 47193, 2], 0),
#  ([0, 128474, 176570, 2], 5)]

# %%
print('Shortest sample:', len(train_samples[0][0]))
print('Longest sample:', len(train_samples[-1][0]))
# Out:
# Shortest sample: 4
# Longest sample: 250

# %%
# Get the new list of lengths after sorting.
sorted_lengths = [len(s[0]) for s in train_samples]

# %%
plt.plot(range(0, len(sorted_lengths)), sorted_lengths)

plt.xlabel('Sample Number')
plt.ylabel('Sequence Length')
plt.title('Samples after Sorting')

plt.show()

# %% [markdown]
# ### Random Batch Selections

# %%
train_samples[0]
# Out:
# ([0, 240897, 223551, 2], 0)

# %%
batch_size = 16

# %%
# List of batches that we'll construct.
batch_ordered_sentences = []
batch_ordered_labels = []

print('Creating training batches of size {:}'.format(batch_size))

# Loop over all of the input samples...
while len(train_samples) > 0:

    # Report progress.
    if ((len(batch_ordered_sentences) % 100) == 0):
        print('  Selected {:,} batches.'.format(len(batch_ordered_sentences)))

    # `to_take` is our actual batch size. It will be `batch_size` until
    # we get to the last batch, which may be smaller.
    to_take = min(batch_size, len(train_samples))

    # Pick a random index in the list of remaining samples to start
    # our batch at.
    select = random.randint(0, len(train_samples) - to_take)

    # Select a contiguous batch of samples starting at `select`.
    batch = train_samples[select:(select + to_take)]

    # Each sample is a tuple--split them apart to create a separate list of
    # sequences and a list of labels for this batch.
    batch_ordered_sentences.append([s[0] for s in batch])
    batch_ordered_labels.append([s[1] for s in batch])

    # Remove these samples from the list.
    del train_samples[select:select + to_take]

print('\n  DONE - {:,} batches.'.format(len(batch_ordered_sentences)))
# Out:
# Creating training batches of size 16
#   Selected 0 batches.
#   Selected 100 batches.
#   Selected 200 batches.
#
#   DONE - 300 batches.

# %%
print(batch_ordered_sentences[0])
# Out:
# [[0, 14403, 37555, 16576, 7443, 4822, 4577, 5534, 2], [0, 44201, 9853, 2937, 50395, 2763, 16908, 53718, 2], [0, 13705, 2763, 4198, 14403, 27372, 75880, 23878, 2], [0, 6386, 8619, 2730, 21145, 26596, 8751, 189198, 2], [0, 21145, 30414, 9853, 3397, 21145, 85921, 122699, 2], [0, 6386, 7802, 2763, 140102, 4876, 176363, 4480, 2], [0, 6, 152860, 47458, 17145, 2801, 7163, 15709, 2], [0, 22540, 42854, 64963, 11622, 132526, 50442, 2801, 2], [0, 14536, 176569, 145895, 48940, 896, 18336, 89783, 2], [0, 240028, 209979, 24090, 7277, 23703, 2763, 5534, 2], [0, 6, 196776, 17145, 999, 4198, 214112, 125, 2], [0, 31527, 20423, 7802, 5534, 6, 57158, 2730, 2], [0, 168969, 47857, 53718, 117465, 91129, 8050, 5534, 2], [0, 44201, 5534, 58041, 20134, 9115, 9755, 16550, 2], [0, 37555, 11622, 71896, 44056, 125141, 14940, 67026, 2], [0, 67026, 9618, 2730, 45409, 8751, 80936, 956, 2]]

# %%
batch_ordered_labels[0]
# Out:
# [0, 5, 5, 5, 2, 0, 0, 5, 5, 5, 5, 5, 5, 3, 5, 0]

# %% [markdown]
# ### Padding

# %%
py_inputs = []
py_attn_masks = []
py_labels = []

# For each batch...
for (batch_inputs, batch_labels) in zip(batch_ordered_sentences, batch_ordered_labels):

    # New version of the batch, this time with padded sequences and now with
    # attention masks defined.
    batch_padded_inputs = []
    batch_attn_masks = []

    # First, find the longest sample in the batch.
    # Note that the sequences do currently include the special tokens!
    max_size = max([len(sen) for sen in batch_inputs])

    #print('Max size:', max_size)

    # For each input in this batch...
    for sen in batch_inputs:

        # How many pad tokens do we need to add?
        num_pads = max_size - len(sen)

        # Add `num_pads` padding tokens to the end of the sequence.
        padded_input = sen + [tokenizer.pad_token_id]*num_pads

        # Define the attention mask--it's just a `1` for every real token
        # and a `0` for every padding token.
        attn_mask = [1] * len(sen) + [0] * num_pads

        # Add the padded results to the batch.
        batch_padded_inputs.append(padded_input)
        batch_attn_masks.append(attn_mask)

    # Our batch has been padded, so we need to save this updated batch.
    # We also need the inputs to be PyTorch tensors, so we'll do that here.
    py_inputs.append(torch.tensor(batch_padded_inputs))
    py_attn_masks.append(torch.tensor(batch_attn_masks))
    py_labels.append(torch.tensor(batch_labels))

# %% [markdown]
# ### Check the number of token reductions because of smart batching

# %%
# Get the new list of lengths after sorting.

padded_lengths = []

# For each batch...
for batch in py_inputs:

    # For each sample...
    for s in batch:

        # Record its length.
        padded_lengths.append(len(s))

# Sum up the lengths to the get the total number of tokens after smart batching.
smart_token_count = np.sum(padded_lengths)

# To get the total number of tokens in the dataset using fixed padding, it's
# as simple as the number of samples times our `max_len` parameter (that we
# would pad everything to).
fixed_token_count = len(train_sentences) * max_input_length

# Calculate the percentage reduction.
prcnt_reduced = (fixed_token_count - smart_token_count) / float(fixed_token_count)

print('Total tokens:')
print('   Fixed Padding: {:,}'.format(fixed_token_count))
print('  Smart Batching: {:,}  ({:.1%} less)'.format(smart_token_count, prcnt_reduced))
# Out:
# Total tokens:
#    Fixed Padding: 1,440,000
#   Smart Batching: 75,840  (94.7% less)

# %% [markdown]
# ## Load the model configuration from the transformers library using AutoConfig

# %%
# Load the Config object, with an output configured for classification.
config = AutoConfig.from_pretrained(pretrained_model_name_or_path=model_name,
                                    num_labels=6)

print('Config type:', str(type(config)), '\n')
# Out:
# Config type: <class 'transformers.models.xlm_roberta.configuration_xlm_roberta.XLMRobertaConfig'>

# %%
model = AutoModelForSequenceClassification.from_pretrained(pretrained_model_name_or_path=model_name,config = config)
# Out:
# Some weights of XLMRobertaForSequenceClassification were not initialized from the model checkpoint at FacebookAI/xlm-roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
model.cuda()
# Out:
# XLMRobertaForSequenceClassification(
#   (roberta): XLMRobertaModel(
#     (embeddings): XLMRobertaEmbeddings(
#       (word_embeddings): Embedding(250002, 768, padding_idx=1)
#       (position_embeddings): Embedding(514, 768, padding_idx=1)
#       (token_type_embeddings): Embedding(1, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): XLMRobertaEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x XLMRobertaLayer(
#           (attention): XLMRobertaAttention(
#             (self): XLMRobertaSdpaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): XLMRobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): XLMRobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): XLMRobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (classifier): XLMRobertaClassificationHead(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#     (out_proj): Linear(in_features=768, out_features=6, bias=True)
#   )
# )

# %% [markdown]
# ## Load the model from the transformers library using AutoModel

# %%
# Load the pre-trained model for classification, passing in the `config` from
# above.
bert = AutoModel.from_pretrained(
    pretrained_model_name_or_path=model_name,
    config=config)

print('\nModel type:', str(type(bert)))
# Out:
# Model type: <class 'transformers.models.xlm_roberta.modeling_xlm_roberta.XLMRobertaModel'>

# %%
# freeze all the parameters
for param in bert.parameters():
    param.requires_grad = False

# %% [markdown]
# ## Creating a custom BERT model

# %%
# class BERT_Model(nn.Module):
#     ## defining the constructor for the class
#     def __init__(self, bert,num_labels):
#       ## calling the super class constructor
#       super(BERT_Model, self).__init__()
#       ## adding the bert layer to the model
#       self.bert = bert
#       # relu activation function
#       self.relu =  nn.ReLU()
#       # adding a dense layer to our custom model
#       self.fc1 = nn.Linear(768,512)
#       # adding another dense layer to our custom model ,i.e., the Output layer
#       self.fc2 = nn.Linear(512,num_labels)
#       # adding a softmax  activation function for our custom model's output layer
#       self.softmax = nn.LogSoftmax(dim=1)

#     #defining the forward pass
#     def forward(self, input_id, mask):
#       #pass the inputs to the model
#       outputs = self.bert(input_id,mask)

#       last_hidden_state = outputs.last_hidden_state       ## last hidden state from the model
#       pooler_output = outputs.pooler_output               ## pooler output from the model
#       ## adding a fully connected layer to the BERT model
#       x = self.fc1(pooler_output)
#       ## applying relu activation function
#       x = self.relu(x)
#       # the final output layer
#       x = self.fc2(x)
#       # apply softmax activation to our output layer
#       x = self.softmax(x)

#       return x

# %%
# print('\nLoading model ...')
# # pass the pre-trained BERT to our define architecture
# model = BERT_Model(bert,num_labels=3)

# model.cuda()

# %% [markdown]
# ## Custom Loss function

# %%
# # convert class weights to tensor
# weights= torch.tensor(class_wts,dtype=torch.float)
# weights = weights.to(device)

# # loss function
# cross_entropy  = nn.NLLLoss(weight=weights)

# %% [markdown]
# ## Loading Optimizer

# %%
# Note: AdamW is a class from the huggingface library (as opposed to pytorch)
# I believe the 'W' stands for 'Weight Decay fix"
optimizer = AdamW(model.parameters(),
                  lr = 2e-5, # This is the value Michael used.
                  eps = 1e-8 # args.adam_epsilon  - default is 1e-8.
                )
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:591: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %% [markdown]
# ## Loading lr scheduler

# %%
# Number of training epochs. I chose to train for 1 simply because the training
# time is long. More epochs may improve the model's accuracy.
epochs = 20

# Total number of training steps is [number of batches] x [number of epochs].
# Note that it's the number of *batches*, not *samples*!
total_steps = len(py_inputs) * epochs

# Create the learning rate scheduler.
scheduler = get_linear_schedule_with_warmup(optimizer,
                                            num_warmup_steps = 0, # Default value in run_glue.py
                                            num_training_steps = total_steps)

# %%
# import numpy as np
# from sklearn.preprocessing import LabelEncoder

# # Check if all validation labels are present in the training labels
# missing_labels = set(val_labels) - set(train_labels)

# if missing_labels:
#     print(f"Warning: The following labels in validation data were not seen in the training data: {missing_labels}")
#     # Optionally, you could handle missing labels here, either by filtering or adding them to the encoder.
# else:
#     # Convert validation labels using the same LabelEncoder to ensure the mapping is consistent
#     val_labels_encoded = label_encoder.transform(val_labels)

# # Now continue with the rest of the training as planned.

# %% [markdown]
# ## Training Loop

# %%
import time
import torch
from sklearn.preprocessing import LabelEncoder

# Assuming your labels are strings like 'ham' and 'spam', we first fit the LabelEncoder on the training labels
label_encoder = LabelEncoder()

# Convert training labels to numeric values
train_labels_encoded = label_encoder.fit_transform(train_labels)

# Convert validation labels using the same LabelEncoder to ensure the mapping is consistent
val_labels_encoded = label_encoder.transform(val_labels)

# Now, we can proceed with the rest of the code for training and validation.

# We'll store a number of quantities such as training and validation loss, validation accuracy, and timings.
training_stats = {
    'epoch': [],
    'train_loss': [],
    'Training Time': [],
    'val_loss': [],
    'Validation Time': [],
    'train_acc': [],
    'val_acc': []
}

# Update every `update_interval` batches.
update_interval = good_update_interval(total_iters=len(py_inputs), num_desired_updates=10)

# Measure the total training time for the whole run.
total_t0 = time.time()

# For each epoch...
for epoch_i in range(0, epochs):

    predictions = []
    true_labels = []

    print("")
    print(f'======== Epoch {epoch_i + 1} / {epochs} ========')

    if epoch_i > 0:
        # Re-shuffle the dataset into new batches
        (py_inputs, py_attn_masks, py_labels) = make_smart_batches(train_sentences, train_labels_encoded, batch_size, tokenizer, max_input_length)

    print(f'Training on {len(py_inputs):,} batches...')

    t0 = time.time()
    total_train_loss = 0

    model.train()

    for step in range(0, len(py_inputs)):

        if step % update_interval == 0 and step != 0:
            elapsed = format_time(time.time() - t0)
            remaining_sec = (time.time() - t0) / step * (len(py_inputs) - step)
            remaining = format_time(remaining_sec)
            print(f'  Batch {step:>7,} of {len(py_inputs):>7,}. Elapsed: {elapsed}. Remaining: {remaining}')

        b_input_ids = py_inputs[step].to(device)
        b_input_mask = py_attn_masks[step].to(device)
        b_labels = py_labels[step].to(device)

        model.zero_grad()
        output = model(b_input_ids, attention_mask=b_input_mask, labels=b_labels)

        #output = model(b_input_ids, token_type_ids=None, attention_mask=b_input_mask, labels=b_labels)
        loss = output.loss
        logits = output.logits

        logits = logits.detach().cpu().numpy()
        label_ids = b_labels.to('cpu').numpy()

        predictions.append(logits)
        true_labels.append(label_ids)

        total_train_loss += loss.item()

        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        optimizer.step()
        scheduler.step()

    avg_train_loss = total_train_loss / len(py_inputs)
    training_accuracy = check_accuracy(predictions, true_labels)
    training_time = format_time(time.time() - t0)

    print(f"  Average training loss: {avg_train_loss:.2f}")
    print(f"  Training Accuracy: {training_accuracy:.2f}")
    print(f"  Training epoch took: {training_time}")

    # Validation
    (py_inputs, py_attn_masks, py_labels) = make_smart_batches(val_sentences, val_labels_encoded, batch_size, tokenizer, max_input_length)
    val_loss, val_accuracy, validation_time = eval_model(model, py_inputs, py_attn_masks, py_labels)

    # (py_inputs, py_attn_masks, py_labels) = make_smart_batches(val_sentences, val_labels_encoded, batch_size,  max_input_length)
    # val_loss, val_accuracy, validation_time = eval_model(model, py_inputs, py_attn_masks, py_labels)

    print("")
    print(f"  Average validation loss: {val_loss:.2f}")
    print(f"  Validation Accuracy: {val_accuracy:.2f}")
    print(f"  Validation epoch took: {validation_time}")

    # Record all statistics from this epoch.
    training_stats['epoch'].append(epoch_i + 1)
    training_stats['train_loss'].append(avg_train_loss)
    training_stats['Training Time'].append(training_time)
    training_stats['val_loss'].append(val_loss)
    training_stats['Validation Time'].append(validation_time)
    training_stats['train_acc'].append(training_accuracy)
    training_stats['val_acc'].append(val_accuracy)

print("")
print(f"Training complete! Total training took {format_time(time.time() - total_t0)} (h:mm:ss)")
# Out:
# ======== Epoch 1 / 20 ========
# Training on 300 batches...
#   Batch      30 of     300. Elapsed: 0:00:05. Remaining: 0:00:42
#   Batch      60 of     300. Elapsed: 0:00:10. Remaining: 0:00:41
#   Batch      90 of     300. Elapsed: 0:00:15. Remaining: 0:00:35
#   Batch     120 of     300. Elapsed: 0:00:20. Remaining: 0:00:30
#   Batch     150 of     300. Elapsed: 0:00:25. Remaining: 0:00:25
#   Batch     180 of     300. Elapsed: 0:00:30. Remaining: 0:00:20
#   Batch     210 of     300. Elapsed: 0:00:34. Remaining: 0:00:14
#   Batch     240 of     300. Elapsed: 0:00:38. Remaining: 0:00:09
#   Batch     270 of     300. Elapsed: 0:00:42. Remaining: 0:00:05
#   Average training loss: 1.26
#   Training Accuracy: 0.47
#   Training epoch took: 0:00:47
# Creating Smart Batches from 600 examples with batch size 16...
#
# Tokenizing 600 samples...
#   Tokenized 0 samples.
#   Tokenized 60 samples.
#   Tokenized 120 samples.
#   Tokenized 180 samples.
#   Tokenized 240 samples.
#   Tokenized 300 samples.
#   Tokenized 360 samples.
#   Tokenized 420 samples.
#   Tokenized 480 samples.
#   Tokenized 540 samples.
# DONE.
#        600 samples
#
#        600 samples after sorting
#
# Creating batches of size 16...
#
#   DONE - Selected 38 batches.
#
# Padding out sequences within each batch...
#   DONE.
# Doing validation on 38 sentences...
#   Batch       4  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:01
#   Batch       8  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      12  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      16  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      20  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      24  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      28  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      32  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      36  of       38.    Elapsed: 0:00:01.  Remaining: 0:00:00
#
#   Average validation loss: 1.13
#   Validation Accuracy: 0.57
#   Validation epoch took: 0:00:01
#
# ======== Epoch 2 / 20 ========
# Creating Smart Batches from 4,800 examples with batch size 16...
#
# Tokenizing 4,800 samples...
#   Tokenized 0 samples.
#   Tokenized 500 samples.
#   Tokenized 1,000 samples.
#   Tokenized 1,500 samples.
#   Tokenized 2,000 samples.
#   Tokenized 2,500 samples.
#   Tokenized 3,000 samples.
#   Tokenized 3,500 samples.
#   Tokenized 4,000 samples.
#   Tokenized 4,500 samples.
# DONE.
#      4,800 samples
#
#      4,800 samples after sorting
#
# Creating batches of size 16...
#
#   DONE - Selected 300 batches.
#
# Padding out sequences within each batch...
#   DONE.
# Training on 300 batches...
#   Batch      30 of     300. Elapsed: 0:00:04. Remaining: 0:00:37
#   Batch      60 of     300. Elapsed: 0:00:08. Remaining: 0:00:32
#   Batch      90 of     300. Elapsed: 0:00:12. Remaining: 0:00:28
#   Batch     120 of     300. Elapsed: 0:00:16. Remaining: 0:00:24
#   Batch     150 of     300. Elapsed: 0:00:20. Remaining: 0:00:20
#   Batch     180 of     300. Elapsed: 0:00:24. Remaining: 0:00:16
#   Batch     210 of     300. Elapsed: 0:00:29. Remaining: 0:00:12
#   Batch     240 of     300. Elapsed: 0:00:33. Remaining: 0:00:08
#   Batch     270 of     300. Elapsed: 0:00:37. Remaining: 0:00:04
#   Average training loss: 1.04
#   Training Accuracy: 0.59
#   Training epoch took: 0:00:42
# Creating Smart Batches from 600 examples with batch size 16...
#
# Tokenizing 600 samples...
#   Tokenized 0 samples.
#   Tokenized 60 samples.
#   Tokenized 120 samples.
#   Tokenized 180 samples.
#   Tokenized 240 samples.
#   Tokenized 300 samples.
#   Tokenized 360 samples.
#   Tokenized 420 samples.
#   Tokenized 480 samples.
#   Tokenized 540 samples.
# DONE.
#        600 samples
#
#        600 samples after sorting
#
# Creating batches of size 16...
#
#   DONE - Selected 38 batches.
#
# Padding out sequences within each batch...
#   DONE.
# Doing validation on 38 sentences...
#   Batch       4  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch       8  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      12  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      16  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      20  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      24  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      28  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      32  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      36  of       38.    Elapsed: 0:00:01.  Remaining: 0:00:00
#
#   Average validation loss: 1.05
#   Validation Accuracy: 0.59
#   Validation epoch took: 0:00:01
#
# ======== Epoch 3 / 20 ========
# Creating Smart Batches from 4,800 examples with batch size 16...
#
# Tokenizing 4,800 samples...
#   Tokenized 0 samples.
#   Tokenized 500 samples.
#   Tokenized 1,000 samples.
#   Tokenized 1,500 samples.
#   Tokenized 2,000 samples.
#   Tokenized 2,500 samples.
#   Tokenized 3,000 samples.
#   Tokenized 3,500 samples.
#   Tokenized 4,000 samples.
#   Tokenized 4,500 samples.
# DONE.
#      4,800 samples
#
#      4,800 samples after sorting
#
# Creating batches of size 16...
#
#   DONE - Selected 300 batches.
#
# Padding out sequences within each batch...
#   DONE.
# Training on 300 batches...
#   Batch      30 of     300. Elapsed: 0:00:04. Remaining: 0:00:36
#   Batch      60 of     300. Elapsed: 0:00:08. Remaining: 0:00:32
#   Batch      90 of     300. Elapsed: 0:00:12. Remaining: 0:00:29
#   Batch     120 of     300. Elapsed: 0:00:16. Remaining: 0:00:25
#   Batch     150 of     300. Elapsed: 0:00:21. Remaining: 0:00:21
#   Batch     180 of     300. Elapsed: 0:00:25. Remaining: 0:00:17
#   Batch     210 of     300. Elapsed: 0:00:29. Remaining: 0:00:12
#   Batch     240 of     300. Elapsed: 0:00:33. Remaining: 0:00:08
#   Batch     270 of     300. Elapsed: 0:00:38. Remaining: 0:00:04
#   Average training loss: 0.92
#   Training Accuracy: 0.65
#   Training epoch took: 0:00:43
# Creating Smart Batches from 600 examples with batch size 16...
#
# Tokenizing 600 samples...
#   Tokenized 0 samples.
#   Tokenized 60 samples.
#   Tokenized 120 samples.
#   Tokenized 180 samples.
#   Tokenized 240 samples.
#   Tokenized 300 samples.
#   Tokenized 360 samples.
#   Tokenized 420 samples.
#   Tokenized 480 samples.
#   Tokenized 540 samples.
# DONE.
#        600 samples
#
#        600 samples after sorting
#
# Creating batches of size 16...
#
#   DONE - Selected 38 batches.
#
# Padding out sequences within each batch...
#   DONE.
# Doing validation on 38 sentences...
#   Batch       4  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:01
#   Batch       8  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:01
#   Batch      12  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      16  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      20  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      24  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      28  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      32  of       38.    Elapsed: 0:00:01.  Remaining: 0:00:00
#   Batch      36  of       38.    Elapsed: 0:00:01.  Remaining: 0:00:00
#
#   Average validation loss: 1.03
#   Validation Accuracy: 0.61
#   Validation epoch took: 0:00:01
#
# ======== Epoch 4 / 20 ========
# Creating Smart Batches from 4,800 examples with batch size 16...
#
# Tokenizing 4,800 samples...
#   Tokenized 0 samples.
#   Tokenized 500 samples.
#   Tokenized 1,000 samples.
#   Tokenized 1,500 samples.
#   Tokenized 2,000 samples.
#   Tokenized 2,500 samples.
#   Tokenized 3,000 samples.
#   Tokenized 3,500 samples.
#   Tokenized 4,000 samples.
#   Tokenized 4,500 samples.
# DONE.
#      4,800 samples
#
#      4,800 samples after sorting
#
# Creating batches of size 16...
#
#   DONE - Selected 300 batches.
#
# Padding out sequences within each batch...
#   DONE.
# Training on 300 batches...
#   Batch      30 of     300. Elapsed: 0:00:05. Remaining: 0:00:45
#   Batch      60 of     300. Elapsed: 0:00:09. Remaining: 0:00:36
#   Batch      90 of     300. Elapsed: 0:00:14. Remaining: 0:00:33
#   Batch     120 of     300. Elapsed: 0:00:18. Remaining: 0:00:28
#   Batch     150 of     300. Elapsed: 0:00:23. Remaining: 0:00:23
#   Batch     180 of     300. Elapsed: 0:00:27. Remaining: 0:00:18
#   Batch     210 of     300. Elapsed: 0:00:31. Remaining: 0:00:13
#   Batch     240 of     300. Elapsed: 0:00:35. Remaining: 0:00:09
#   Batch     270 of     300. Elapsed: 0:00:39. Remaining: 0:00:04
#   Average training loss: 0.80
#   Training Accuracy: 0.71
#   Training epoch took: 0:00:43
# Creating Smart Batches from 600 examples with batch size 16...
#
# Tokenizing 600 samples...
#   Tokenized 0 samples.
#   Tokenized 60 samples.
#   Tokenized 120 samples.
#   Tokenized 180 samples.
#   Tokenized 240 samples.
#   Tokenized 300 samples.
#   Tokenized 360 samples.
#   Tokenized 420 samples.
#   Tokenized 480 samples.
#   Tokenized 540 samples.
# DONE.
#        600 samples
#
#        600 samples after sorting
#
# Creating batches of size 16...
#
#   DONE - Selected 38 batches.
#
# Padding out sequences within each batch...
#   DONE.
# Doing validation on 38 sentences...
#   Batch       4  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch       8  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      12  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      16  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      20  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      24  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      28  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      32  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      36  of       38.    Elapsed: 0:00:01.  Remaining: 0:00:00
#
#   Average validation loss: 1.08
#   Validation Accuracy: 0.60
#   Validation epoch took: 0:00:01
#
# ======== Epoch 5 / 20 ========
# Creating Smart Batches from 4,800 examples with batch size 16...
#
# Tokenizing 4,800 samples...
#   Tokenized 0 samples.
#   Tokenized 500 samples.
#   Tokenized 1,000 samples.
#   Tokenized 1,500 samples.
#   Tokenized 2,000 samples.
#   Tokenized 2,500 samples.
#   Tokenized 3,000 samples.
#   Tokenized 3,500 samples.
#   Tokenized 4,000 samples.
#   Tokenized 4,500 samples.
# DONE.
#      4,800 samples
#
#      4,800 samples after sorting
#
# Creating batches of size 16...
#
#   DONE - Selected 300 batches.
#
# Padding out sequences within each batch...
#   DONE.
# Training on 300 batches...
#   Batch      30 of     300. Elapsed: 0:00:04. Remaining: 0:00:36
#   Batch      60 of     300. Elapsed: 0:00:08. Remaining: 0:00:32
#   Batch      90 of     300. Elapsed: 0:00:12. Remaining: 0:00:28
#   Batch     120 of     300. Elapsed: 0:00:16. Remaining: 0:00:25
#   Batch     150 of     300. Elapsed: 0:00:21. Remaining: 0:00:21
#   Batch     180 of     300. Elapsed: 0:00:25. Remaining: 0:00:17
#   Batch     210 of     300. Elapsed: 0:00:29. Remaining: 0:00:13
#   Batch     240 of     300. Elapsed: 0:00:34. Remaining: 0:00:08
#   Batch     270 of     300. Elapsed: 0:00:38. Remaining: 0:00:04
#   Average training loss: 0.70
#   Training Accuracy: 0.74
#   Training epoch took: 0:00:43
# Creating Smart Batches from 600 examples with batch size 16...
#
# Tokenizing 600 samples...
#   Tokenized 0 samples.
#   Tokenized 60 samples.
#   Tokenized 120 samples.
#   Tokenized 180 samples.
#   Tokenized 240 samples.
#   Tokenized 300 samples.
#   Tokenized 360 samples.
#   Tokenized 420 samples.
#   Tokenized 480 samples.
#   Tokenized 540 samples.
# DONE.
#        600 samples
#
#        600 samples after sorting
#
# Creating batches of size 16...
#
#   DONE - Selected 38 batches.
#
# Padding out sequences within each batch...
#   DONE.
# Doing validation on 38 sentences...
#   Batch       4  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:01
#   Batch       8  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      12  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      16  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      20  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      24  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      28  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      32  of       38.    Elapsed: 0:00:01.  Remaining: 0:00:00
#   Batch      36  of       38.    Elapsed: 0:00:01.  Remaining: 0:00:00
#
#   Average validation loss: 1.14
#   Validation Accuracy: 0.60
#   Validation epoch took: 0:00:01
#
# ======== Epoch 6 / 20 ========
# Creating Smart Batches from 4,800 examples with batch size 16...
#
# Tokenizing 4,800 samples...
#   Tokenized 0 samples.
#   Tokenized 500 samples.
#   Tokenized 1,000 samples.
#   Tokenized 1,500 samples.
#   Tokenized 2,000 samples.
#   Tokenized 2,500 samples.
#   Tokenized 3,000 samples.
#   Tokenized 3,500 samples.
#   Tokenized 4,000 samples.
#   Tokenized 4,500 samples.
# DONE.
#      4,800 samples
#
#      4,800 samples after sorting
#
# Creating batches of size 16...
#
#   DONE - Selected 300 batches.
#
# Padding out sequences within each batch...
#   DONE.
# Training on 300 batches...
#   Batch      30 of     300. Elapsed: 0:00:04. Remaining: 0:00:38
#   Batch      60 of     300. Elapsed: 0:00:08. Remaining: 0:00:33
#   Batch      90 of     300. Elapsed: 0:00:13. Remaining: 0:00:29
#   Batch     120 of     300. Elapsed: 0:00:17. Remaining: 0:00:25
#   Batch     150 of     300. Elapsed: 0:00:21. Remaining: 0:00:21
#   Batch     180 of     300. Elapsed: 0:00:25. Remaining: 0:00:17
#   Batch     210 of     300. Elapsed: 0:00:29. Remaining: 0:00:12
#   Batch     240 of     300. Elapsed: 0:00:33. Remaining: 0:00:08
#   Batch     270 of     300. Elapsed: 0:00:37. Remaining: 0:00:04
#   Average training loss: 0.62
#   Training Accuracy: 0.80
#   Training epoch took: 0:00:42
# Creating Smart Batches from 600 examples with batch size 16...
#
# Tokenizing 600 samples...
#   Tokenized 0 samples.
#   Tokenized 60 samples.
#   Tokenized 120 samples.
#   Tokenized 180 samples.
#   Tokenized 240 samples.
#   Tokenized 300 samples.
#   Tokenized 360 samples.
#   Tokenized 420 samples.
#   Tokenized 480 samples.
#   Tokenized 540 samples.
# DONE.
#        600 samples
#
#        600 samples after sorting
#
# Creating batches of size 16...
#
#   DONE - Selected 38 batches.
#
# Padding out sequences within each batch...
#   DONE.
# Doing validation on 38 sentences...
#   Batch       4  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch       8  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      12  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      16  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      20  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      24  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      28  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      32  of       38.    Elapsed: 0:00:01.  Remaining: 0:00:00
#   Batch      36  of       38.    Elapsed: 0:00:01.  Remaining: 0:00:00
#
#   Average validation loss: 1.15
#   Validation Accuracy: 0.59
#   Validation epoch took: 0:00:01
#
# ======== Epoch 7 / 20 ========
# Creating Smart Batches from 4,800 examples with batch size 16...
#
# Tokenizing 4,800 samples...
#   Tokenized 0 samples.
#   Tokenized 500 samples.
#   Tokenized 1,000 samples.
#   Tokenized 1,500 samples.
#   Tokenized 2,000 samples.
#   Tokenized 2,500 samples.
#   Tokenized 3,000 samples.
#   Tokenized 3,500 samples.
#   Tokenized 4,000 samples.
#   Tokenized 4,500 samples.
# DONE.
#      4,800 samples
#
#      4,800 samples after sorting
#
# Creating batches of size 16...
#
#   DONE - Selected 300 batches.
#
# Padding out sequences within each batch...
#   DONE.
# Training on 300 batches...
#   Batch      30 of     300. Elapsed: 0:00:04. Remaining: 0:00:36
#   Batch      60 of     300. Elapsed: 0:00:08. Remaining: 0:00:32
#   Batch      90 of     300. Elapsed: 0:00:12. Remaining: 0:00:29
#   Batch     120 of     300. Elapsed: 0:00:16. Remaining: 0:00:25
#   Batch     150 of     300. Elapsed: 0:00:20. Remaining: 0:00:20
#   Batch     180 of     300. Elapsed: 0:00:25. Remaining: 0:00:16
#   Batch     210 of     300. Elapsed: 0:00:29. Remaining: 0:00:12
#   Batch     240 of     300. Elapsed: 0:00:33. Remaining: 0:00:08
#   Batch     270 of     300. Elapsed: 0:00:37. Remaining: 0:00:04
#   Average training loss: 0.53
#   Training Accuracy: 0.82
#   Training epoch took: 0:00:42
# Creating Smart Batches from 600 examples with batch size 16...
#
# Tokenizing 600 samples...
#   Tokenized 0 samples.
#   Tokenized 60 samples.
#   Tokenized 120 samples.
#   Tokenized 180 samples.
#   Tokenized 240 samples.
#   Tokenized 300 samples.
#   Tokenized 360 samples.
#   Tokenized 420 samples.
#   Tokenized 480 samples.
#   Tokenized 540 samples.
# DONE.
#        600 samples
#
#        600 samples after sorting
#
# Creating batches of size 16...
#
#   DONE - Selected 38 batches.
#
# Padding out sequences within each batch...
#   DONE.
# Doing validation on 38 sentences...
#   Batch       4  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:01
#   Batch       8  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:01
#   Batch      12  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      16  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      20  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      24  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      28  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      32  of       38.    Elapsed: 0:00:01.  Remaining: 0:00:00
#   Batch      36  of       38.    Elapsed: 0:00:01.  Remaining: 0:00:00
#
#   Average validation loss: 1.19
#   Validation Accuracy: 0.64
#   Validation epoch took: 0:00:01
#
# ======== Epoch 8 / 20 ========
# Creating Smart Batches from 4,800 examples with batch size 16...
#
# Tokenizing 4,800 samples...
#   Tokenized 0 samples.
#   Tokenized 500 samples.
#   Tokenized 1,000 samples.
#   Tokenized 1,500 samples.
#   Tokenized 2,000 samples.
#   Tokenized 2,500 samples.
#   Tokenized 3,000 samples.
#   Tokenized 3,500 samples.
#   Tokenized 4,000 samples.
#   Tokenized 4,500 samples.
# DONE.
#      4,800 samples
#
#      4,800 samples after sorting
#
# Creating batches of size 16...
#
#   DONE - Selected 300 batches.
#
# Padding out sequences within each batch...
#   DONE.
# Training on 300 batches...
#   Batch      30 of     300. Elapsed: 0:00:04. Remaining: 0:00:40
#   Batch      60 of     300. Elapsed: 0:00:09. Remaining: 0:00:35
#   Batch      90 of     300. Elapsed: 0:00:13. Remaining: 0:00:29
#   Batch     120 of     300. Elapsed: 0:00:17. Remaining: 0:00:25
#   Batch     150 of     300. Elapsed: 0:00:21. Remaining: 0:00:21
#   Batch     180 of     300. Elapsed: 0:00:25. Remaining: 0:00:17
#   Batch     210 of     300. Elapsed: 0:00:29. Remaining: 0:00:12
#   Batch     240 of     300. Elapsed: 0:00:33. Remaining: 0:00:08
#   Batch     270 of     300. Elapsed: 0:00:38. Remaining: 0:00:04
#   Average training loss: 0.45
#   Training Accuracy: 0.85
#   Training epoch took: 0:00:42
# Creating Smart Batches from 600 examples with batch size 16...
#
# Tokenizing 600 samples...
#   Tokenized 0 samples.
#   Tokenized 60 samples.
#   Tokenized 120 samples.
#   Tokenized 180 samples.
#   Tokenized 240 samples.
#   Tokenized 300 samples.
#   Tokenized 360 samples.
#   Tokenized 420 samples.
#   Tokenized 480 samples.
#   Tokenized 540 samples.
# DONE.
#        600 samples
#
#        600 samples after sorting
#
# Creating batches of size 16...
#
#   DONE - Selected 38 batches.
#
# Padding out sequences within each batch...
#   DONE.
# Doing validation on 38 sentences...
#   Batch       4  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:01
#   Batch       8  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      12  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      16  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      20  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      24  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      28  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      32  of       38.    Elapsed: 0:00:01.  Remaining: 0:00:00
#   Batch      36  of       38.    Elapsed: 0:00:01.  Remaining: 0:00:00
#
#   Average validation loss: 1.28
#   Validation Accuracy: 0.64
#   Validation epoch took: 0:00:01
#
# ======== Epoch 9 / 20 ========
# Creating Smart Batches from 4,800 examples with batch size 16...
#
# Tokenizing 4,800 samples...
#   Tokenized 0 samples.
#   Tokenized 500 samples.
#   Tokenized 1,000 samples.
#   Tokenized 1,500 samples.
#   Tokenized 2,000 samples.
#   Tokenized 2,500 samples.
#   Tokenized 3,000 samples.
#   Tokenized 3,500 samples.
#   Tokenized 4,000 samples.
#   Tokenized 4,500 samples.
# DONE.
#      4,800 samples
#
#      4,800 samples after sorting
#
# Creating batches of size 16...
#
#   DONE - Selected 300 batches.
#
# Padding out sequences within each batch...
#   DONE.
# Training on 300 batches...
#   Batch      30 of     300. Elapsed: 0:00:05. Remaining: 0:00:44
#   Batch      60 of     300. Elapsed: 0:00:09. Remaining: 0:00:36
#   Batch      90 of     300. Elapsed: 0:00:13. Remaining: 0:00:31
#   Batch     120 of     300. Elapsed: 0:00:17. Remaining: 0:00:26
#   Batch     150 of     300. Elapsed: 0:00:21. Remaining: 0:00:21
#   Batch     180 of     300. Elapsed: 0:00:25. Remaining: 0:00:17
#   Batch     210 of     300. Elapsed: 0:00:30. Remaining: 0:00:13
#   Batch     240 of     300. Elapsed: 0:00:34. Remaining: 0:00:08
#   Batch     270 of     300. Elapsed: 0:00:38. Remaining: 0:00:04
#   Average training loss: 0.38
#   Training Accuracy: 0.87
#   Training epoch took: 0:00:42
# Creating Smart Batches from 600 examples with batch size 16...
#
# Tokenizing 600 samples...
#   Tokenized 0 samples.
#   Tokenized 60 samples.
#   Tokenized 120 samples.
#   Tokenized 180 samples.
#   Tokenized 240 samples.
#   Tokenized 300 samples.
#   Tokenized 360 samples.
#   Tokenized 420 samples.
#   Tokenized 480 samples.
#   Tokenized 540 samples.
# DONE.
#        600 samples
#
#        600 samples after sorting
#
# Creating batches of size 16...
#
#   DONE - Selected 38 batches.
#
# Padding out sequences within each batch...
#   DONE.
# Doing validation on 38 sentences...
#   Batch       4  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch       8  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      12  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      16  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      20  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      24  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      28  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      32  of       38.    Elapsed: 0:00:01.  Remaining: 0:00:00
#   Batch      36  of       38.    Elapsed: 0:00:01.  Remaining: 0:00:00
#
#   Average validation loss: 1.43
#   Validation Accuracy: 0.61
#   Validation epoch took: 0:00:01
#
# ======== Epoch 10 / 20 ========
# Creating Smart Batches from 4,800 examples with batch size 16...
#
# Tokenizing 4,800 samples...
#   Tokenized 0 samples.
#   Tokenized 500 samples.
#   Tokenized 1,000 samples.
#   Tokenized 1,500 samples.
#   Tokenized 2,000 samples.
#   Tokenized 2,500 samples.
#   Tokenized 3,000 samples.
#   Tokenized 3,500 samples.
#   Tokenized 4,000 samples.
#   Tokenized 4,500 samples.
# DONE.
#      4,800 samples
#
#      4,800 samples after sorting
#
# Creating batches of size 16...
#
#   DONE - Selected 300 batches.
#
# Padding out sequences within each batch...
#   DONE.
# Training on 300 batches...
#   Batch      30 of     300. Elapsed: 0:00:04. Remaining: 0:00:37
#   Batch      60 of     300. Elapsed: 0:00:08. Remaining: 0:00:34
#   Batch      90 of     300. Elapsed: 0:00:13. Remaining: 0:00:29
#   Batch     120 of     300. Elapsed: 0:00:17. Remaining: 0:00:26
#   Batch     150 of     300. Elapsed: 0:00:22. Remaining: 0:00:22
#   Batch     180 of     300. Elapsed: 0:00:26. Remaining: 0:00:17
#   Batch     210 of     300. Elapsed: 0:00:30. Remaining: 0:00:13
#   Batch     240 of     300. Elapsed: 0:00:34. Remaining: 0:00:08
#   Batch     270 of     300. Elapsed: 0:00:38. Remaining: 0:00:04
#   Average training loss: 0.32
#   Training Accuracy: 0.90
#   Training epoch took: 0:00:42
# Creating Smart Batches from 600 examples with batch size 16...
#
# Tokenizing 600 samples...
#   Tokenized 0 samples.
#   Tokenized 60 samples.
#   Tokenized 120 samples.
#   Tokenized 180 samples.
#   Tokenized 240 samples.
#   Tokenized 300 samples.
#   Tokenized 360 samples.
#   Tokenized 420 samples.
#   Tokenized 480 samples.
#   Tokenized 540 samples.
# DONE.
#        600 samples
#
#        600 samples after sorting
#
# Creating batches of size 16...
#
#   DONE - Selected 38 batches.
#
# Padding out sequences within each batch...
#   DONE.
# Doing validation on 38 sentences...
#   Batch       4  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:01
#   Batch       8  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      12  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      16  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      20  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      24  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      28  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      32  of       38.    Elapsed: 0:00:01.  Remaining: 0:00:00
#   Batch      36  of       38.    Elapsed: 0:00:01.  Remaining: 0:00:00
#
#   Average validation loss: 1.50
#   Validation Accuracy: 0.62
#   Validation epoch took: 0:00:01
#
# ======== Epoch 11 / 20 ========
# Creating Smart Batches from 4,800 examples with batch size 16...
#
# Tokenizing 4,800 samples...
#   Tokenized 0 samples.
#   Tokenized 500 samples.
#   Tokenized 1,000 samples.
#   Tokenized 1,500 samples.
#   Tokenized 2,000 samples.
#   Tokenized 2,500 samples.
#   Tokenized 3,000 samples.
#   Tokenized 3,500 samples.
#   Tokenized 4,000 samples.
#   Tokenized 4,500 samples.
# DONE.
#      4,800 samples
#
#      4,800 samples after sorting
#
# Creating batches of size 16...
#
#   DONE - Selected 300 batches.
#
# Padding out sequences within each batch...
#   DONE.
# Training on 300 batches...
#   Batch      30 of     300. Elapsed: 0:00:04. Remaining: 0:00:38
#   Batch      60 of     300. Elapsed: 0:00:08. Remaining: 0:00:33
#   Batch      90 of     300. Elapsed: 0:00:12. Remaining: 0:00:29
#   Batch     120 of     300. Elapsed: 0:00:17. Remaining: 0:00:25
#   Batch     150 of     300. Elapsed: 0:00:21. Remaining: 0:00:21
#   Batch     180 of     300. Elapsed: 0:00:25. Remaining: 0:00:17
#   Batch     210 of     300. Elapsed: 0:00:29. Remaining: 0:00:13
#   Batch     240 of     300. Elapsed: 0:00:33. Remaining: 0:00:08
#   Batch     270 of     300. Elapsed: 0:00:38. Remaining: 0:00:04
#   Average training loss: 0.27
#   Training Accuracy: 0.91
#   Training epoch took: 0:00:43
# Creating Smart Batches from 600 examples with batch size 16...
#
# Tokenizing 600 samples...
#   Tokenized 0 samples.
#   Tokenized 60 samples.
#   Tokenized 120 samples.
#   Tokenized 180 samples.
#   Tokenized 240 samples.
#   Tokenized 300 samples.
#   Tokenized 360 samples.
#   Tokenized 420 samples.
#   Tokenized 480 samples.
#   Tokenized 540 samples.
# DONE.
#        600 samples
#
#        600 samples after sorting
#
# Creating batches of size 16...
#
#   DONE - Selected 38 batches.
#
# Padding out sequences within each batch...
#   DONE.
# Doing validation on 38 sentences...
#   Batch       4  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:01
#   Batch       8  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      12  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      16  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      20  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      24  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      28  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      32  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      36  of       38.    Elapsed: 0:00:01.  Remaining: 0:00:00
#
#   Average validation loss: 1.68
#   Validation Accuracy: 0.65
#   Validation epoch took: 0:00:01
#
# ======== Epoch 12 / 20 ========
# Creating Smart Batches from 4,800 examples with batch size 16...
#
# Tokenizing 4,800 samples...
#   Tokenized 0 samples.
#   Tokenized 500 samples.
#   Tokenized 1,000 samples.
#   Tokenized 1,500 samples.
#   Tokenized 2,000 samples.
#   Tokenized 2,500 samples.
#   Tokenized 3,000 samples.
#   Tokenized 3,500 samples.
#   Tokenized 4,000 samples.
#   Tokenized 4,500 samples.
# DONE.
#      4,800 samples
#
#      4,800 samples after sorting
#
# Creating batches of size 16...
#
#   DONE - Selected 300 batches.
#
# Padding out sequences within each batch...
#   DONE.
# Training on 300 batches...
#   Batch      30 of     300. Elapsed: 0:00:04. Remaining: 0:00:37
#   Batch      60 of     300. Elapsed: 0:00:08. Remaining: 0:00:33
#   Batch      90 of     300. Elapsed: 0:00:13. Remaining: 0:00:29
#   Batch     120 of     300. Elapsed: 0:00:17. Remaining: 0:00:25
#   Batch     150 of     300. Elapsed: 0:00:21. Remaining: 0:00:21
#   Batch     180 of     300. Elapsed: 0:00:25. Remaining: 0:00:17
#   Batch     210 of     300. Elapsed: 0:00:29. Remaining: 0:00:12
#   Batch     240 of     300. Elapsed: 0:00:33. Remaining: 0:00:08
#   Batch     270 of     300. Elapsed: 0:00:38. Remaining: 0:00:04
#   Average training loss: 0.23
#   Training Accuracy: 0.93
#   Training epoch took: 0:00:42
# Creating Smart Batches from 600 examples with batch size 16...
#
# Tokenizing 600 samples...
#   Tokenized 0 samples.
#   Tokenized 60 samples.
#   Tokenized 120 samples.
#   Tokenized 180 samples.
#   Tokenized 240 samples.
#   Tokenized 300 samples.
#   Tokenized 360 samples.
#   Tokenized 420 samples.
#   Tokenized 480 samples.
#   Tokenized 540 samples.
# DONE.
#        600 samples
#
#        600 samples after sorting
#
# Creating batches of size 16...
#
#   DONE - Selected 38 batches.
#
# Padding out sequences within each batch...
#   DONE.
# Doing validation on 38 sentences...
#   Batch       4  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch       8  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      12  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      16  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      20  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      24  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      28  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      32  of       38.    Elapsed: 0:00:01.  Remaining: 0:00:00
#   Batch      36  of       38.    Elapsed: 0:00:01.  Remaining: 0:00:00
#
#   Average validation loss: 1.77
#   Validation Accuracy: 0.64
#   Validation epoch took: 0:00:01
#
# ======== Epoch 13 / 20 ========
# Creating Smart Batches from 4,800 examples with batch size 16...
#
# Tokenizing 4,800 samples...
#   Tokenized 0 samples.
#   Tokenized 500 samples.
#   Tokenized 1,000 samples.
#   Tokenized 1,500 samples.
#   Tokenized 2,000 samples.
#   Tokenized 2,500 samples.
#   Tokenized 3,000 samples.
#   Tokenized 3,500 samples.
#   Tokenized 4,000 samples.
#   Tokenized 4,500 samples.
# DONE.
#      4,800 samples
#
#      4,800 samples after sorting
#
# Creating batches of size 16...
#
#   DONE - Selected 300 batches.
#
# Padding out sequences within each batch...
#   DONE.
# Training on 300 batches...
#   Batch      30 of     300. Elapsed: 0:00:04. Remaining: 0:00:37
#   Batch      60 of     300. Elapsed: 0:00:08. Remaining: 0:00:33
#   Batch      90 of     300. Elapsed: 0:00:12. Remaining: 0:00:28
#   Batch     120 of     300. Elapsed: 0:00:16. Remaining: 0:00:24
#   Batch     150 of     300. Elapsed: 0:00:20. Remaining: 0:00:20
#   Batch     180 of     300. Elapsed: 0:00:25. Remaining: 0:00:16
#   Batch     210 of     300. Elapsed: 0:00:29. Remaining: 0:00:13
#   Batch     240 of     300. Elapsed: 0:00:34. Remaining: 0:00:08
#   Batch     270 of     300. Elapsed: 0:00:38. Remaining: 0:00:04
#   Average training loss: 0.20
#   Training Accuracy: 0.94
#   Training epoch took: 0:00:42
# Creating Smart Batches from 600 examples with batch size 16...
#
# Tokenizing 600 samples...
#   Tokenized 0 samples.
#   Tokenized 60 samples.
#   Tokenized 120 samples.
#   Tokenized 180 samples.
#   Tokenized 240 samples.
#   Tokenized 300 samples.
#   Tokenized 360 samples.
#   Tokenized 420 samples.
#   Tokenized 480 samples.
#   Tokenized 540 samples.
# DONE.
#        600 samples
#
#        600 samples after sorting
#
# Creating batches of size 16...
#
#   DONE - Selected 38 batches.
#
# Padding out sequences within each batch...
#   DONE.
# Doing validation on 38 sentences...
#   Batch       4  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch       8  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      12  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      16  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      20  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      24  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      28  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      32  of       38.    Elapsed: 0:00:01.  Remaining: 0:00:00
#   Batch      36  of       38.    Elapsed: 0:00:01.  Remaining: 0:00:00
#
#   Average validation loss: 1.97
#   Validation Accuracy: 0.63
#   Validation epoch took: 0:00:01
#
# ======== Epoch 14 / 20 ========
# Creating Smart Batches from 4,800 examples with batch size 16...
#
# Tokenizing 4,800 samples...
#   Tokenized 0 samples.
#   Tokenized 500 samples.
#   Tokenized 1,000 samples.
#   Tokenized 1,500 samples.
#   Tokenized 2,000 samples.
#   Tokenized 2,500 samples.
#   Tokenized 3,000 samples.
#   Tokenized 3,500 samples.
#   Tokenized 4,000 samples.
#   Tokenized 4,500 samples.
# DONE.
#      4,800 samples
#
#      4,800 samples after sorting
#
# Creating batches of size 16...
#
#   DONE - Selected 300 batches.
#
# Padding out sequences within each batch...
#   DONE.
# Training on 300 batches...
#   Batch      30 of     300. Elapsed: 0:00:04. Remaining: 0:00:37
#   Batch      60 of     300. Elapsed: 0:00:08. Remaining: 0:00:33
#   Batch      90 of     300. Elapsed: 0:00:12. Remaining: 0:00:29
#   Batch     120 of     300. Elapsed: 0:00:16. Remaining: 0:00:25
#   Batch     150 of     300. Elapsed: 0:00:21. Remaining: 0:00:21
#   Batch     180 of     300. Elapsed: 0:00:25. Remaining: 0:00:17
#   Batch     210 of     300. Elapsed: 0:00:29. Remaining: 0:00:12
#   Batch     240 of     300. Elapsed: 0:00:33. Remaining: 0:00:08
#   Batch     270 of     300. Elapsed: 0:00:38. Remaining: 0:00:04
#   Average training loss: 0.17
#   Training Accuracy: 0.95
#   Training epoch took: 0:00:42
# Creating Smart Batches from 600 examples with batch size 16...
#
# Tokenizing 600 samples...
#   Tokenized 0 samples.
#   Tokenized 60 samples.
#   Tokenized 120 samples.
#   Tokenized 180 samples.
#   Tokenized 240 samples.
#   Tokenized 300 samples.
#   Tokenized 360 samples.
#   Tokenized 420 samples.
#   Tokenized 480 samples.
#   Tokenized 540 samples.
# DONE.
#        600 samples
#
#        600 samples after sorting
#
# Creating batches of size 16...
#
#   DONE - Selected 38 batches.
#
# Padding out sequences within each batch...
#   DONE.
# Doing validation on 38 sentences...
#   Batch       4  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch       8  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      12  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      16  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      20  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      24  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      28  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      32  of       38.    Elapsed: 0:00:01.  Remaining: 0:00:00
#   Batch      36  of       38.    Elapsed: 0:00:01.  Remaining: 0:00:00
#
#   Average validation loss: 2.18
#   Validation Accuracy: 0.63
#   Validation epoch took: 0:00:01
#
# ======== Epoch 15 / 20 ========
# Creating Smart Batches from 4,800 examples with batch size 16...
#
# Tokenizing 4,800 samples...
#   Tokenized 0 samples.
#   Tokenized 500 samples.
#   Tokenized 1,000 samples.
#   Tokenized 1,500 samples.
#   Tokenized 2,000 samples.
#   Tokenized 2,500 samples.
#   Tokenized 3,000 samples.
#   Tokenized 3,500 samples.
#   Tokenized 4,000 samples.
#   Tokenized 4,500 samples.
# DONE.
#      4,800 samples
#
#      4,800 samples after sorting
#
# Creating batches of size 16...
#
#   DONE - Selected 300 batches.
#
# Padding out sequences within each batch...
#   DONE.
# Training on 300 batches...
#   Batch      30 of     300. Elapsed: 0:00:04. Remaining: 0:00:37
#   Batch      60 of     300. Elapsed: 0:00:08. Remaining: 0:00:33
#   Batch      90 of     300. Elapsed: 0:00:12. Remaining: 0:00:29
#   Batch     120 of     300. Elapsed: 0:00:17. Remaining: 0:00:25
#   Batch     150 of     300. Elapsed: 0:00:21. Remaining: 0:00:21
#   Batch     180 of     300. Elapsed: 0:00:25. Remaining: 0:00:17
#   Batch     210 of     300. Elapsed: 0:00:29. Remaining: 0:00:12
#   Batch     240 of     300. Elapsed: 0:00:33. Remaining: 0:00:08
#   Batch     270 of     300. Elapsed: 0:00:37. Remaining: 0:00:04
#   Average training loss: 0.18
#   Training Accuracy: 0.95
#   Training epoch took: 0:00:42
# Creating Smart Batches from 600 examples with batch size 16...
#
# Tokenizing 600 samples...
#   Tokenized 0 samples.
#   Tokenized 60 samples.
#   Tokenized 120 samples.
#   Tokenized 180 samples.
#   Tokenized 240 samples.
#   Tokenized 300 samples.
#   Tokenized 360 samples.
#   Tokenized 420 samples.
#   Tokenized 480 samples.
#   Tokenized 540 samples.
# DONE.
#        600 samples
#
#        600 samples after sorting
#
# Creating batches of size 16...
#
#   DONE - Selected 38 batches.
#
# Padding out sequences within each batch...
#   DONE.
# Doing validation on 38 sentences...
#   Batch       4  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:01
#   Batch       8  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      12  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      16  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      20  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      24  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      28  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      32  of       38.    Elapsed: 0:00:01.  Remaining: 0:00:00
#   Batch      36  of       38.    Elapsed: 0:00:01.  Remaining: 0:00:00
#
#   Average validation loss: 2.32
#   Validation Accuracy: 0.61
#   Validation epoch took: 0:00:01
#
# ======== Epoch 16 / 20 ========
# Creating Smart Batches from 4,800 examples with batch size 16...
#
# Tokenizing 4,800 samples...
#   Tokenized 0 samples.
#   Tokenized 500 samples.
#   Tokenized 1,000 samples.
#   Tokenized 1,500 samples.
#   Tokenized 2,000 samples.
#   Tokenized 2,500 samples.
#   Tokenized 3,000 samples.
#   Tokenized 3,500 samples.
#   Tokenized 4,000 samples.
#   Tokenized 4,500 samples.
# DONE.
#      4,800 samples
#
#      4,800 samples after sorting
#
# Creating batches of size 16...
#
#   DONE - Selected 300 batches.
#
# Padding out sequences within each batch...
#   DONE.
# Training on 300 batches...
#   Batch      30 of     300. Elapsed: 0:00:04. Remaining: 0:00:37
#   Batch      60 of     300. Elapsed: 0:00:08. Remaining: 0:00:33
#   Batch      90 of     300. Elapsed: 0:00:12. Remaining: 0:00:29
#   Batch     120 of     300. Elapsed: 0:00:16. Remaining: 0:00:25
#   Batch     150 of     300. Elapsed: 0:00:21. Remaining: 0:00:21
#   Batch     180 of     300. Elapsed: 0:00:25. Remaining: 0:00:17
#   Batch     210 of     300. Elapsed: 0:00:29. Remaining: 0:00:13
#   Batch     240 of     300. Elapsed: 0:00:34. Remaining: 0:00:08
#   Batch     270 of     300. Elapsed: 0:00:38. Remaining: 0:00:04
#   Average training loss: 0.14
#   Training Accuracy: 0.96
#   Training epoch took: 0:00:42
# Creating Smart Batches from 600 examples with batch size 16...
#
# Tokenizing 600 samples...
#   Tokenized 0 samples.
#   Tokenized 60 samples.
#   Tokenized 120 samples.
#   Tokenized 180 samples.
#   Tokenized 240 samples.
#   Tokenized 300 samples.
#   Tokenized 360 samples.
#   Tokenized 420 samples.
#   Tokenized 480 samples.
#   Tokenized 540 samples.
# DONE.
#        600 samples
#
#        600 samples after sorting
#
# Creating batches of size 16...
#
#   DONE - Selected 38 batches.
#
# Padding out sequences within each batch...
#   DONE.
# Doing validation on 38 sentences...
#   Batch       4  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:01
#   Batch       8  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      12  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      16  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      20  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      24  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      28  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      32  of       38.    Elapsed: 0:00:01.  Remaining: 0:00:00
#   Batch      36  of       38.    Elapsed: 0:00:01.  Remaining: 0:00:00
#
#   Average validation loss: 2.31
#   Validation Accuracy: 0.63
#   Validation epoch took: 0:00:01
#
# ======== Epoch 17 / 20 ========
# Creating Smart Batches from 4,800 examples with batch size 16...
#
# Tokenizing 4,800 samples...
#   Tokenized 0 samples.
#   Tokenized 500 samples.
#   Tokenized 1,000 samples.
#   Tokenized 1,500 samples.
#   Tokenized 2,000 samples.
#   Tokenized 2,500 samples.
#   Tokenized 3,000 samples.
#   Tokenized 3,500 samples.
#   Tokenized 4,000 samples.
#   Tokenized 4,500 samples.
# DONE.
#      4,800 samples
#
#      4,800 samples after sorting
#
# Creating batches of size 16...
#
#   DONE - Selected 300 batches.
#
# Padding out sequences within each batch...
#   DONE.
# Training on 300 batches...
#   Batch      30 of     300. Elapsed: 0:00:04. Remaining: 0:00:37
#   Batch      60 of     300. Elapsed: 0:00:08. Remaining: 0:00:33
#   Batch      90 of     300. Elapsed: 0:00:12. Remaining: 0:00:29
#   Batch     120 of     300. Elapsed: 0:00:16. Remaining: 0:00:25
#   Batch     150 of     300. Elapsed: 0:00:21. Remaining: 0:00:21
#   Batch     180 of     300. Elapsed: 0:00:25. Remaining: 0:00:17
#   Batch     210 of     300. Elapsed: 0:00:29. Remaining: 0:00:12
#   Batch     240 of     300. Elapsed: 0:00:33. Remaining: 0:00:08
#   Batch     270 of     300. Elapsed: 0:00:37. Remaining: 0:00:04
#   Average training loss: 0.12
#   Training Accuracy: 0.97
#   Training epoch took: 0:00:42
# Creating Smart Batches from 600 examples with batch size 16...
#
# Tokenizing 600 samples...
#   Tokenized 0 samples.
#   Tokenized 60 samples.
#   Tokenized 120 samples.
#   Tokenized 180 samples.
#   Tokenized 240 samples.
#   Tokenized 300 samples.
#   Tokenized 360 samples.
#   Tokenized 420 samples.
#   Tokenized 480 samples.
#   Tokenized 540 samples.
# DONE.
#        600 samples
#
#        600 samples after sorting
#
# Creating batches of size 16...
#
#   DONE - Selected 38 batches.
#
# Padding out sequences within each batch...
#   DONE.
# Doing validation on 38 sentences...
#   Batch       4  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:01
#   Batch       8  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      12  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      16  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      20  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      24  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      28  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      32  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      36  of       38.    Elapsed: 0:00:01.  Remaining: 0:00:00
#
#   Average validation loss: 2.45
#   Validation Accuracy: 0.62
#   Validation epoch took: 0:00:01
#
# ======== Epoch 18 / 20 ========
# Creating Smart Batches from 4,800 examples with batch size 16...
#
# Tokenizing 4,800 samples...
#   Tokenized 0 samples.
#   Tokenized 500 samples.
#   Tokenized 1,000 samples.
#   Tokenized 1,500 samples.
#   Tokenized 2,000 samples.
#   Tokenized 2,500 samples.
#   Tokenized 3,000 samples.
#   Tokenized 3,500 samples.
#   Tokenized 4,000 samples.
#   Tokenized 4,500 samples.
# DONE.
#      4,800 samples
#
#      4,800 samples after sorting
#
# Creating batches of size 16...
#
#   DONE - Selected 300 batches.
#
# Padding out sequences within each batch...
#   DONE.
# Training on 300 batches...
#   Batch      30 of     300. Elapsed: 0:00:04. Remaining: 0:00:38
#   Batch      60 of     300. Elapsed: 0:00:08. Remaining: 0:00:33
#   Batch      90 of     300. Elapsed: 0:00:12. Remaining: 0:00:29
#   Batch     120 of     300. Elapsed: 0:00:17. Remaining: 0:00:25
#   Batch     150 of     300. Elapsed: 0:00:21. Remaining: 0:00:21
#   Batch     180 of     300. Elapsed: 0:00:25. Remaining: 0:00:17
#   Batch     210 of     300. Elapsed: 0:00:29. Remaining: 0:00:13
#   Batch     240 of     300. Elapsed: 0:00:34. Remaining: 0:00:08
#   Batch     270 of     300. Elapsed: 0:00:38. Remaining: 0:00:04
#   Average training loss: 0.13
#   Training Accuracy: 0.97
#   Training epoch took: 0:00:42
# Creating Smart Batches from 600 examples with batch size 16...
#
# Tokenizing 600 samples...
#   Tokenized 0 samples.
#   Tokenized 60 samples.
#   Tokenized 120 samples.
#   Tokenized 180 samples.
#   Tokenized 240 samples.
#   Tokenized 300 samples.
#   Tokenized 360 samples.
#   Tokenized 420 samples.
#   Tokenized 480 samples.
#   Tokenized 540 samples.
# DONE.
#        600 samples
#
#        600 samples after sorting
#
# Creating batches of size 16...
#
#   DONE - Selected 38 batches.
#
# Padding out sequences within each batch...
#   DONE.
# Doing validation on 38 sentences...
#   Batch       4  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch       8  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      12  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      16  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      20  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      24  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      28  of       38.    Elapsed: 0:00:01.  Remaining: 0:00:00
#   Batch      32  of       38.    Elapsed: 0:00:01.  Remaining: 0:00:00
#   Batch      36  of       38.    Elapsed: 0:00:01.  Remaining: 0:00:00
#
#   Average validation loss: 2.48
#   Validation Accuracy: 0.62
#   Validation epoch took: 0:00:01
#
# ======== Epoch 19 / 20 ========
# Creating Smart Batches from 4,800 examples with batch size 16...
#
# Tokenizing 4,800 samples...
#   Tokenized 0 samples.
#   Tokenized 500 samples.
#   Tokenized 1,000 samples.
#   Tokenized 1,500 samples.
#   Tokenized 2,000 samples.
#   Tokenized 2,500 samples.
#   Tokenized 3,000 samples.
#   Tokenized 3,500 samples.
#   Tokenized 4,000 samples.
#   Tokenized 4,500 samples.
# DONE.
#      4,800 samples
#
#      4,800 samples after sorting
#
# Creating batches of size 16...
#
#   DONE - Selected 300 batches.
#
# Padding out sequences within each batch...
#   DONE.
# Training on 300 batches...
#   Batch      30 of     300. Elapsed: 0:00:04. Remaining: 0:00:37
#   Batch      60 of     300. Elapsed: 0:00:08. Remaining: 0:00:33
#   Batch      90 of     300. Elapsed: 0:00:13. Remaining: 0:00:29
#   Batch     120 of     300. Elapsed: 0:00:17. Remaining: 0:00:25
#   Batch     150 of     300. Elapsed: 0:00:21. Remaining: 0:00:21
#   Batch     180 of     300. Elapsed: 0:00:25. Remaining: 0:00:17
#   Batch     210 of     300. Elapsed: 0:00:29. Remaining: 0:00:12
#   Batch     240 of     300. Elapsed: 0:00:33. Remaining: 0:00:08
#   Batch     270 of     300. Elapsed: 0:00:37. Remaining: 0:00:04
#   Average training loss: 0.09
#   Training Accuracy: 0.98
#   Training epoch took: 0:00:42
# Creating Smart Batches from 600 examples with batch size 16...
#
# Tokenizing 600 samples...
#   Tokenized 0 samples.
#   Tokenized 60 samples.
#   Tokenized 120 samples.
#   Tokenized 180 samples.
#   Tokenized 240 samples.
#   Tokenized 300 samples.
#   Tokenized 360 samples.
#   Tokenized 420 samples.
#   Tokenized 480 samples.
#   Tokenized 540 samples.
# DONE.
#        600 samples
#
#        600 samples after sorting
#
# Creating batches of size 16...
#
#   DONE - Selected 38 batches.
#
# Padding out sequences within each batch...
#   DONE.
# Doing validation on 38 sentences...
#   Batch       4  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch       8  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      12  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      16  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      20  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      24  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      28  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      32  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      36  of       38.    Elapsed: 0:00:01.  Remaining: 0:00:00
#
#   Average validation loss: 2.59
#   Validation Accuracy: 0.62
#   Validation epoch took: 0:00:01
#
# ======== Epoch 20 / 20 ========
# Creating Smart Batches from 4,800 examples with batch size 16...
#
# Tokenizing 4,800 samples...
#   Tokenized 0 samples.
#   Tokenized 500 samples.
#   Tokenized 1,000 samples.
#   Tokenized 1,500 samples.
#   Tokenized 2,000 samples.
#   Tokenized 2,500 samples.
#   Tokenized 3,000 samples.
#   Tokenized 3,500 samples.
#   Tokenized 4,000 samples.
#   Tokenized 4,500 samples.
# DONE.
#      4,800 samples
#
#      4,800 samples after sorting
#
# Creating batches of size 16...
#
#   DONE - Selected 300 batches.
#
# Padding out sequences within each batch...
#   DONE.
# Training on 300 batches...
#   Batch      30 of     300. Elapsed: 0:00:04. Remaining: 0:00:37
#   Batch      60 of     300. Elapsed: 0:00:08. Remaining: 0:00:33
#   Batch      90 of     300. Elapsed: 0:00:12. Remaining: 0:00:29
#   Batch     120 of     300. Elapsed: 0:00:16. Remaining: 0:00:25
#   Batch     150 of     300. Elapsed: 0:00:21. Remaining: 0:00:21
#   Batch     180 of     300. Elapsed: 0:00:25. Remaining: 0:00:17
#   Batch     210 of     300. Elapsed: 0:00:29. Remaining: 0:00:12
#   Batch     240 of     300. Elapsed: 0:00:33. Remaining: 0:00:08
#   Batch     270 of     300. Elapsed: 0:00:37. Remaining: 0:00:04
#   Average training loss: 0.09
#   Training Accuracy: 0.98
#   Training epoch took: 0:00:42
# Creating Smart Batches from 600 examples with batch size 16...
#
# Tokenizing 600 samples...
#   Tokenized 0 samples.
#   Tokenized 60 samples.
#   Tokenized 120 samples.
#   Tokenized 180 samples.
#   Tokenized 240 samples.
#   Tokenized 300 samples.
#   Tokenized 360 samples.
#   Tokenized 420 samples.
#   Tokenized 480 samples.
#   Tokenized 540 samples.
# DONE.
#        600 samples
#
#        600 samples after sorting
#
# Creating batches of size 16...
#
#   DONE - Selected 38 batches.
#
# Padding out sequences within each batch...
#   DONE.
# Doing validation on 38 sentences...
#   Batch       4  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:01
#   Batch       8  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      12  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      16  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      20  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      24  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      28  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      32  of       38.    Elapsed: 0:00:01.  Remaining: 0:00:00
#   Batch      36  of       38.    Elapsed: 0:00:01.  Remaining: 0:00:00
#
#   Average validation loss: 2.56
#   Validation Accuracy: 0.63
#   Validation epoch took: 0:00:01
#
# Training complete! Total training took 0:14:38 (h:mm:ss)

# %%
plot_training_history(training_stats)

# %% [markdown]
# ## Evaluating Performance Over Training Set

# %%
(py_inputs, py_attn_masks, py_labels) = make_smart_batches(train_sentences, train_labels, batch_size ,tokenizer,max_input_length)

y_pred , y_true = get_predictions(py_inputs, py_attn_masks, py_labels)
# Out:
# Creating Smart Batches from 4,800 examples with batch size 16...
#
# Tokenizing 4,800 samples...
#   Tokenized 0 samples.
#   Tokenized 500 samples.
#   Tokenized 1,000 samples.
#   Tokenized 1,500 samples.
#   Tokenized 2,000 samples.
#   Tokenized 2,500 samples.
#   Tokenized 3,000 samples.
#   Tokenized 3,500 samples.
#   Tokenized 4,000 samples.
#   Tokenized 4,500 samples.
# DONE.
#      4,800 samples
#
#      4,800 samples after sorting
#
# Creating batches of size 16...
#
#   DONE - Selected 300 batches.
#
# Padding out sequences within each batch...
#   DONE.
# Predicting labels for 300 test batches...
#   Batch      30  of      300.    Elapsed: 0:00:01.  Remaining: 0:00:05
#   Batch      60  of      300.    Elapsed: 0:00:01.  Remaining: 0:00:04
#   Batch      90  of      300.    Elapsed: 0:00:01.  Remaining: 0:00:03
#   Batch     120  of      300.    Elapsed: 0:00:02.  Remaining: 0:00:03
#   Batch     150  of      300.    Elapsed: 0:00:02.  Remaining: 0:00:02
#   Batch     180  of      300.    Elapsed: 0:00:03.  Remaining: 0:00:02
#   Batch     210  of      300.    Elapsed: 0:00:03.  Remaining: 0:00:01
#   Batch     240  of      300.    Elapsed: 0:00:04.  Remaining: 0:00:01
#   Batch     270  of      300.    Elapsed: 0:00:04.  Remaining: 0:00:00

# %%
print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
#                        precision    recall  f1-score   support
#
#         Cyberbullying       0.99      1.00      0.99      1695
#      Religious_Hatred       0.98      0.92      0.95        48
# Gender_Discrimination       1.00      0.99      0.99       788
#               Sarcasm       0.98      0.97      0.98       194
#             Political       1.00      0.99      0.99       469
#                Racism       0.99      1.00      0.99      1606
#
#              accuracy                           0.99      4800
#             macro avg       0.99      0.98      0.98      4800
#          weighted avg       0.99      0.99      0.99      4800

# %%
cm = confusion_matrix(y_true, y_pred)
show_confusion_matrix(cm, class_names)

# %% [markdown]
# ## Evaluating Performance Over Validation Set

# %%
(py_inputs, py_attn_masks, py_labels) = make_smart_batches(val_sentences, val_labels, batch_size ,tokenizer,max_input_length)

y_pred , y_true = get_predictions(py_inputs, py_attn_masks, py_labels)
# Out:
# Creating Smart Batches from 600 examples with batch size 16...
#
# Tokenizing 600 samples...
#   Tokenized 0 samples.
#   Tokenized 60 samples.
#   Tokenized 120 samples.
#   Tokenized 180 samples.
#   Tokenized 240 samples.
#   Tokenized 300 samples.
#   Tokenized 360 samples.
#   Tokenized 420 samples.
#   Tokenized 480 samples.
#   Tokenized 540 samples.
# DONE.
#        600 samples
#
#        600 samples after sorting
#
# Creating batches of size 16...
#
#   DONE - Selected 38 batches.
#
# Padding out sequences within each batch...
#   DONE.
# Predicting labels for 38 test batches...
#   Batch       4  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch       8  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:01
#   Batch      12  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      16  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      20  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      24  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      28  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      32  of       38.    Elapsed: 0:00:01.  Remaining: 0:00:00
#   Batch      36  of       38.    Elapsed: 0:00:01.  Remaining: 0:00:00

# %%
print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
#                        precision    recall  f1-score   support
#
#         Cyberbullying       0.63      0.65      0.64       216
#      Religious_Hatred       0.67      0.40      0.50         5
# Gender_Discrimination       0.74      0.70      0.72       104
#               Sarcasm       0.39      0.40      0.39        30
#             Political       0.70      0.65      0.67        54
#                Racism       0.59      0.60      0.59       191
#
#              accuracy                           0.63       600
#             macro avg       0.62      0.57      0.59       600
#          weighted avg       0.63      0.63      0.63       600

# %%
cm = confusion_matrix(y_true, y_pred)
show_confusion_matrix(cm, class_names)

# %% [markdown]
# ## Making Predictions on Test Set

# %%
test_df
# Out:
#        PID                                              texts  \
# 5000  5001                   নাচের সাথে ধর্মের কোনো কারণ নেই।
# 5492  5493           নিজের গায়ে লাগলে হারাম অন্যের সময় হালাল
# 439    440            পানি লে আগে নাহলি মাতা ঘুইরি পইরি জাবিন
# 4834  4835                            ভাস্কর খানকির ছেলে পাঠা
# 1225  1226                       ড্রাইভার আবেদ আলী কাকু নাকি?
# ...    ...                                                ...
# 1086  1087               হানিবানি ম্যাডাম ঠিক এই ভাবে কথা বলে
# 5488  5489  নামধারী আলেম শুধু লেগে থাকেন একজন আরেকজনের দোষ...
# 776    777  পাগলা গারদে মোবাইল ইন্টারনেট ব্যাবহার করা যায় ...
# 4190  4191                          মাতারির বাড়ির লোকেশন দেন
# 4280  4281                   কুকুর মালিকের সাথেই থাকে সবসময়।
#
#                 labels
# 5000  Religious_Hatred
# 5492  Religious_Hatred
# 439            Sarcasm
# 4834     Cyberbullying
# 1225           Sarcasm
# ...                ...
# 1086     Cyberbullying
# 5488  Religious_Hatred
# 776            Sarcasm
# 4190     Cyberbullying
# 4280           Sarcasm
#
# [600 rows x 3 columns]

# %% [markdown]
# ## Loading `test_sentences`

# %%
test_sentences = test_df['texts'].values
test_labels = test_df['labels'].values
test_ids = test_df.index.values

# %%
test_ids
# Out:
# array([5000, 5492,  439, 4834, 1225,  183,  681, 4480, 2244,  381, 4879,
#        2031, 4071, 3053, 5992, 3193, 5563, 5294, 4999, 3647, 1964, 3958,
#        4369, 4866, 1176,  351, 2080, 5050, 1671,  622, 3867,  292, 3185,
#        4724, 4557, 3184, 2977,  996, 1194,  445, 4762, 1039, 5317, 5368,
#        5693, 1891, 5112, 3720, 3035, 1487, 4301, 4458,   69, 2892, 5510,
#        2127,  199, 2357, 3469, 4939, 1864, 1535, 4756,  319,  549, 5118,
#        5591, 2024, 5823, 5606, 5892, 1505, 3033, 4674, 3544,  245, 1978,
#        4046, 2617, 5851,  748,  476, 1564,  124, 5527, 2834, 3484, 3090,
#        4020, 3892, 4568, 2313, 1905, 4196,   93, 3459, 2602, 1161, 2788,
#        5098,  371, 2163,  185, 5047, 2611, 3094, 2086, 4010,  228,  296,
#        1407, 2476, 4310,  584, 2584,  752, 4353, 5846, 5525, 1817, 2957,
#        3045, 5297, 2142, 1729, 1374, 2638, 1533, 3971, 4581, 3407, 3937,
#        5556, 5808,   23, 3859, 3707, 5217, 3764, 4379, 3130, 4876, 3226,
#         501, 2767, 3734, 4603, 5026, 2663, 5683,  308, 3382, 1451, 4620,
#        2857, 1918, 5314, 1620, 1057, 1477, 1454, 2463, 3869,  181, 5663,
#        3077, 2677, 1400, 1297, 4541, 4815,  787, 4808, 1328, 3973, 4983,
#        1844, 3182, 3895,  432, 3204,  469, 1383, 2885, 1485, 3934, 2157,
#        2945, 4886, 1370, 1042, 2503, 4745,  453, 1881, 4714, 5095, 5459,
#         230, 5648, 1033, 5110, 5224, 1221, 5164,  794,  239, 5479, 3127,
#        5800, 1172,  293, 4001, 5454, 1803, 3784,  472, 4607, 3664, 4362,
#         297, 1543, 3669,  964, 4028, 3552, 5094, 3970, 3149, 4614, 5747,
#        5409, 3012, 3938, 1321,  167, 1514,   84, 1507,  742, 5828, 5210,
#        1894, 1344, 1049, 5289,  286, 5830, 5545, 4956, 4184, 2350, 3158,
#          71, 2445, 2210,   15, 4734, 3396, 5006, 3187, 4655, 5169, 1765,
#         135, 4472,  747,  452, 3916, 5751, 5351,  604, 1188, 5138, 2223,
#        5638, 1024, 2077, 4650, 4758, 4476,  810, 1209, 3813, 2559,  605,
#        3815, 1720,  100, 4706, 3413, 3942, 4333, 4526, 1357, 1027, 2187,
#         683, 1652, 3946, 5329, 3805, 4738, 5460, 3487, 4101, 1726, 2874,
#        1354, 5837, 2795, 2802, 2995, 1871, 2287, 1965, 3550, 5034, 1090,
#         346, 2653,  422, 3372, 3886, 4423, 1859, 4264, 1094, 2002, 4102,
#        4930, 4393, 2704, 2436, 5708, 2439, 3799, 5597, 2227, 1121, 2432,
#          29, 3309, 3285, 2915, 2846,  177,  969,  380, 2650, 5959, 3607,
#        5303, 5799,  812, 3240, 5241,  805, 5639, 1562,  505, 1219, 3488,
#        4503, 4698, 5330, 2292, 1561,  896, 1669, 1837, 3379, 5692, 2841,
#        5907, 1186, 4098, 3133,  978, 3905, 1657, 1204, 3821, 1192, 4629,
#        1073,  586, 1755, 2812, 4275,  473, 1253, 2298,  142, 4594,  960,
#         247,  977, 2115, 1499, 2450, 3181, 3026, 1075, 1666, 5825, 1144,
#        4343, 1163, 3392,  691, 5931, 1183, 2775, 4635, 5565, 3710, 1966,
#        2213, 3671, 5109, 2323, 5769,  227, 2447, 2742, 2380,  198, 3795,
#        4950, 5544, 5912, 4691, 5364, 3289,  408, 1032, 5803, 5854, 3967,
#        3320, 3409,  530, 2272, 1047, 1488, 3103, 1634, 3917, 2549, 3667,
#        1569, 1566, 1448, 1623, 1773, 1536, 1902,  121, 1142, 1609, 4733,
#        3525,   47, 5787, 3651, 1084, 1612,  486, 2377, 2819, 3557, 4633,
#        4454,  443, 4666, 4103, 1888, 5687,  414, 2900, 3494,  497, 4250,
#        5690,  437, 2370,   65, 1873, 2022,  478, 4192, 3529, 2420, 1397,
#        3617,  625, 1630, 4945, 3796, 4668,  336, 2110, 2263, 2913, 1586,
#        4832, 2858, 2770, 1496, 3163, 5322, 3670, 2347, 4383, 5400, 3135,
#        3856, 1745, 3593, 2018, 5404, 3492, 2168, 1879, 2240, 2146, 1471,
#        4742,  168, 4258, 5658, 1420, 5395, 5948, 5790, 3833, 4878, 1545,
#        4686, 2410, 1559, 4630, 2798, 5661, 4838,  911, 5283, 2338, 5272,
#        1617, 2516, 2083, 5273, 5694,  110,  324,  393, 1158,  333,   14,
#        1438, 3624,  746,  655, 3167, 5495, 1315, 2133, 2598, 2968, 1694,
#         613, 4441, 4796, 1345, 2091, 3751, 1002, 2225, 5470,  259, 5261,
#        1322, 5684,  751,  706, 4240, 4708, 4269, 3877, 3700, 4562, 2275,
#        1706, 1086, 5488,  776, 4190, 4280])

# %%
(py_inputs, py_attn_masks,py_ids) = make_smart_batches_on_test(test_sentences,test_ids, 16,tokenizer,max_input_length)
# Out:
# Creating Smart Batches from 600 examples with batch size 16...
#
# Tokenizing 600 samples...
#   Tokenized 0 samples.
#   Tokenized 60 samples.
#   Tokenized 120 samples.
#   Tokenized 180 samples.
#   Tokenized 240 samples.
#   Tokenized 300 samples.
#   Tokenized 360 samples.
#   Tokenized 420 samples.
#   Tokenized 480 samples.
#   Tokenized 540 samples.
# DONE.
#        600 samples
#
#        600 samples after sorting
#
# Creating batches of size 16...
#
#   DONE - Selected 38 batches.
#
# Padding out sequences within each batch...
#   DONE.

# %%
y_ids,y_preds  = get_predictions_test(py_inputs, py_attn_masks,py_ids)
# Out:
# Predicting labels for 38 test batches...
#   Batch       4  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch       8  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      12  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      16  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      20  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      24  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      28  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      32  of       38.    Elapsed: 0:00:01.  Remaining: 0:00:00
#   Batch      36  of       38.    Elapsed: 0:00:01.  Remaining: 0:00:00

# %%
test_sentences
# Out:
# array(['নাচের সাথে ধর্মের কোনো কারণ নেই।',
#        'নিজের গায়ে লাগলে হারাম অন্যের সময় হালাল',
#        'পানি লে আগে নাহলি মাতা ঘুইরি পইরি জাবিন',
#        'ভাস্কর খানকির ছেলে পাঠা', 'ড্রাইভার আবেদ আলী কাকু নাকি?',
#        'শালার পুত অহংকারী ওর পতন এমনিই হবে ইনশাআল্লাহ।',
#        'তুমি তো সিয়াগো চেয়ে খারাপ', 'বেরোনা মোনা নাহলে ঘটি বেকিয়ে দেবো',
#        'বুলেটের মুখে দাঁড়িয়েও বাঙালি',
#        'বাংলায় একটা প্রবাদ আছে, রতনে রতন চিনে, আর শুকরে চিনে কচু। আর বেশি কিছু বললাম না।',
#        'তৃণমূল এর পাকা পাঁঠা ঐ শালার গুলি করে মারা উচিত',
#        'বাকি কাপড়টুকু না রাখলে আসল জিনিস দেখা যেত',
#        'আরে এটা কে? কেত্থেকে এল এ? আর এর মুখ এত ছোট কেন? ',
#        'খুনিরা করছে শোক।❞',
#        'দেশে নিরপেক্ষ নির্বাচন হলে নিঃসন্দেহে আওয়ামীলীগ জয় লাভ করবে।',
#        'একটু বুকে আই', 'যু্দ্ধ করবো ভারতের বিরুদ্ধে',
#        'মিথ্যা নাটক এবার বন্দ কর অতিরিক্ত কোন কিছুই ভালো না',
#        'র্খদের মতো এখনো মানুষকে লিঙ্গ,জাত,ধর্ম,কালো,সাদা হিসেবে বিবেচনা করি',
#        'বিবেকটাই আসল।', 'ওরা সমাজটা নষ্ট করে দিচ্ছে',
#        'এই তুমি কোন পথে যেন স্বর্ণ ঢুকায় ছিলে ?', 'দেশ আজ কোথায় গেছে',
#        'এখন অঙ্ক পারিস পাঠা', 'ওর কি জামাই নাই?',
#        'আমি আপনার অনেক বড় বক্ত কারণ আমি আপনার প্রত্যেক পোস্টে গালাগালি করি',
#        'কত বড় পাপী হইলে এসব পোস্ট সামনে পরে',
#        'হিন্দু ছেলে কোন মুসলিম মেয়ে কে ভালো বাসে তখন যে আঘাত আসে তখন তোমারা কোথায় থাক?',
#        'অইদিন কুডস এ দেখছি এক সুগার ডেডি এর লগে', 'জেফার দ্যা ফকিন্নি',
#        'একিই রনরন বাজাবাজি ঘনঘন। ছন রনরন, ঝনঝন। সেকি তমকি ধমকি। দ্রামা-দ্রিমি দ্রিমি',
#        'এহালারে কেনো ডাকে আমি বুজি না জারা ডাকে তাদের মাথা কি আছে জানতে ছাওয়া আমার আবুজ মন',
#        'অমানুষের মার্কা, নৌকা মার্কা', 'ফাজলামি বাদ দেন',
#        'ওরে ল্যাংটা করে তো ঠিকই করছে', 'হালকার উপর ঝাপসা',
#        'লিংক যেন ফুল বের হয়', 'দুই টা কুকুরের বাচ্চা কুত্তা',
#        'জাহান্নামে যাওয়াটা সহজ করে দিলেন',
#        'মানবতার ফেরিওয়ালা হবেন ভাই বুঝছি', 'গাধা দিয়ে হালচাষ হয় না।',
#        'দূরু মিয়া আপনাগো লাইগা আমরা সাপ্লাই কম পাই।কি দরকার পরীক্ষার হলে সাংবাদিক গিরি করার',
#        'আরেকটা প্যাচাল ধরাই দিলেন তো?',
#        'মাদারচোদ বন্ধ কর তোর গুজবের ভিডিও।', 'কই আছিস তুই রে খানকি',
#        'তর সোনাদিয়া গরম রটডু কামু খারাপ মহিলা',
#        'সারা বিশ্বে কিছু মানুষ নামের অমানুষ ঘেউ ঘেউ করে ।',
#        'বাংলাদেশ আবাল লীগ', 'এমন বেশরম জিন্দেগীতে দেখিনাই',
#        'মুখেআটকায় তুতলাগো মতন',
#        'কু*ত্তার বাচ্চা গুলো দেখতে ফুটফুটে সুন্দর', 'অহংকার পতনের মুল',
#        'গান গায় জেফার,,,শ্বাসকষ্ট হয় আমাদের.',
#        'ওমা হ্যাতেদি কোমল পানির দোকান লইয়া বইছেগো',
#        'এটা মেয়ে না অন্য কিছু...',
#        'তোমাদের পিরিত চুদানোর কারণে নিজের বউয়ের কাছে ভালো',
#        'এদেরকে টাইগার বললে বাঘেরা অপমান বোধ করে', 'নিজের ধন কখনো দিয়ো না',
#        'এটা গান নাকি কবিতা', 'মূর্খতার চরম পর্যায়ে', 'ঝন্টু খাবে ঝাড়ু',
#        'হিরো আলমের ডান্স দেখে আমার ২ ঘন্টা জ্ঞান ছিল না',
#        'ভরে দাও মাইয়াটারে পিও', 'সবচেয়ে বড় কথা আংকেল খুব গর্ভবতী',
#        'কনডম ব্যবহার কারিদের বলতাছি বউ কে আসতে আসতে পিঠাইবেন',
#        'অরাজনৈতিক দাবি করলেও সময়ে অসময়ে রাজনীতিতে বাঁ হাত দিয়ে দেশকে অস্থিতিশীল করার চেষ্টা',
#        'মাইরের ওপর কোন ঔষধ নাই,', 'আমার দেখা সেরা কাচার',
#        'তুমি কার বাল পালাইচ',
#        'সাব্বাশ কুত্তার বাচ্চারা তোদের এই পৃথিবী চাচার অধিকার নেই',
#        'বিএনপি এর একটা থিম সং এর বড়ই অভাব', 'রিপন্দার দুইটা বিচি',
#        'আগস্ট মানেই ঈদ', 'চুরি হাতে রাস্তায় নামবেন',
#        'এমন একটা আফা আমিও ডিসার্ভ করি',
#        'কোন সালায় একে বিসিবির সভাপতি বানালো আমার মাথায় আসে না',
#        'নির্লজ্জ হাজারো পচালে ও পচবেনা অপচনশীল দ্রব্য',
#        'ফ্যাসিস্টের দোসর হিসাবে বিচার করতে হবে।',
#        'দুমুঠো ভাতের লড়াই ছিল মা, দেখো আজ কি পেলাম',
#        'ঢেঁকি স্বর্গে গেলেও ধান ভানে', 'সব দয়াল বাবা কেরামতি',
#        'চারদিকে এতো লয়্যালের মধ্যে আমি বাটপার', 'জাতীয় সবজী নাম গাঁজা',
#        'জাতি রেল চুক্তি নিয়ে জানতে চায়! পরিমনি বা বিকিনি মডেলের আত্মজীবনী জানতে চায় না',
#        'বিছি আলা আপু।', 'বার্বুচি না ডির্বুচি', 'আরও গোছাতে হবে।',
#        'শোকের নামে অপমান।', 'বিচার মানি। কিন্তু তাল গাছটা আমার-ই',
#        'যাদের জন্ম পতিতালয়ে তাদের কাজ এটা। কোন শিক্ষিত জাতির নয়',
#        'পাপ বাপকেও ছাড়ে না', 'বদনাম থেকে বেচে গেলুম',
#        'চামড়া ব্যবসায় ধস নেমেছিলো হয়তো', 'কলকাতা হারবাল খেয়ে লাগান ওরে',
#        'উনি এমন ভাব করেন মনে হয় এখনো ১৬ পার হয়নি..!!',
#        'কাকু খুব সম্ভব শক্ত পলেথিন ছিলো', 'তার পরিচয় কেউ জানেন??',
#        'সংসার জোড়া লাগাইতে খবর দেয়নি', 'জুকারবাগ সোনা দে কমেন্ট বক্সে',
#        'বিভাজন ভারতের ভবিষ্যত অখন্ডতাতে হুমকির মুখে ফেলতে পারে',
#        'লজ্জার একটা লিমিট থাকা দরকার বিয়ে ছাড়া সম্পর্ক তা নিয়ে আবার এত নাটক',
#        'রস পরে গেল সব',
#        'বাংলা দেশের 2 plyar বাদ দিয়ে আমি আর জসিম ভাই খেলবো হবে',
#        'মুসলিম দেশে সম্ভব না ওরা বলতো হারাম অমুসলিম দেশে বলতে',
#        'নির্মমতা কত দূর হলে জাতি হবে র্নিলজ্জ', 'ঘুম ভেঙেছে মন হয়',
#        'দেখিস দানা দুনা সামলাই রাখিস',
#        'এ মানুষ টা কতো নিকৃষ্ট তা কল্পনার ও বাহিরেচ হ্মমতা ধরে রাখতে এমন কোনো খারাপ কাজ নাই যা উনি গত ১৫ বছরে উনি করেননি, দুঃখের বিষয় কিছু অতি আবেগি মানুষ উনাকে নিয়ে পোস্ট দেয়, এ রক্তশোষা প্রাণীটাকে নিয়ে, আপনি জানেন, উনি পদত্যাগ করতে চাইনি, আইন শৃঙ্খলা বাহীনির শক্ত অবস্থানে কারনে এবং আন্তজাতিজ চাপে উনি পদত্যাগ করতে বাধ্য হয়েছেনন, উনি চেয়েছিলেন শত শত গণহত্যা চালিয়ে হলেও উনি হ্মমতায় থাকবেন, মানুষের জীবনের মূল্য তার কাছে কিছুই নই, গত ১৫ বছর উনার নিতাকর্মী রা কি পরিমান মানুষের রক্ত সুচেষে বলার বাহিরে, পদত্যাগ এর পর উনার পরিবার চেয়ে সাম্প্রদায়িক উস্কানি দিয়ে ভারতের সাথে যুদ্ধ লাগিয়ে দেওয়া, এমন অনেক বক্তব্য তার ছেলে জয় এর আইডিতে পাবেন, বাট তাও কোনো কাজ হয়নি, এখন আপনাদের আবেগ পুঁজি করে উনার ছেলে আবার ঘোষনা দিয়েছে তারা নির্বাচনে আসবে, কথা হচ্ছে এ রক্ত চোষা দের দেশে কি আবারও জায়গা দেওয়া হবে? এতো গুলো মানুষ মেরেও ওদের হ্মান্ত হয়নি? এতো লুটতরাজ করে? জয় বলে আওয়ামীলীগ বঙ্গবন্ধু দেশ স্বাধীন করছে, ৩০লাখ মানুষ কি করেছে? প্লিজ এসব সস্তা আবেগ বাদ দিন।',
#        'অনেক ফর্সা হিরো আলম', 'তুই কোন দেসের মাদারচোত',
#        'আমার শ্বশুর কোনটি শুদবে',
#        'আর যার লুটপাট করলো তারা হলো দেশপ্রেমি আওয়ালিয়া,পীর এ জাদা সহি সুফি মুক্তিযোদ্ধা',
#        'দুটাই ক্ষমতা লোভী তাদেরকে আজীবনের জন্য নিষিদ্ধ করা হোক।',
#        'দাদর গায়ে লাগে কেন', 'পিতৃ পরিচয় হীন জারজ সন্তান',
#        'এতো দিনে পম পম বড়ো হয়ে গেছে', 'কতোটা কুলাংগার হলে যা হয়',
#        'ভয়ানক মৃত্যু হবে তোর আসাদ নূর',
#        'অসভ্য মেয়ে তো কর্মি হওয়ার যোগ্যতা রাখে না।',
#        'উনি কি ট্রেনিং এর সময় ভোট চুরি ট্রেনিং দিয়েছেন', 'আপা,নুনুদেখ',
#        'তুমি প্রেগন্যান্ট হয়ে যাবে নিশ্চিত।', 'আয়না রাণী বায়না ধরেছে',
#        'মেয়েটার ঠোঁটের নিচে দুধ আছে।', 'লাও বড় হও কেমনে',
#        'এত মানুষ করোনায় মরছিন তরা কয় ছিলি', 'এইটা কিসের চাষ করলি বাবা',
#        'আসল মজা পাবে সাউন্ড বন্ধ করে',
#        'ছাত্র লিগের সাদ্দাম কয় গেলি সাহস থাকলে মাঠে আছিস ',
#        'গুজব মারা যায় নি', 'বুলেটের সাথে কলমের কালির লড়াই',
#        'তোমাকে খুঁজছে বাংলাদেশ কোথায় তুমি',
#        'ভারতের কু-রুচিপূর্ণ চর্চা নিয়ে বি*স্ফো*রক মন্তব্য',
#        'ছাত্র ছাত্রী মানুষের কাতারে পড়ে না , এরা অমানুষ ।',
#        'বাংলাদেশ ক্রিকেটের ডাক নাম হচ্ছে সমীকরণ',
#        'এবার পদত্যাগ পত্র জমা দেও।', 'আওয়ামী ফূটবল লীগ',
#        'কাম নাই হলুদ মিডিয়া গুলার', 'ক্লাসে কি ছেলের অভাব হইয়ে গেলো?',
#        'অসাধারণ ডেজ ভাইয়া',
#        'আরে নিগা তোর ফটোই যথেষ্ট শোক দিবস পালনের জন্য',
#        'যে রাম পাঠা বলছে তার মা অন্য মতের চোদানর ছেলে',
#        'ই মহিলা এতো খবিশ দেখেই সাকা চৌ বিয়ে করে নাই।বাপে আলা ভোলা একটার ঘাড়ে চাপায়া দিছে।',
#        "টাকা দে নয়তো কা'পড় উঠামু", 'কিরে জারক সন্তান', 'খনিকের ছেলে',
#        'পেট মনে হয় ফুটো করা',
#        'হিন্দ বা মুসলিম এক সাথে হলেই যে জঙ্গি বলতে হবে',
#        'জাগোবাঙালিরা জাগো', 'তুমি তুলে নিলে আমি বাধা দিবোনা পিও',
#        'নাটক কম করো পিও। তুমি যে ভান করে কান্মা করতেছো আমরা বুজে গেছি পিও',
#        'পুলিশকে অর্ডার করে ছাত্রদেরকে গুলি করার জন্য ছি ছি ছি',
#        'তোদের কয়টা ফিফা কাফ', 'বোতলের ভিত্রের মাল গিললো। ওয়াও।',
#        'জাতীয় কি হগেছে', 'হালায় দি কানা', 'কেয়ামতের আলামত ত দেখেই যাচ্ছি',
#        'পাবনার গেইট খুললো কে', 'আমার খুব প্রয়োজন এমন একটা সুগার মামি',
#        'গাঁজা হিরোই তো দুরের কথা', 'ব্রাজিলকে পুটকি মেরে',
#        'অনেক বড় গাবি', 'শুভকামনা রইল প্রিয় লাল ভাইদের জন্য',
#        'উড়ছে লুঙ্গি লাগছে বেশ বাL ছিঁড়লো বাংলাদেশ',
#        'আওয়ামী লীগ দেশ ছেড়ে পালিয়ে গেছে,এইবার যত পুরুষ আছে সবাই কে তোমার বাসায় দাওয়াত দিয়ে তোমার হালুয়া খাওয়া।',
#        'শয়তানের ও যোগ্যতা থাকে', 'একটি ছাত্রলীগ তুমি জাগ্রত জানোয়ার',
#        'বৌরা ও মাঝে মাঝে বরদের ও ডুডু চোষে',
#        'লুকিয়ে থাকা প্রেতাত্মাদের বের করে ডিম থেরাপি',
#        'ক্ষমতা হারানোর যন্ত্রণা লাঘবের ব্যর্থ চেষ্টা',
#        'হিন্দু আইন সংস্কারের কোন প্রয়োজন নেই।',
#        'কিছু কিছু মূল\u200d্যবান অকেজো জিনিস রয়েছে আমাদের চারপাশে যা নিতান্তই জাদুঘরে শোভনীয় কিন্তু সেখানে স্থানান্তর করা হচ্ছে না',
#        'এতো বিনোদন কোথায় রাখি',
#        'জিয়া ও খালেদার ছেলে তারেক জিয়ার দুর্নীতি ও সন্ত্রাস ছিল',
#        'তুমি কুতায় এখন পিও', 'নষ্টামি ছাড়া আর কিছুই শিখা যাবেনা।',
#        'এটা তোর আব্বা ইকবাল কে দেখাইস নটির পোলা',
#        'এই নৌকা টাইটানিকের চেয়ে শক্তিশালী বাপে রাইখা গেছে',
#        'আরেকটু উপরে বেয়াদব', 'দেথো দিনি কান্দওটা',
#        'মেশিন নষ্ট হলে তো এমন ই মনে হবে',
#        'ফেলানীর বুক ছিঁড়ে ট্রেন চলেছে ঝকঝকা ঝকঝক',
#        'তোমরা গিটারিস্ট পার্টি বুঝবা কি ভাবে', 'কইরে কেও দিলনা',
#        'তুই যে পাগল হয়ছস তর বাড়িতে জানে',
#        'এই দুঃসময়ে আমি ছাত্রলীগ মেয়েদের পাশে থাকতে চাই!',
#        'ওমা গো টুরু লাভ', 'নাউজুবিল্লাহ মিন যালেক',
#        'ছাগল পাঠা ছাড়া এই দলের কোন অস্তিত্বই নেই',
#        'ছেলে মেয়ে সমান আধিকার', 'ভাই বাঙ্গালীর একটু ছাড় দেন এবার',
#        'ফাউ কষ্ট করে ভিডিও বানাই কোনো ফলোয়ার নাই',
#        'এরা আসলে কাপড় খুলে রাস্তায় হাঁটতে চায়।',
#        'এই কু*ত্তার বা*চ্চা তু কি বললি।তুই কি বললি',
#        'টাকলু ওরে বাট পার ভালো হয়ে যাও', 'অসভ্যতা আমাদের রক্তে',
#        'শাহারুখ খাঁন আর দিপ্পিকা নাচলে ধর্মের সমস্যা হয়না!',
#        'বৌদ্ধ ধর্ম হিন্দু ধর্মের চেয়ে অনেক বেটার |',
#        'ধিক্কার জানাই কনডম কোম্পানিকে', 'তুই ত নোয়াখাইল্লা',
#        'বাংলাদেশ আর ভারত ভাই বোনের সম্পর্ক',
#        'পুরা ভারত রাষ্ট্রই হলো পাগলের ফ্যাক্টরি।',
#        'যদি দাড়ি টুপি আলাদের গালগাল খেতে চান তাহলে মুসলিম ছেলে মেয়েদের সাথে নাচানাচি করবেন।',
#        'এখন তাকে নটিপারা ভর্তি করে দেওয়া হোক',
#        'হিন্দুর সাথে মুসলিম কত অনুষ্ঠানে',
#        'কাদের ভাই মন খারাপ ক্যাআন্নেগো',
#        'তর দুই ডা বিচি কিশোরগঞ্জের ব্রিজে ঝুলিয়ে শুকানোর ব্যবস্থা যদি করা হতো',
#        'কিরে ল্যাংড়া, তুই আবার ছবি পোস্ট করোস কেন', 'শোকের নাটক কবর দে.',
#        'অভিসাব লাগবে এই ছাএ সমাজে', 'পুন মারি দে,',
#        'নিজে পইচা আরেকজনরে পচায়',
#        'আগে আওয়ামিলীগের সামনে বলতে পারতাম না এখন বি এন পি এর সামনে কিছু বলতে পারি না।',
#        'এই মেয়ে তোমার কি জাত বংশ নাই',
#        'সারফারাজ মিষ্টি খাবার কম খাইস বাবা।',
#        'সত্যি বলার জন্য এমন বাঘের প্রয়োজন',
#        'চুল কালার করলে কি গরীব হয়ে যায়?', 'এ কোন পাগল চোদা রে',
#        'নতুন খেলা তো সবে শুরু।',
#        'কুলাঙ্গার মেয়ের জন্য তার বাবার আজকে এই অবস্থা',
#        'সোনা আলম এই খানকীর পোলাদের কারনে ইন্ডিয়া আমাদের নিয়া হাসাহাসি করে',
#        'চিড়িয়াখানা প্রাণী হিসেবে বন্দি করা হোক।',
#        'এসব ফালতু বেডি সমাজ নস্টের মূল', 'শালা পাঠার পো পাঠা', 'ছাপড়ি',
#        'ওতো বিধবা মনে হয় এই গুলো বুঝার ক্ষমতা নেই',
#        'মিডিয়াগুলোকে বলছি জাহিলিয়াত কে সমর্থন করছেন',
#        'জুতার মালা পরিয়ে তোকে সাড়া বাংলা ঘুরানোর ইচ্ছা ছিল',
#        'নৌকা ডুবার পরে কেউ উকি মারতেও যাবে না', 'পান্তা না ফান্টা',
#        'খেলা হবে এখন নিছে অনেক ব্যাথা তাই একটু রেস্টে আছে',
#        'ভারতের লোক তোদের বাংলাদেশে বাল ছিড়তে যাবো না।',
#        'বাজার গরমের কৌশল।',
#        'কই আছো আছো গো প্রিয় তোমারে একটু দেখতে চায় আমর এই অবুঝ মন..\U0001fae3\U0001fae6',
#        'মিষ্টার জায়েং খান ফম বাংগাডেশ',
#        'এইসব বাজে মহিলা দের ডং দেখলে রাগ হয় খুব', 'হাই ফকিন্নির পুত',
#        'ভেতরে বাতাস লাগাচ্ছেন বুজি', 'এ লটির বাচ্ছা',
#        'আকামের শান্তি নাই, আকামের শাস্তি এমনি হয়।', 'ছাগল দিয়ে হাল চাষ',
#        'ধর্মের বিধিবিধানকে দূরে ঠেলে দেওয়া আবার কোন ধরনের মানবিকতা??!!',
#        'সানিলিওনকে কি ফলো করতেছেন', 'মন্দির উপাসনার জায়গা',
#        'গানের বাচ্চা বাহির করি দিছে', 'প্রতিটি ঘর একেকটি পার্লামেন্ট',
#        'কমেন্ট পরে দেখলাম তারে একটা লোক ভালো বলে না আসলে নির্লজ্জ বেহায়া লোক।',
#        'জীবনে কি বাল ফালাইলাম,', 'দানা ওয়ালী আপি।',
#        'কালা মাইয়ারা কেন সুন্দর পায়না',
#        'সোনার বাংলা থেকে জালিম দের বিদায়', 'গাজাব বেজ্জতি',
#        'কি কথা বলেছো দোস্ত সেই রকমে',
#        'অতিরিক্ত ভায়াগ্রা সেবনের ফলে তার এই অবস্থা',
#        'গরুটা কিন্তু ভালোই গুলুমুলু', 'খনকিরে চাপায় দেন',
#        'পাগলের হাট বাজার আল্লাহ হেদায়েত করুক',
#        '৫ ই আগস্ট গনভবন লুটপাট দিবস পালন করা হোক',
#        'মি বাবা মা হারাইছো, সন্তান তো হারানো নি বুবু',
#        'মানুষ ধর্মকে হিংস্র ভাবে ব্যাবহার করছে,', 'পর্ন কি',
#        'রক্তের দামে কেনা দ্বিতীয় স্বাধীনতাও কি ব্যর্থ হবে !!',
#        'হিন্দু বলে কী তারা মানুষ নন।', 'মোডা হই অইয়ি,,বর না অইয়ি',
#        'কাউয়া আবার মেকআপ করে', 'বাংলা দেশে শিক্ষার অভাব পড়ছে',
#        'জাহান্নামে জাওয়ার জন্য এই দৃশ্য টি যথেষ্ট',
#        'আপনি তো চেল চেলায়া বেহেশতে যাইবেন',
#        'অসুস্থ প্রজন্ম,,,এদের বাবা কে????',
#        'হোগা মারা খেতে খেতে ছাএলীগ ক্লান্ত',
#        'বাঙালি মানেই সুখে দুঃখে বিনোদন', 'হ্যাঁ সে বেয়াদব খেলোয়াড়',
#        'দেবতা নিজেকে রক্ষা করতে পারে না', 'মূল বিষয়টাই মুর্খতা।',
#        'দেওয়ালের কালি মোছা নিষেধ"', 'তোমরা দুই জনে জারোস সন্তান',
#        'স্বামীর কলিজা এত বড় কেন?????', 'বুকের ভিতর গ্যাস্টিকের ব্যাথা',
#        'জিম্মি করে ফেলবে!', 'দুষ্টু পোলাপাইন!',
#        'কুকুরের সাথের সিংহ তুলনা', 'নায়িকা হিসেবে একদমই বেমানান',
#        'বিশাল উপরে উঠে গেছো সুতমারানি', 'হঠাও মাফিয়া বাচাও দেশ',
#        'রাজাকার দেশদ্রোহী ফাঁসি দিয়ে মারা', 'ও শালারা তো এরকমই করে',
#        'বাংলাদেশে ক্রিকেট এবং ফুটবল খেলা নিষিদ্ধ করা হোক।',
#        'সম্পর্ক বদলে গেলো একটি পলকে',
#        'তাদের জুতা মারলে।জুতার সম্মান কমে যাবে', 'পিও তুমিও অনেক দুস্ট',
#        'আল্লাহ এদের উপর গজব নাজিল করুক।',
#        'বেয়াদবের মতো না জেনে শেষের মেয়েটার ভিডিও এড করে দিছেন কেন? সে তো ছাত্রলীগ করে না। ওইটা একটা প্রতিবাদ কর্মসূচি ছিল জগন্নাথ বিশ্ববিদ্যালয় প্রশাসনের বিরুদ্ধে। এই কারণেই তো তোমাদের জন্য হাসিনাই পারফেক্ট। এটা আল্লাহর কথা যারা যেমন তাদের শাসক\u200cও তেমন।',
#        'ইজ্জতে হাত দিলি', 'ওই শুভরে বাচ্চা',
#        'ভাইপো ভাগিনাদের বাদাম খোটার প্রাকটিসে কাজে লাগে',
#        'পোস্টদাতা হলো দাইমা!', 'কনডম ফুটা হয়ে জন্ম নিলে যা হয়।',
#        'ওরে গাঁজা দিলো কে', 'সয়"তা\'ন বেডি কই জানি লুকাইয়া আছে',
#        'তোর মা হাসু পালাইছে। এই দায় এদেশের মানুষ নিবে না।।',
#        'তামাশা দেখা জনগনকে বুঝলি পা চাটা দালাল', 'কথা বল , এখন বলার সময়',
#        'নিচে কি সেটা আঁকা মা',
#        'বৌদ্ধ ধর্ম নারীর কোনো সম্মান\u200c দেয় না',
#        'অনুপম স্যার এবার বিস খাবে',
#        'আন্তর্জাতিক অঙ্গনে, সংখ্যালঘু নির্যাতনের কার্ড ইউজ করা ছাড়া, বাংলাদেশের রাজনীতিতে আওয়ামীলীগের পুনরায় ব্যাক করার আর দ্বিতীয় কোন অপশন নাই ',
#        'সবি মুতার জায়গায় গুতা খাওয়ার উন্নয়ন', 'সরিষার মধ্যে ভূত',
#        'হুদাই সো দেখানোর জন্য দিছে', 'অ*সভ্যের এত বড় সাহস',
#        'মানসিক সমস্যা আছে',
#        "বাবুচি হারুনের প্রিয় কোমল পানীয় লেবুর শরবত''",
#        'জয় বাংলা হোটেল সামলা', 'কাজী হায়াত তো হিরো আলমের সাথেও কাজ করে',
#        'পাবলিক পেলেসে দেওয়ার কি আছে', 'নিজের চরকায় তেল দেয়া দরকার',
#        'এবার মন খুলে দেখবেন',
#        'আধুনিকতার ছোঁয়ায় আমরা ইসলাম থেকে অনেক দূরে সরে গেছি',
#        'দিলা তো গরম করে',
#        'হালায় বুইড়া বেডিরে লইয়া বর প্রবলেমে আচে বুইড়া বেডি না নাচতে পারে না tiktok করতে জানে',
#        'অন্যায় নিপাত যাক,হক প্রতিষ্ঠা হোক',
#        'ভিডিও কি আর ক্যাপশন কি! পাগল',
#        'উফফ দেশ টা রাজাকার দিয়া ভইরা গেল।', 'আর একটু নিচেতো হাগুরপথ',
#        'ধুয়া তুলসিপাতা', 'শাকিব খান মানেই ব্র্যান্ড অ্যাম্বাসেডর',
#        'তলদেশে বরশি বাযাইয়া টান দিলেই সব ঠিক হইয়া যাইব',
#        'হেতে এইতা কিতা খয়।', 'মানবতা আজ কোথায়',
#        'আমি সমগ্র বাংলাদেশের হিন্দু সম্প্রদায়ের মানুষদেরকে এবং আওয়ামী লীগ বিরোধী সকল রাজনৈতিক দলগুলোকে সদা-সতর্ক থাকার জন্য বলছি, যাতে কোন ভাবেই আওয়ামী লীগ এই "খেলা" খেলতে না পারে।',
#        'বৌদ্ধ ধর্মের প্রবর্তক গৌতম বুদ্ধের একমাত্র পুত্র',
#        'এই বেআদব তা কে?', 'বিশিষ্ট কাল রাতের খাট ব্যবসায়ী',
#        'লেজ ধরে টানতেছে মনে করছি',
#        'আপনি কি গাজা একটু বেশি খাচ্ছেন নাকি আজকে একটু এক দোস বেশি পড়ছে, দয়া করে জানাবেন, আর কবে থেকে গাজা খাওয়া শুরু করেছেন সেটাও কমেন্টসে জানাবেন জনগণ জানতে চাচ্ছে।',
#        'পাগল তানিশা ওকে দেখলে বুমি আসে', 'এটা দলে আস্তে চাইছে মনে হয়',
#        'এমন নোংরামি এমনিতে বের হয়ে যাবে।', 'জামাই সেঁজে হাতে রুমাল',
#        'অহংকার আর ভাব ছুটে জাবে নি কয়দিন পরে,',
#        'এতগুলো আমেরিকান এর মাঝে একটা নিগ্র',
#        'চাঁদপুর এর মাল বলে কথা সব সময় বিনোদন এ সেরা',
#        'এমন একটা দল কর যেখানে কেউ ভালো বলতে পারেনা',
#        'আহা শুনা গো আমার। খুব কষ্ট যে মনা', 'আফচুষ লাগতেছে',
#        'কেঁচো খুড়তে সাপ বেরিয়ে আসছে',
#        'দুই বিয়ে বসার পরেও উনার পছন্দের পুরুষ নিয়ে এখনো ভাবে নাই',
#        'মুরুব্বী বলে কি', 'তোরা আবার বউ পাল্টা পাল্টি করলি নাকি',
#        'লাখো শহীদের রক্তে কেনাদেশটা কারো বাপের না',
#        'সময় হলে আসবে -- আগে দেখতে হবে এর সাথে আবার কোন কুচক্রী মহল জড়িত কি না।',
#        'জামাই কেঠ্যা,এই দলা আপার', 'পাপ এতো সহজে শেষ হবে না',
#        'ছি ছি ছি ছি ছাড়া কোন ভাষা নেই।',
#        'শাকিব খানকে পেয়ে কি স্বামীর কথার মনে আছে',
#        'জামাত-শিবিরের প্রেম আওয়ামী লীগ আজও বলতে পারেনি',
#        'জংগী সন্ত্রাসী জিহাদীরা কলিজার মধ্যে লালন-পালন করেন।',
#        'ভাই আপনারা যাই কন তাই কন আমি বিশ্বাস করি এইডারে খাইয়া দিছে শাকিব খান',
#        'কুলাউড়া দের কে সমাজ থেকে বাহির করা হোক দে',
#        'শিক্ষিতো ভাষায় কাঁচামরি', 'ছি এটা আমি আশা করি নাই',
#        'জন্মের ঠিক না থাকলে এমনই হবে', 'একটু অত্যাচার তো সয্য করতে হবে',
#        'কুমিল্লার আওয়ামী নেত্রী কে জয় বাংলা করে দিলো ছাত্রজনতা',
#        'রসিকতার একটা সীমা থাকে',
#        'সমর্থনপুষ্ট একজন নারী কিভাবে এভাবে সমুদ্র গোসল করতে পারে?',
#        'বেডার ধৈর্য দেখে আমি শিহরিত', 'বাংলাদেশের জাতীয় সবজিন নাম বেগুন',
#        'ইজ্জত এর ভয়ে মন খুলে কমেন্ট করতে পারি না',
#        'নাড়াচাড়া পরলে তো উন্নয়ন তো হবেই', 'ভাই ওর পিরিয়ড চলতাছে মনে হয়',
#        'এই ফেরাউনের সাথে গান এড করে গানের ইজ্জত নষ্ট করা হচ্ছে।',
#        'আমি তো চাই তুমি মোরে তুইলা নিয়া ধর্ষন কর।', 'হালায় কামডা করলো কি',
#        'বিনোদন দিলা নাতি ', 'ভগবানের অকাল মৃত্যুতে আমরা গভীর শোকাহত',
#        'যারা এরকম অন্যায় কাজ করছে তাদের ধরিয়ে দিন',
#        'টা টাইটানিক না এটা নৌকা।', 'তোর ভিতরে কুকুর আছে।',
#        'চরম লেভেলের বদমায়েশি', 'লিজেন্ড রা অন্য কিছু দেকবে',
#        'কনফার্ম জান্নাতি', 'সব খানে দুর্নীতি হতো কোন জাইগা বাদ যাইতো না',
#        'প্রাতিষ্ঠানিক শিক্ষা কেমন তবে মানসিক শিক্ষার অনেক অভাব',
#        'লিভার আছে না গেছে',
#        'প্রতিভা কি দেখলাম আমি তো শুনতেছি অশ্লীল শব্দ বালে',
#        'হুংকার গারে গুঁজে দিয়েছে',
#        'সামাজিক দূরত্ব বজায় রেখে গালাগালি করুন।', 'মূলার জুশ পান করেন',
#        'ভাই থেকে কিভাবে চুদির ভাই হয়ে গেলি',
#        'কখনো গিটার ধরেই দেখলাম না বাজাতে পারাটা বিলাসিতা',
#        'প্রবাসীরা রেমিট্যান্স যোদ্ধা', 'আঁকেন তবে নিচের দিকে',
#        'জুতাচোর কোথাকারের মতো দেখা যায়', 'তোর কিডনির মাগফেরাত কামনা করি',
#        'চুদ্দে মাসিক বন্ধ কইরা ফালামু',
#        'ধর্ম নিয়ে রাজনীতি সবচেয়ে বড় দূর্ণীতি"',
#        'এর চেহারার মধ্যে বদমাশ বদমাশ ভাব', 'হারবাল লাভ',
#        'খাংকির পুলা বাল লাগে না তোর', 'জজ্ঞলে কাম সারতে জাইতেছে',
#        'নৌকা তো মিয়া হাওয়াই চলে।',
#        'শোকের রঙ হিসেবে কালোকেই প্রত্যাখ্যান করলাম।', 'নাক বুছি করে কেমন',
#        'কঠোর পরিশ্রমের সফলতা', 'তুমি মিয়া দালাল', 'বাহ্ অসাধারণ কিস',
#        'কোনো সভ্য মায়ের অসভ্য সন্তান বিয়াদব', 'সময় দুষ্ট কোকিলের',
#        'বিনা দোষে হাজার হাজার প্রান শেষ করে দিলি আর এখনো বলতেছিস কি দোষ করেছিস',
#        'জামাত ইসলাম কে খোজা দিলেন কেন হুজুর',
#        'আর আমাদের দেশের নেতা রাই একেক টা পর্ণস্টার খুব গর্বের সাথে এরা এটা প্রকাশ করে',
#        'বাংলাদেশ কি নারায়ান হয়েগেছে', 'নস্ট একটা মহিলা',
#        'বোতলের গোয়ায় চুমু দেয় কেন?', 'চলিতেছে সার্কাস',
#        'সুবিধাবাদী জিন্দাবাদ', 'ইজ্জত হারা লোক আপনাদের কি মত?',
#        'আগে চাপা দে পরে দেখা যাবে', 'নেতার তো ভিসা রেডি',
#        'আপনারা চান কি বলেন তো?', 'এসব কি শুনি', 'হলো চোর',
#        'অভিনয় দেখে মনে হচ্ছে, সব গুলো পাবনার পাগল',
#        'বিচি ছাড়া গরু চলবে না',
#        'কুত্তার বাচ্চা মানুষের তো অনেক অশান্তির মাঝে রাখছো এবার মানুষ একটু শান্তিতে মইরা',
#        'কামড়াকামড়ি করে জিতলেও জানাবেন হারলেও জানাবেন',
#        'এই বলদে খালি হাসে', 'যত দুর্নীতি আছে, সব ফাঁস করে দেন',
#        'ও আচঁল ধরে টান দিওনা লাজে মরে যায়',
#        'হায়রে সাংবাদিক তোরে তো ধর্ষণ করে ছারছে',
#        'তা বলি কি কুত্তালীগের মতো বিএনপি এমন নৈরাচার কখনো করেছিলো?',
#        'ধর্ষকদের বিরুদ্ধে গন আন্দোলন', 'ইন্টারভিউ ছাড়া অটো চাকুরী',
#        'মাদারবোর্ড কান্না করে আর আমরা আলহামদুলিল্লাহ বলি',
#        'ভবিষ্যতে ১২ ভাতারি', 'ইন্ডিয়া হটাও বাংলাদেশ জিন্দাবাদ',
#        'দেশের আইন ব্যবস্থা কি ধ্বংস হয়ে গেছে?', 'বেহায়ামণি হইলে যা হয়',
#        'সব বাজেয়াপ্ত করার জোর দাবি জানাচ্ছি।',
#        'মানুষ একসাথে থেকেই পিঠে ছুরি মারে',
#        'পুলিশের সাথে ছাত্রলীগের ক্যাডাররা দাঁড়ায়',
#        'তোরে ফোন মারে দিবে পাবলিকে শালার ঘরের শালা', 'হিজড়াদের মিলনমেলা',
#        'নেয়া ভাই আমনে মোগো মুক্তি দেন', 'জুতা মারি তোর মুখে সালা',
#        'সোনাটা তো অতো বড় না', 'হ্যাপি বাড্ডে কি রে ভাই?', 'হাউন আঙ্কেল',
#        'দাবায়ে রাখতে পারবানা', 'সব চরিত্রহীন মানুষগুলো একসাথে হইছে',
#        'পুলাডার বুদ্ধি কম আছে, হরলিক্স খা বেটা',
#        'লম্পট স্বৈরাচারী হযরত নবীর খেজুর।', 'পাগলের সুখ মনে মনে',
#        'মন চাইতাছে নিজের বিচিতে নিজে টিপডা মইরা যাই',
#        'অবৈধ ভাবে এসব কে পয়দা করিস না', 'প\u200d্যান্ট হলুদ হয়া যাবে না?',
#        'নতুন সানাই মাহবুব।',
#        'প্রিয়া জান্নাতুল তো নিজের কর্মকান্ডে ভাইরাল। আবার নতুন করে সাকলায়েনের সাথে জড়িয়ে ভাইরাল হওয়ার দরকার কি?',
#        'রাস্তার প্রাণীদের সংসার আছে নাকি --?', 'কি করলি জীবনে',
#        'এসব উসকানি মূলক', 'ও কি বুঝবে',
#        'ওরে দেখে আমার কাছে পতিবন্ধি মনে হলো',
#        'বায়ো টা কিন্তু এখনো আছে, মীর জাফর দের কে কখনো বিশ্বাস করা যায় না। ৭ মিনিটে ক্লিয়ার করো এখন আসো রাজপথে...',
#        'ফর্নো স্টার দিয়েই জান্নাতে যাবি',
#        'এতে দেশের বা****** উপকার হবে ফালতু',
#        'তোর চেহারারটা এক বার আয়নায় দেখেছিস।',
#        'আমি ত বউ এর মাথা খুজে পাচ্ছিলাম না', 'সাদা সাদা কালা কালা',
#        'দোষ হয় খালি পরিমনীর', 'আলহামদুলিল্লাহ আবারো স্বাধীন',
#        'ওরে এক বোতল হারপিক দে', 'লাফালাফি একদম বন্ধ হয়ে গেছে।',
#        'মেশিন কি দুর্বল নাকি ভাই তোর', 'ক্ষমতা কারো চিরস্থায়ী নয়,',
#        'একটা ভিডিও দেখলাম না মন্দির ভাংগার,একটা দেখলাম মহিলারা মন্দিরের সামবে গড়াগড়ি করে কাদছে,মূর্তি ভাংগা টাংগা দেখায় না,দেখেই বুঝা যায় নাটক।নাটক কম করো পিও',
#        'জাহিদ খান নিয়ে দাজ্জাল আসলে',
#        'তর মাত মাল পাইলে শাস্তি পেতেও রাজি',
#        'ফকিন্নির বাচ্চারা মানুষের ইমোশন নিয়ে খেলা করস.',
#        'আজকে মালে নেশা না রে পিনিক পিনিক লাগে',
#        'গিটার টা কই পাওয়া যাইবো', 'কইরা লাইছিরে ভাই',
#        'ওমাগো হিন্দি মারানী..', 'পুটকি লাল করার শখ হইছে ',
#        'কারন রবীন্দ্রনাথ মনে মনে কল্যানি কে ভালোবাসতো',
#        'চাচ লুঙ্গিটা একটু ভালো করে আটকান',
#        'ভাইপো আজকে ইন্ডিয়ার হালাতো ভাইয়েরা ইচ্ছে মত পিঠাইছে মুস্তাফিজসহ কয়েকজনকে',
#        'তুই মুরগী বিক্রি কর ভালো হবে', 'কোপা ফাইনালে তাকে দেখতে চাই',
#        'আর এদিকে বাল কে গালি না মনে করা আমি',
#        'থুক্কু বায়ু পথে মানে আকাশ পথে', 'এইরকম একটা বউ দরকার,',
#        'পচা খাবারে সব সময় মাছি বৌ বৌ করে,', 'তর মার হেডা চুদানির ফুয়া',
#        'উনার আলাদাই টেনশন চলছিল',
#        'চাপা মানে মিথ্যা কথা আর মিথ্যা কথা মানে জাহান্নামে জাওয়ার রাস্তা।',
#        'বেগুন ঢুকাই ঢুকাই শরিল কি করছিস', 'ইনবক্সে গালি দিছি চেক দিয়েন',
#        'এতদিন চুপ থাকলে সোহান এখন সাহস করে মুখ খুলে ফেলললো',
#        'চামচামি করতে আর জায়গা পায়না',
#        'অবস্থা দেখে মনেহচ্ছে একেকটা যেন পাগলাগারদ থেকে পালিয়ে এসেছে',
#        'আমি এত দুর্বল কেন', 'ব্রেইন লেফট দ্যা হেড',
#        'কি দিন আইলো সবাই খালি লিংক চায়', 'হালার সুয়রর সুদাইন কুবাইকুর',
#        'ভগবান শ্রী রাম মানে রামপাঁঠা!!', 'ওও পাখি পাখিরে',
#        'মালডারে চেনা চেনা লাগেরে', 'জুতার বারি খাবি রিপন ভিডিও চোদাও',
#        'আরে মিয়া এই নৌকা হজরত শেখ হাসিনার নৌকা এত সহজে ডুববে না',
#        'সাগরে আমি তালের নৌকা চালিয়ে আমেরিকাই জাবো?',
#        'বুঝলাম কিছু আপুটার ডাব গুলো বের করে ভিডিও বানা কেন',
#        'ভুড়ি পরিস্কার করার পরে শাড়ি পড়ে পিক দিও',
#        'সাবাস বেটা এগিয়ে যান বহুদূরে',
#        'কলা খুব পছন্দ তাই অনেক কাজে লাগে কলা রাতে লাগে',
#        'যে নৌকায় এত্ত এত্ত লীগ আছে,সে নৌকা কী করে ভেসে থাকবে?',
#        'কিছু না জানা হুজুগে বাংগালী যারা গুজব লীগ দ্বারা ব্রেইনওয়াসড!',
#        'সেই প্রেশার মাপা হয়েছে',
#        'জামাইরে দেখে পানি ফালাইতে পাড়সনাই দেখে এত দরত উতলাইয়া পড়তাচেনি',
#        'নুনু কাজেরনা অইটা রাইখা লাভ কি', 'তোদের ভারত কলা দেখিয়ে দিয়েছে',
#        'বাঞ্চোত কে দেখে আমার এমবি লস', 'ভোদার জালা বেশি থাকলে যা হয় আরকি',
#        'নিপুন বলে ডিপজল মুর্খ', 'শাহবাগী রা সবাই আস্তিক',
#        'লাচ্ছি ও নাই আরাম ও নাই', 'ট্রাকের কোন বরিশালে ভাত নাই',
#        'খাম্বা তারেক এর মা', 'অসভ্য মহিলা। আর কিছু বলার নেই',
#        'মালগুলো আছে কই', 'আস আমার বাসায়', 'পারিবারিক শিক্ষার অভাব',
#        'বাংলাদেশে হচ্ছে একটি গরীব দেশ,,,',
#        'পদ্মা মেঘনা যমুনা এটা তো শেখ হাসিনার ডায়লগ \nতাহলে তারা কি শেখ হাসিনার এজেন্ডা হয়ে আন্দোলন করতেছে??',
#        'গুষ্টি মারছে।।। এতো পিনিক কই থেকে',
#        'আমার এক্স ও আমার সাথে দুর্নীতি করছে',
#        'তুই আল্ল\u200d্যর পাল্লা মারা পাঠা', 'আজকে কোমর ভেঙ্গে যেতে পারে',
#        'দাজ্জালের বিরুদ্ধে যুদ্ধ ঘোষণা',
#        'চুরে চুরে আলী এক চুরে বিয়া করে আর এক চুরের সাদী।',
#        'ডান্ডি খোর,, আর হিজরা', 'মাউন্টেন ডিয়্যু ভয়ের মারে বাপ..',
#        'শালায় যীশুর ছবি রাখছে রুমের ভিতরে', 'আহো ভাতিজি আহো',
#        'সালার কথা গুলো পাঠার মতো গন্ধ।',
#        'মানুষ যত শিক্ষিত হবে তত টয়লেট ঘরের ভিতরে ঢুকবে',
#        'মেয়েটি কি ব্রা পরেনাই', 'বিয়ের সময় শিক্ষিত বেকার,',
#        'ভারত একটা বাওতাবাজ রাষ্ট্র,,,', 'রোজার পরে পোস্ট দিয়েন',
#        'জয় না নিয়ে ঘরে ফেরো না', 'তোগর দেখতে ঢাকা মেডিকেল যাওয়া লাগে',
#        'হিন্দু সম্প্রদায়ের মেয়েরা হচ্ছে হিন্দু জাতির জন্য কলঙ্ক।।',
#        'ইনবক্সে গালি দিছি চেক কইরো',
#        'নবাব ব্যাটিংয়ে আসলে মীর জাফররা কঠিন থেকে কঠিনতম বোলিং করা শুরু করে।',
#        'তুই তো মা মন টুকাই ছিলি তুই তো ঢুকাবি',
#        'ধিক্কার জানাই কনডম এবং মেডিসিন কোম্পানিকে এত পরীক্ষার পরেও কিভাবে দুর্ঘটনা ঘটে',
#        'নষ্ট নারী', 'ওবার ডেট মাল খাইলে যা হয় আর কি',
#        'এখন তো একদল লোক বলবে এটা তাহেরি আঙ্কেল', 'বাংলাদেশের পরিবেশ নষ্ট',
#        'ওরে তো পিছন মারা উচিৎ', 'ভাই খেলাটা দেখতে পারলাম না',
#        'শাহারিয়া নাদিম জয়, কঠিন একটা মাল',
#        'নদি মাতৃক বাংলার জলে নৌকাইতো ভরসা স্থল।',
#        'কুরআন হাদিসের আলোকে দলিল মানিনা।',
#        'আর্জেন্টিনার জার্সি গায়ে বসে থাকা জায়েদ খানকে বাংলাদেশের পতাকা হাতে...',
#        'কুত্তায় চুদলে যা হয় আর কি',
#        'সরকার সফল একটি সন্ত্রাসী লীগ তৈরি করেছে।',
#        'যাহারা করে জিয়া জিয়া, তাদের আম্মা করে ইয়া ইয়া',
#        'কারো না কারো বড়ো ওবদান আছে এখানে', "ফালায়া দিলাম' এটা আবার কি",
#        'কথায় কথায় হিন্দু নাম নেন কেন?', 'ফেরাউন, নম্রুদ এরকমই ছিল একদম।',
#        'এমন গর্ত কি আর পাবো', 'ডেটে গেলে বাড়ি রেখে যাবো',
#        'হাছিনাকে পয়দা করা....', 'ছাগলে কি বলে আর পাগলে কি করে',
#        'খাল কেটে কুমির',
#        'মুসলিম নামক এই শব্দটি মুছে যাক শুধু হিন্দু ধর্ম থাক',
#        'শেষমেষ গানের ইজ্জতটা নষ্ট করে দিল আলম ভাই,,,',
#        'শয়তানের ধোকার মধ্যে পড়ে আছে,', 'ফুটবলারের সম্মানে আঘা’ত',
#        'তুই কোন গর্তে আগে সেটা বল মা***', 'আজাইরা ফষ্টি নষ্টি',
#        'পথ ভূষ্ট সঠিক নয়,,পদ হারা রাইট',
#        'সেফুদার কাছে পাঠিয়ে দেওয়া হোক তাকে,,',
#        'পর্ন স্টাররা ও চোররা দেশ স্বাধীন করছে', 'যেখানে পাবেন, বাটবেন',
#        'নিচে আপাকে চাটতে হবে', 'কে খারাপ তুমি', 'অন্যায় অবিচার জুলুম!',
#        'ঘুমাইলাম কাম শেষ হইলে আমারে ডাক দিস', 'এখানে অনেক কিছু বোঝার আছে',
#        'হানিবানি ম্যাডাম ঠিক এই ভাবে কথা বলে',
#        'নামধারী আলেম শুধু লেগে থাকেন একজন আরেকজনের দোষ খুঁজতে',
#        'পাগলা গারদে মোবাইল ইন্টারনেট ব্যাবহার করা যায় বাহ দেশ তো আগায় যাইতাছে',
#        'মাতারির বাড়ির লোকেশন দেন', 'কুকুর মালিকের সাথেই থাকে সবসময়।'],
#       dtype=object)

# %%
(py_inputs, py_attn_masks,py_ids) = make_smart_batches_on_test(test_sentences,test_ids, 16,tokenizer,max_input_length)
y_pred , y_true = get_predictions(py_inputs, py_attn_masks, py_labels)
# Out:
# Creating Smart Batches from 600 examples with batch size 16...
#
# Tokenizing 600 samples...
#   Tokenized 0 samples.
#   Tokenized 60 samples.
#   Tokenized 120 samples.
#   Tokenized 180 samples.
#   Tokenized 240 samples.
#   Tokenized 300 samples.
#   Tokenized 360 samples.
#   Tokenized 420 samples.
#   Tokenized 480 samples.
#   Tokenized 540 samples.
# DONE.
#        600 samples
#
#        600 samples after sorting
#
# Creating batches of size 16...
#
#   DONE - Selected 38 batches.
#
# Padding out sequences within each batch...
#   DONE.
# Predicting labels for 38 test batches...
#   Batch       4  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch       8  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      12  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      16  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      20  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      24  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      28  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      32  of       38.    Elapsed: 0:00:01.  Remaining: 0:00:00
#   Batch      36  of       38.    Elapsed: 0:00:01.  Remaining: 0:00:00

# %%
y_pred
# Out:
# array([0, 0, 0, 5, 5, 0, 0, 5, 2, 4, 5, 5, 5, 0, 0, 0, 0, 2, 5, 5, 2, 5,
#        4, 0, 4, 5, 4, 5, 0, 5, 3, 4, 5, 0, 0, 0, 1, 0, 3, 0, 0, 0, 0, 0,
#        4, 5, 0, 0, 0, 4, 2, 4, 0, 0, 2, 5, 0, 0, 0, 0, 5, 0, 0, 0, 0, 5,
#        5, 5, 0, 2, 0, 5, 0, 5, 5, 5, 0, 2, 2, 0, 4, 5, 4, 4, 0, 3, 0, 0,
#        5, 5, 0, 0, 2, 5, 0, 0, 0, 0, 5, 5, 2, 5, 0, 2, 0, 2, 0, 2, 5, 5,
#        0, 0, 5, 5, 5, 3, 5, 5, 0, 2, 3, 4, 5, 0, 0, 4, 0, 5, 0, 0, 5, 5,
#        4, 5, 5, 5, 5, 5, 5, 0, 3, 4, 0, 5, 5, 4, 5, 0, 4, 0, 0, 0, 0, 5,
#        0, 3, 0, 5, 4, 0, 0, 5, 5, 2, 5, 5, 5, 0, 5, 5, 0, 5, 5, 5, 3, 5,
#        2, 0, 3, 0, 0, 2, 4, 0, 2, 2, 5, 0, 0, 4, 5, 0, 0, 0, 2, 5, 4, 0,
#        4, 5, 0, 0, 0, 0, 0, 5, 2, 2, 0, 0, 4, 0, 5, 0, 0, 5, 5, 0, 5, 0,
#        0, 3, 0, 0, 5, 5, 2, 5, 0, 0, 5, 5, 5, 3, 2, 5, 2, 5, 5, 5, 5, 5,
#        1, 5, 4, 3, 0, 3, 5, 0, 5, 0, 0, 3, 0, 2, 5, 5, 5, 5, 0, 0, 0, 5,
#        0, 5, 5, 5, 0, 5, 1, 3, 0, 5, 0, 0, 0, 2, 5, 0, 0, 2, 2, 4, 5, 0,
#        0, 0, 0, 4, 4, 5, 0, 4, 0, 0, 5, 4, 5, 2, 0, 0, 2, 4, 2, 5, 0, 5,
#        5, 5, 0, 0, 4, 5, 0, 5, 5, 0, 5, 5, 0, 0, 5, 0, 2, 5, 5, 5, 5, 3,
#        0, 5, 3, 5, 0, 0, 5, 2, 5, 3, 3, 5, 5, 0, 0, 0, 2, 0, 0, 0, 0, 0,
#        0, 0, 5, 5, 0, 0, 5, 5, 0, 2, 0, 0, 5, 0, 0, 0, 4, 4, 4, 2, 0, 5,
#        0, 2, 5, 2, 0, 0, 0, 5, 2, 5, 5, 5, 3, 2, 0, 0, 0, 0, 5, 4, 3, 5,
#        3, 5, 5, 0, 0, 5, 3, 5, 0, 5, 0, 4, 0, 0, 5, 5, 0, 0, 5, 5, 5, 5,
#        0, 5, 2, 0, 3, 5, 4, 5, 2, 0, 5, 5, 5, 3, 5, 5, 0, 4, 5, 5, 0, 5,
#        5, 4, 0, 5, 2, 2, 0, 0, 0, 3, 0, 0, 0, 5, 0, 0, 0, 5, 0, 0, 2, 4,
#        0, 0, 3, 5, 0, 0, 4, 0, 2, 5, 5, 0, 0, 0, 0, 3, 5, 5, 0, 5, 4, 0,
#        2, 2, 5, 2, 0, 2, 3, 0, 0, 0, 4, 0, 0, 0, 0, 2, 3, 0, 5, 4, 2, 0,
#        0, 0, 0, 4, 5, 4, 5, 5, 5, 5, 4, 5, 0, 0, 0, 0, 5, 5, 5, 5, 0, 4,
#        0, 4, 0, 2, 5, 0, 5, 4, 0, 5, 2, 4, 2, 3, 2, 2, 5, 0, 2, 2, 1, 2,
#        5, 0, 0, 5, 3, 4, 5, 5, 0, 0, 5, 0, 5, 5, 4, 0, 0, 2, 5, 0, 5, 5,
#        0, 0, 2, 4, 1, 0, 5, 2, 0, 4, 0, 0, 0, 4, 0, 5, 5, 5, 5, 2, 2, 5,
#        5, 0, 0, 0, 2, 2])

# %% [markdown]
# ## Evaluating accuracy over test set

# %%
y_ids,y_preds  = get_predictions_test(py_inputs, py_attn_masks,py_ids)
# Out:
# Predicting labels for 38 test batches...
#   Batch       4  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch       8  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:01
#   Batch      12  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      16  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      20  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      24  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      28  of       38.    Elapsed: 0:00:00.  Remaining: 0:00:00
#   Batch      32  of       38.    Elapsed: 0:00:01.  Remaining: 0:00:00
#   Batch      36  of       38.    Elapsed: 0:00:01.  Remaining: 0:00:00

# %%
print(y_preds)
# Out:
# [0 0 0 5 5 0 0 5 2 4 5 5 5 0 0 0 0 2 5 5 2 5 4 0 4 5 4 5 0 5 3 4 5 0 0 0 1
#  0 3 0 0 0 0 0 4 5 0 0 0 4 2 4 0 0 2 5 0 0 0 0 5 0 0 0 0 5 5 5 0 2 0 5 0 5
#  5 5 0 2 2 0 4 5 4 4 0 3 0 0 5 5 0 0 2 5 0 0 0 0 5 5 2 5 0 2 0 2 0 2 5 5 0
#  0 5 5 5 3 5 5 0 2 3 4 5 0 0 4 0 5 0 0 5 5 4 5 5 5 5 5 5 0 3 4 0 5 5 4 5 0
#  4 0 0 0 0 5 0 3 0 5 4 0 0 5 5 2 5 5 5 0 5 5 0 5 5 5 3 5 2 0 3 0 0 2 4 0 2
#  2 5 0 0 4 5 0 0 0 2 5 4 0 4 5 0 0 0 0 0 5 2 2 0 0 4 0 5 0 0 5 5 0 5 0 0 3
#  0 0 5 5 2 5 0 0 5 5 5 3 2 5 2 5 5 5 5 5 1 5 4 3 0 3 5 0 5 0 0 3 0 2 5 5 5
#  5 0 0 0 5 0 5 5 5 0 5 1 3 0 5 0 0 0 2 5 0 0 2 2 4 5 0 0 0 0 4 4 5 0 4 0 0
#  5 4 5 2 0 0 2 4 2 5 0 5 5 5 0 0 4 5 0 5 5 0 5 5 0 0 5 0 2 5 5 5 5 3 0 5 3
#  5 0 0 5 2 5 3 3 5 5 0 0 0 2 0 0 0 0 0 0 0 5 5 0 0 5 5 0 2 0 0 5 0 0 0 4 4
#  4 2 0 5 0 2 5 2 0 0 0 5 2 5 5 5 3 2 0 0 0 0 5 4 3 5 3 5 5 0 0 5 3 5 0 5 0
#  4 0 0 5 5 0 0 5 5 5 5 0 5 2 0 3 5 4 5 2 0 5 5 5 3 5 5 0 4 5 5 0 5 5 4 0 5
#  2 2 0 0 0 3 0 0 0 5 0 0 0 5 0 0 2 4 0 0 3 5 0 0 4 0 2 5 5 0 0 0 0 3 5 5 0
#  5 4 0 2 2 5 2 0 2 3 0 0 0 4 0 0 0 0 2 3 0 5 4 2 0 0 0 0 4 5 4 5 5 5 5 4 5
#  0 0 0 0 5 5 5 5 0 4 0 4 0 2 5 0 5 4 0 5 2 4 2 3 2 2 5 0 2 2 1 2 5 0 0 5 3
#  4 5 5 0 0 5 0 5 5 4 0 0 2 5 0 5 5 0 0 2 4 1 0 5 2 0 4 0 0 0 4 0 5 5 5 5 2
#  2 5 5 0 0 0 2 2]

# %%
print(y_ids)
# Out:
# [2819 1888 4250 2913 2858 2770  613  751 4562 5000 5317 4756 5591 1407
#  2584 4353 1487 5892 4020 1905   93 3459 5846  501 5026 5683 5314 3869
#  1881  230 5094 4184 3492 2168 1879  168 1559 4838 5272  655 1002 5261
#  1322 4240 4280 1225 5294 2080 1837 1186 4098 4594  960 5544 3967 1536
#  3651  486  443 5687 2370 3617 4945 1586  414 1630 3670  439 5112 3130
#  1400 3182 5330 5692 3289  437 3796 3163 3135 2410  742 3396 5006  452
#   100 1192  977 4343  227 3320 3667 1569 1612 2420 2018 4878 4264 2742
#  1315  776 5118  124  239 4001  297 3856  805 3392  308  292 1039  393
#  2313 5297 2638 2663 1451 1057 3077 2677 1042  794 3784 4607 4956 1188
#  1024 4758 2767 4603 4808 3973 5164 1507 4526 3550 2812 1075 1163 1448
#  2377 4686 1617 4269 1543   15 5351 1209 3413 2187 1871 1859 2439 3285
#  3607 5799  812 1755  691 2900 1158 3700 3193 4369 3033 2163 3734 2463
#  2002 2115 2775 2323 3525 5658 1438 2977 4541 4745 5110 5409  167 4655
#   747 5751 3372 3240  896 1073  530 4832 2347 5790 5597   29 5322 5400
#  5273  333 5495 1694 5684 5492 1891 1535  319  476 1817 1328 4557  996
#   445 5693 3544 4196 1161 2788 2086  296  752 3045 3204 5800  293  472
#  1144 5565 3671 5109  198 3103 2549 4733 2022 1420 3833 5661 2516  746
#  1345 2091   23 1620 1477  432 2945 5648 1221 5454 5289 5830 3158 5638
#   810 3813 1354 3799 3647 4866 4724 3184 2357 4939 4674  748 1564  228
#  2957 1729 1454 2885 1370 1033 1084 4633 5690  478 1397 3185 3035 3916
#  4983 1383 3934 5459 1803 4192 1496 5694 4071 5095 5959  324  549 5210
#   286 5931  110 5488 3938   65 3593 4999 2476 5224 3707 4379  681 3053
#  1172 3664 4614 1514 1344 5545 2350 2210 4706 4333 4738 2874 4028 3187
#  2795 5769 3720 3469 2024 2602 3094 2857 1918 2995 1090 5907 4629 5825
#  2275 3958  199 2611 1374  706 2617 5525 1485 3970 4734 1765 1652 5329
#   177  380 2846 3488 2292 1669  142 1499 2450 4635 1966 5803 5854 1773
#  1142   47 4708 1086 4930 5241 3379 5912  911 3167  183 5663  381 5948
#   121 3226  346 5787 4101  787 3905 1657 1183 4691  408 1488 1902 2142
#  1533 3407 3937 2227 2432 3309  586 4275 3895 2157 4714 3127  964 3012
#  5828 5169  135 4472 5138 4650 1027  683 3805 2287 1561 3133  978 1253
#   247 5364 1032 1634 3557 4454 4666 3494 1873 2263 4383 5395 3484 3090
#   584 4581 4423 2915  505 4698 2841 1204 2225 1706 5563 1964 1176  622
#  3751 2244 3669   84 1894 1049   71 2445  604 2223 2077 4476 2559 5460
#  3487 1726 1562 1545 3624 2133 4441 5837 2653  422 4480 5368 4301   69
#  2127 4046 5851 3764 1121 2380 1566 1623 4879 5992  351 3971 5556 3382
#   181 1297 1844  473  625  336 2031 1671 2892  245 3892  371  185 5047
#  4310 5808 4876 5479 1357 5034  259 5050 1720 1094 2704 2436 5303 4620
#  4886 2503 4362 3552 3149 5747 1321 4630 2798   14 4834 1194 4762 4458
#  1864 5823 2834 4568  605 3815 2968 5470 2650 5639 4503 3821 2213 2447
#  3795 3409 2272 1047  497 3529 4668 1745 5404 2240 2146 1471 5283 2338
#  3877 4190 3026 4950 4796 5606 1978 5098  469  453 3946 2802 3867 5708
#  4102 4103 5510 1505 5527 3859 5217 4815 1965 3886 4393  969 1219 2298
#  3181 1666 2083 2598 3710 3917 1609 2110 4742 4258 3942 4010]

# %%
le.inverse_transform(y_preds)
# Out:
# array(['Cyberbullying', 'Cyberbullying', 'Cyberbullying', 'Sarcasm',
#        'Sarcasm', 'Cyberbullying', 'Cyberbullying', 'Sarcasm',
#        'Political', 'Religious_Hatred', 'Sarcasm', 'Sarcasm', 'Sarcasm',
#        'Cyberbullying', 'Cyberbullying', 'Cyberbullying', 'Cyberbullying',
#        'Political', 'Sarcasm', 'Sarcasm', 'Political', 'Sarcasm',
#        'Religious_Hatred', 'Cyberbullying', 'Religious_Hatred', 'Sarcasm',
#        'Religious_Hatred', 'Sarcasm', 'Cyberbullying', 'Sarcasm',
#        'Racism', 'Religious_Hatred', 'Sarcasm', 'Cyberbullying',
#        'Cyberbullying', 'Cyberbullying', 'Gender_Discrimination',
#        'Cyberbullying', 'Racism', 'Cyberbullying', 'Cyberbullying',
#        'Cyberbullying', 'Cyberbullying', 'Cyberbullying',
#        'Religious_Hatred', 'Sarcasm', 'Cyberbullying', 'Cyberbullying',
#        'Cyberbullying', 'Religious_Hatred', 'Political',
#        'Religious_Hatred', 'Cyberbullying', 'Cyberbullying', 'Political',
#        'Sarcasm', 'Cyberbullying', 'Cyberbullying', 'Cyberbullying',
#        'Cyberbullying', 'Sarcasm', 'Cyberbullying', 'Cyberbullying',
#        'Cyberbullying', 'Cyberbullying', 'Sarcasm', 'Sarcasm', 'Sarcasm',
#        'Cyberbullying', 'Political', 'Cyberbullying', 'Sarcasm',
#        'Cyberbullying', 'Sarcasm', 'Sarcasm', 'Sarcasm', 'Cyberbullying',
#        'Political', 'Political', 'Cyberbullying', 'Religious_Hatred',
#        'Sarcasm', 'Religious_Hatred', 'Religious_Hatred', 'Cyberbullying',
#        'Racism', 'Cyberbullying', 'Cyberbullying', 'Sarcasm', 'Sarcasm',
#        'Cyberbullying', 'Cyberbullying', 'Political', 'Sarcasm',
#        'Cyberbullying', 'Cyberbullying', 'Cyberbullying', 'Cyberbullying',
#        'Sarcasm', 'Sarcasm', 'Political', 'Sarcasm', 'Cyberbullying',
#        'Political', 'Cyberbullying', 'Political', 'Cyberbullying',
#        'Political', 'Sarcasm', 'Sarcasm', 'Cyberbullying',
#        'Cyberbullying', 'Sarcasm', 'Sarcasm', 'Sarcasm', 'Racism',
#        'Sarcasm', 'Sarcasm', 'Cyberbullying', 'Political', 'Racism',
#        'Religious_Hatred', 'Sarcasm', 'Cyberbullying', 'Cyberbullying',
#        'Religious_Hatred', 'Cyberbullying', 'Sarcasm', 'Cyberbullying',
#        'Cyberbullying', 'Sarcasm', 'Sarcasm', 'Religious_Hatred',
#        'Sarcasm', 'Sarcasm', 'Sarcasm', 'Sarcasm', 'Sarcasm', 'Sarcasm',
#        'Cyberbullying', 'Racism', 'Religious_Hatred', 'Cyberbullying',
#        'Sarcasm', 'Sarcasm', 'Religious_Hatred', 'Sarcasm',
#        'Cyberbullying', 'Religious_Hatred', 'Cyberbullying',
#        'Cyberbullying', 'Cyberbullying', 'Cyberbullying', 'Sarcasm',
#        'Cyberbullying', 'Racism', 'Cyberbullying', 'Sarcasm',
#        'Religious_Hatred', 'Cyberbullying', 'Cyberbullying', 'Sarcasm',
#        'Sarcasm', 'Political', 'Sarcasm', 'Sarcasm', 'Sarcasm',
#        'Cyberbullying', 'Sarcasm', 'Sarcasm', 'Cyberbullying', 'Sarcasm',
#        'Sarcasm', 'Sarcasm', 'Racism', 'Sarcasm', 'Political',
#        'Cyberbullying', 'Racism', 'Cyberbullying', 'Cyberbullying',
#        'Political', 'Religious_Hatred', 'Cyberbullying', 'Political',
#        'Political', 'Sarcasm', 'Cyberbullying', 'Cyberbullying',
#        'Religious_Hatred', 'Sarcasm', 'Cyberbullying', 'Cyberbullying',
#        'Cyberbullying', 'Political', 'Sarcasm', 'Religious_Hatred',
#        'Cyberbullying', 'Religious_Hatred', 'Sarcasm', 'Cyberbullying',
#        'Cyberbullying', 'Cyberbullying', 'Cyberbullying', 'Cyberbullying',
#        'Sarcasm', 'Political', 'Political', 'Cyberbullying',
#        'Cyberbullying', 'Religious_Hatred', 'Cyberbullying', 'Sarcasm',
#        'Cyberbullying', 'Cyberbullying', 'Sarcasm', 'Sarcasm',
#        'Cyberbullying', 'Sarcasm', 'Cyberbullying', 'Cyberbullying',
#        'Racism', 'Cyberbullying', 'Cyberbullying', 'Sarcasm', 'Sarcasm',
#        'Political', 'Sarcasm', 'Cyberbullying', 'Cyberbullying',
#        'Sarcasm', 'Sarcasm', 'Sarcasm', 'Racism', 'Political', 'Sarcasm',
#        'Political', 'Sarcasm', 'Sarcasm', 'Sarcasm', 'Sarcasm', 'Sarcasm',
#        'Gender_Discrimination', 'Sarcasm', 'Religious_Hatred', 'Racism',
#        'Cyberbullying', 'Racism', 'Sarcasm', 'Cyberbullying', 'Sarcasm',
#        'Cyberbullying', 'Cyberbullying', 'Racism', 'Cyberbullying',
#        'Political', 'Sarcasm', 'Sarcasm', 'Sarcasm', 'Sarcasm',
#        'Cyberbullying', 'Cyberbullying', 'Cyberbullying', 'Sarcasm',
#        'Cyberbullying', 'Sarcasm', 'Sarcasm', 'Sarcasm', 'Cyberbullying',
#        'Sarcasm', 'Gender_Discrimination', 'Racism', 'Cyberbullying',
#        'Sarcasm', 'Cyberbullying', 'Cyberbullying', 'Cyberbullying',
#        'Political', 'Sarcasm', 'Cyberbullying', 'Cyberbullying',
#        'Political', 'Political', 'Religious_Hatred', 'Sarcasm',
#        'Cyberbullying', 'Cyberbullying', 'Cyberbullying', 'Cyberbullying',
#        'Religious_Hatred', 'Religious_Hatred', 'Sarcasm', 'Cyberbullying',
#        'Religious_Hatred', 'Cyberbullying', 'Cyberbullying', 'Sarcasm',
#        'Religious_Hatred', 'Sarcasm', 'Political', 'Cyberbullying',
#        'Cyberbullying', 'Political', 'Religious_Hatred', 'Political',
#        'Sarcasm', 'Cyberbullying', 'Sarcasm', 'Sarcasm', 'Sarcasm',
#        'Cyberbullying', 'Cyberbullying', 'Religious_Hatred', 'Sarcasm',
#        'Cyberbullying', 'Sarcasm', 'Sarcasm', 'Cyberbullying', 'Sarcasm',
#        'Sarcasm', 'Cyberbullying', 'Cyberbullying', 'Sarcasm',
#        'Cyberbullying', 'Political', 'Sarcasm', 'Sarcasm', 'Sarcasm',
#        'Sarcasm', 'Racism', 'Cyberbullying', 'Sarcasm', 'Racism',
#        'Sarcasm', 'Cyberbullying', 'Cyberbullying', 'Sarcasm',
#        'Political', 'Sarcasm', 'Racism', 'Racism', 'Sarcasm', 'Sarcasm',
#        'Cyberbullying', 'Cyberbullying', 'Cyberbullying', 'Political',
#        'Cyberbullying', 'Cyberbullying', 'Cyberbullying', 'Cyberbullying',
#        'Cyberbullying', 'Cyberbullying', 'Cyberbullying', 'Sarcasm',
#        'Sarcasm', 'Cyberbullying', 'Cyberbullying', 'Sarcasm', 'Sarcasm',
#        'Cyberbullying', 'Political', 'Cyberbullying', 'Cyberbullying',
#        'Sarcasm', 'Cyberbullying', 'Cyberbullying', 'Cyberbullying',
#        'Religious_Hatred', 'Religious_Hatred', 'Religious_Hatred',
#        'Political', 'Cyberbullying', 'Sarcasm', 'Cyberbullying',
#        'Political', 'Sarcasm', 'Political', 'Cyberbullying',
#        'Cyberbullying', 'Cyberbullying', 'Sarcasm', 'Political',
#        'Sarcasm', 'Sarcasm', 'Sarcasm', 'Racism', 'Political',
#        'Cyberbullying', 'Cyberbullying', 'Cyberbullying', 'Cyberbullying',
#        'Sarcasm', 'Religious_Hatred', 'Racism', 'Sarcasm', 'Racism',
#        'Sarcasm', 'Sarcasm', 'Cyberbullying', 'Cyberbullying', 'Sarcasm',
#        'Racism', 'Sarcasm', 'Cyberbullying', 'Sarcasm', 'Cyberbullying',
#        'Religious_Hatred', 'Cyberbullying', 'Cyberbullying', 'Sarcasm',
#        'Sarcasm', 'Cyberbullying', 'Cyberbullying', 'Sarcasm', 'Sarcasm',
#        'Sarcasm', 'Sarcasm', 'Cyberbullying', 'Sarcasm', 'Political',
#        'Cyberbullying', 'Racism', 'Sarcasm', 'Religious_Hatred',
#        'Sarcasm', 'Political', 'Cyberbullying', 'Sarcasm', 'Sarcasm',
#        'Sarcasm', 'Racism', 'Sarcasm', 'Sarcasm', 'Cyberbullying',
#        'Religious_Hatred', 'Sarcasm', 'Sarcasm', 'Cyberbullying',
#        'Sarcasm', 'Sarcasm', 'Religious_Hatred', 'Cyberbullying',
#        'Sarcasm', 'Political', 'Political', 'Cyberbullying',
#        'Cyberbullying', 'Cyberbullying', 'Racism', 'Cyberbullying',
#        'Cyberbullying', 'Cyberbullying', 'Sarcasm', 'Cyberbullying',
#        'Cyberbullying', 'Cyberbullying', 'Sarcasm', 'Cyberbullying',
#        'Cyberbullying', 'Political', 'Religious_Hatred', 'Cyberbullying',
#        'Cyberbullying', 'Racism', 'Sarcasm', 'Cyberbullying',
#        'Cyberbullying', 'Religious_Hatred', 'Cyberbullying', 'Political',
#        'Sarcasm', 'Sarcasm', 'Cyberbullying', 'Cyberbullying',
#        'Cyberbullying', 'Cyberbullying', 'Racism', 'Sarcasm', 'Sarcasm',
#        'Cyberbullying', 'Sarcasm', 'Religious_Hatred', 'Cyberbullying',
#        'Political', 'Political', 'Sarcasm', 'Political', 'Cyberbullying',
#        'Political', 'Racism', 'Cyberbullying', 'Cyberbullying',
#        'Cyberbullying', 'Religious_Hatred', 'Cyberbullying',
#        'Cyberbullying', 'Cyberbullying', 'Cyberbullying', 'Political',
#        'Racism', 'Cyberbullying', 'Sarcasm', 'Religious_Hatred',
#        'Political', 'Cyberbullying', 'Cyberbullying', 'Cyberbullying',
#        'Cyberbullying', 'Religious_Hatred', 'Sarcasm', 'Religious_Hatred',
#        'Sarcasm', 'Sarcasm', 'Sarcasm', 'Sarcasm', 'Religious_Hatred',
#        'Sarcasm', 'Cyberbullying', 'Cyberbullying', 'Cyberbullying',
#        'Cyberbullying', 'Sarcasm', 'Sarcasm', 'Sarcasm', 'Sarcasm',
#        'Cyberbullying', 'Religious_Hatred', 'Cyberbullying',
#        'Religious_Hatred', 'Cyberbullying', 'Political', 'Sarcasm',
#        'Cyberbullying', 'Sarcasm', 'Religious_Hatred', 'Cyberbullying',
#        'Sarcasm', 'Political', 'Religious_Hatred', 'Political', 'Racism',
#        'Political', 'Political', 'Sarcasm', 'Cyberbullying', 'Political',
#        'Political', 'Gender_Discrimination', 'Political', 'Sarcasm',
#        'Cyberbullying', 'Cyberbullying', 'Sarcasm', 'Racism',
#        'Religious_Hatred', 'Sarcasm', 'Sarcasm', 'Cyberbullying',
#        'Cyberbullying', 'Sarcasm', 'Cyberbullying', 'Sarcasm', 'Sarcasm',
#        'Religious_Hatred', 'Cyberbullying', 'Cyberbullying', 'Political',
#        'Sarcasm', 'Cyberbullying', 'Sarcasm', 'Sarcasm', 'Cyberbullying',
#        'Cyberbullying', 'Political', 'Religious_Hatred',
#        'Gender_Discrimination', 'Cyberbullying', 'Sarcasm', 'Political',
#        'Cyberbullying', 'Religious_Hatred', 'Cyberbullying',
#        'Cyberbullying', 'Cyberbullying', 'Religious_Hatred',
#        'Cyberbullying', 'Sarcasm', 'Sarcasm', 'Sarcasm', 'Sarcasm',
#        'Political', 'Political', 'Sarcasm', 'Sarcasm', 'Cyberbullying',
#        'Cyberbullying', 'Cyberbullying', 'Political', 'Political'],
#       dtype=object)

# %%
sns.countplot(y =le.inverse_transform(y_preds))
# Out:
# <Axes: xlabel='count'>

# %%
len(y_ids)
# Out:
# 600

# %%
y_pred=le.inverse_transform(y_preds)
y_pred
# Out:
# array(['Cyberbullying', 'Cyberbullying', 'Cyberbullying', 'Sarcasm',
#        'Sarcasm', 'Cyberbullying', 'Cyberbullying', 'Sarcasm',
#        'Political', 'Religious_Hatred', 'Sarcasm', 'Sarcasm', 'Sarcasm',
#        'Cyberbullying', 'Cyberbullying', 'Cyberbullying', 'Cyberbullying',
#        'Political', 'Sarcasm', 'Sarcasm', 'Political', 'Sarcasm',
#        'Religious_Hatred', 'Cyberbullying', 'Religious_Hatred', 'Sarcasm',
#        'Religious_Hatred', 'Sarcasm', 'Cyberbullying', 'Sarcasm',
#        'Racism', 'Religious_Hatred', 'Sarcasm', 'Cyberbullying',
#        'Cyberbullying', 'Cyberbullying', 'Gender_Discrimination',
#        'Cyberbullying', 'Racism', 'Cyberbullying', 'Cyberbullying',
#        'Cyberbullying', 'Cyberbullying', 'Cyberbullying',
#        'Religious_Hatred', 'Sarcasm', 'Cyberbullying', 'Cyberbullying',
#        'Cyberbullying', 'Religious_Hatred', 'Political',
#        'Religious_Hatred', 'Cyberbullying', 'Cyberbullying', 'Political',
#        'Sarcasm', 'Cyberbullying', 'Cyberbullying', 'Cyberbullying',
#        'Cyberbullying', 'Sarcasm', 'Cyberbullying', 'Cyberbullying',
#        'Cyberbullying', 'Cyberbullying', 'Sarcasm', 'Sarcasm', 'Sarcasm',
#        'Cyberbullying', 'Political', 'Cyberbullying', 'Sarcasm',
#        'Cyberbullying', 'Sarcasm', 'Sarcasm', 'Sarcasm', 'Cyberbullying',
#        'Political', 'Political', 'Cyberbullying', 'Religious_Hatred',
#        'Sarcasm', 'Religious_Hatred', 'Religious_Hatred', 'Cyberbullying',
#        'Racism', 'Cyberbullying', 'Cyberbullying', 'Sarcasm', 'Sarcasm',
#        'Cyberbullying', 'Cyberbullying', 'Political', 'Sarcasm',
#        'Cyberbullying', 'Cyberbullying', 'Cyberbullying', 'Cyberbullying',
#        'Sarcasm', 'Sarcasm', 'Political', 'Sarcasm', 'Cyberbullying',
#        'Political', 'Cyberbullying', 'Political', 'Cyberbullying',
#        'Political', 'Sarcasm', 'Sarcasm', 'Cyberbullying',
#        'Cyberbullying', 'Sarcasm', 'Sarcasm', 'Sarcasm', 'Racism',
#        'Sarcasm', 'Sarcasm', 'Cyberbullying', 'Political', 'Racism',
#        'Religious_Hatred', 'Sarcasm', 'Cyberbullying', 'Cyberbullying',
#        'Religious_Hatred', 'Cyberbullying', 'Sarcasm', 'Cyberbullying',
#        'Cyberbullying', 'Sarcasm', 'Sarcasm', 'Religious_Hatred',
#        'Sarcasm', 'Sarcasm', 'Sarcasm', 'Sarcasm', 'Sarcasm', 'Sarcasm',
#        'Cyberbullying', 'Racism', 'Religious_Hatred', 'Cyberbullying',
#        'Sarcasm', 'Sarcasm', 'Religious_Hatred', 'Sarcasm',
#        'Cyberbullying', 'Religious_Hatred', 'Cyberbullying',
#        'Cyberbullying', 'Cyberbullying', 'Cyberbullying', 'Sarcasm',
#        'Cyberbullying', 'Racism', 'Cyberbullying', 'Sarcasm',
#        'Religious_Hatred', 'Cyberbullying', 'Cyberbullying', 'Sarcasm',
#        'Sarcasm', 'Political', 'Sarcasm', 'Sarcasm', 'Sarcasm',
#        'Cyberbullying', 'Sarcasm', 'Sarcasm', 'Cyberbullying', 'Sarcasm',
#        'Sarcasm', 'Sarcasm', 'Racism', 'Sarcasm', 'Political',
#        'Cyberbullying', 'Racism', 'Cyberbullying', 'Cyberbullying',
#        'Political', 'Religious_Hatred', 'Cyberbullying', 'Political',
#        'Political', 'Sarcasm', 'Cyberbullying', 'Cyberbullying',
#        'Religious_Hatred', 'Sarcasm', 'Cyberbullying', 'Cyberbullying',
#        'Cyberbullying', 'Political', 'Sarcasm', 'Religious_Hatred',
#        'Cyberbullying', 'Religious_Hatred', 'Sarcasm', 'Cyberbullying',
#        'Cyberbullying', 'Cyberbullying', 'Cyberbullying', 'Cyberbullying',
#        'Sarcasm', 'Political', 'Political', 'Cyberbullying',
#        'Cyberbullying', 'Religious_Hatred', 'Cyberbullying', 'Sarcasm',
#        'Cyberbullying', 'Cyberbullying', 'Sarcasm', 'Sarcasm',
#        'Cyberbullying', 'Sarcasm', 'Cyberbullying', 'Cyberbullying',
#        'Racism', 'Cyberbullying', 'Cyberbullying', 'Sarcasm', 'Sarcasm',
#        'Political', 'Sarcasm', 'Cyberbullying', 'Cyberbullying',
#        'Sarcasm', 'Sarcasm', 'Sarcasm', 'Racism', 'Political', 'Sarcasm',
#        'Political', 'Sarcasm', 'Sarcasm', 'Sarcasm', 'Sarcasm', 'Sarcasm',
#        'Gender_Discrimination', 'Sarcasm', 'Religious_Hatred', 'Racism',
#        'Cyberbullying', 'Racism', 'Sarcasm', 'Cyberbullying', 'Sarcasm',
#        'Cyberbullying', 'Cyberbullying', 'Racism', 'Cyberbullying',
#        'Political', 'Sarcasm', 'Sarcasm', 'Sarcasm', 'Sarcasm',
#        'Cyberbullying', 'Cyberbullying', 'Cyberbullying', 'Sarcasm',
#        'Cyberbullying', 'Sarcasm', 'Sarcasm', 'Sarcasm', 'Cyberbullying',
#        'Sarcasm', 'Gender_Discrimination', 'Racism', 'Cyberbullying',
#        'Sarcasm', 'Cyberbullying', 'Cyberbullying', 'Cyberbullying',
#        'Political', 'Sarcasm', 'Cyberbullying', 'Cyberbullying',
#        'Political', 'Political', 'Religious_Hatred', 'Sarcasm',
#        'Cyberbullying', 'Cyberbullying', 'Cyberbullying', 'Cyberbullying',
#        'Religious_Hatred', 'Religious_Hatred', 'Sarcasm', 'Cyberbullying',
#        'Religious_Hatred', 'Cyberbullying', 'Cyberbullying', 'Sarcasm',
#        'Religious_Hatred', 'Sarcasm', 'Political', 'Cyberbullying',
#        'Cyberbullying', 'Political', 'Religious_Hatred', 'Political',
#        'Sarcasm', 'Cyberbullying', 'Sarcasm', 'Sarcasm', 'Sarcasm',
#        'Cyberbullying', 'Cyberbullying', 'Religious_Hatred', 'Sarcasm',
#        'Cyberbullying', 'Sarcasm', 'Sarcasm', 'Cyberbullying', 'Sarcasm',
#        'Sarcasm', 'Cyberbullying', 'Cyberbullying', 'Sarcasm',
#        'Cyberbullying', 'Political', 'Sarcasm', 'Sarcasm', 'Sarcasm',
#        'Sarcasm', 'Racism', 'Cyberbullying', 'Sarcasm', 'Racism',
#        'Sarcasm', 'Cyberbullying', 'Cyberbullying', 'Sarcasm',
#        'Political', 'Sarcasm', 'Racism', 'Racism', 'Sarcasm', 'Sarcasm',
#        'Cyberbullying', 'Cyberbullying', 'Cyberbullying', 'Political',
#        'Cyberbullying', 'Cyberbullying', 'Cyberbullying', 'Cyberbullying',
#        'Cyberbullying', 'Cyberbullying', 'Cyberbullying', 'Sarcasm',
#        'Sarcasm', 'Cyberbullying', 'Cyberbullying', 'Sarcasm', 'Sarcasm',
#        'Cyberbullying', 'Political', 'Cyberbullying', 'Cyberbullying',
#        'Sarcasm', 'Cyberbullying', 'Cyberbullying', 'Cyberbullying',
#        'Religious_Hatred', 'Religious_Hatred', 'Religious_Hatred',
#        'Political', 'Cyberbullying', 'Sarcasm', 'Cyberbullying',
#        'Political', 'Sarcasm', 'Political', 'Cyberbullying',
#        'Cyberbullying', 'Cyberbullying', 'Sarcasm', 'Political',
#        'Sarcasm', 'Sarcasm', 'Sarcasm', 'Racism', 'Political',
#        'Cyberbullying', 'Cyberbullying', 'Cyberbullying', 'Cyberbullying',
#        'Sarcasm', 'Religious_Hatred', 'Racism', 'Sarcasm', 'Racism',
#        'Sarcasm', 'Sarcasm', 'Cyberbullying', 'Cyberbullying', 'Sarcasm',
#        'Racism', 'Sarcasm', 'Cyberbullying', 'Sarcasm', 'Cyberbullying',
#        'Religious_Hatred', 'Cyberbullying', 'Cyberbullying', 'Sarcasm',
#        'Sarcasm', 'Cyberbullying', 'Cyberbullying', 'Sarcasm', 'Sarcasm',
#        'Sarcasm', 'Sarcasm', 'Cyberbullying', 'Sarcasm', 'Political',
#        'Cyberbullying', 'Racism', 'Sarcasm', 'Religious_Hatred',
#        'Sarcasm', 'Political', 'Cyberbullying', 'Sarcasm', 'Sarcasm',
#        'Sarcasm', 'Racism', 'Sarcasm', 'Sarcasm', 'Cyberbullying',
#        'Religious_Hatred', 'Sarcasm', 'Sarcasm', 'Cyberbullying',
#        'Sarcasm', 'Sarcasm', 'Religious_Hatred', 'Cyberbullying',
#        'Sarcasm', 'Political', 'Political', 'Cyberbullying',
#        'Cyberbullying', 'Cyberbullying', 'Racism', 'Cyberbullying',
#        'Cyberbullying', 'Cyberbullying', 'Sarcasm', 'Cyberbullying',
#        'Cyberbullying', 'Cyberbullying', 'Sarcasm', 'Cyberbullying',
#        'Cyberbullying', 'Political', 'Religious_Hatred', 'Cyberbullying',
#        'Cyberbullying', 'Racism', 'Sarcasm', 'Cyberbullying',
#        'Cyberbullying', 'Religious_Hatred', 'Cyberbullying', 'Political',
#        'Sarcasm', 'Sarcasm', 'Cyberbullying', 'Cyberbullying',
#        'Cyberbullying', 'Cyberbullying', 'Racism', 'Sarcasm', 'Sarcasm',
#        'Cyberbullying', 'Sarcasm', 'Religious_Hatred', 'Cyberbullying',
#        'Political', 'Political', 'Sarcasm', 'Political', 'Cyberbullying',
#        'Political', 'Racism', 'Cyberbullying', 'Cyberbullying',
#        'Cyberbullying', 'Religious_Hatred', 'Cyberbullying',
#        'Cyberbullying', 'Cyberbullying', 'Cyberbullying', 'Political',
#        'Racism', 'Cyberbullying', 'Sarcasm', 'Religious_Hatred',
#        'Political', 'Cyberbullying', 'Cyberbullying', 'Cyberbullying',
#        'Cyberbullying', 'Religious_Hatred', 'Sarcasm', 'Religious_Hatred',
#        'Sarcasm', 'Sarcasm', 'Sarcasm', 'Sarcasm', 'Religious_Hatred',
#        'Sarcasm', 'Cyberbullying', 'Cyberbullying', 'Cyberbullying',
#        'Cyberbullying', 'Sarcasm', 'Sarcasm', 'Sarcasm', 'Sarcasm',
#        'Cyberbullying', 'Religious_Hatred', 'Cyberbullying',
#        'Religious_Hatred', 'Cyberbullying', 'Political', 'Sarcasm',
#        'Cyberbullying', 'Sarcasm', 'Religious_Hatred', 'Cyberbullying',
#        'Sarcasm', 'Political', 'Religious_Hatred', 'Political', 'Racism',
#        'Political', 'Political', 'Sarcasm', 'Cyberbullying', 'Political',
#        'Political', 'Gender_Discrimination', 'Political', 'Sarcasm',
#        'Cyberbullying', 'Cyberbullying', 'Sarcasm', 'Racism',
#        'Religious_Hatred', 'Sarcasm', 'Sarcasm', 'Cyberbullying',
#        'Cyberbullying', 'Sarcasm', 'Cyberbullying', 'Sarcasm', 'Sarcasm',
#        'Religious_Hatred', 'Cyberbullying', 'Cyberbullying', 'Political',
#        'Sarcasm', 'Cyberbullying', 'Sarcasm', 'Sarcasm', 'Cyberbullying',
#        'Cyberbullying', 'Political', 'Religious_Hatred',
#        'Gender_Discrimination', 'Cyberbullying', 'Sarcasm', 'Political',
#        'Cyberbullying', 'Religious_Hatred', 'Cyberbullying',
#        'Cyberbullying', 'Cyberbullying', 'Religious_Hatred',
#        'Cyberbullying', 'Sarcasm', 'Sarcasm', 'Sarcasm', 'Sarcasm',
#        'Political', 'Political', 'Sarcasm', 'Sarcasm', 'Cyberbullying',
#        'Cyberbullying', 'Cyberbullying', 'Political', 'Political'],
#       dtype=object)
